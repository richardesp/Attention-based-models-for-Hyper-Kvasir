# %% [markdown]
# # Setup
#
# The implementation is given by: https://keras.io/examples/vision/image_classification_with_vision_transformer/

# %%
# !pip install tensorflow-addons
# !pip install tensorflow==2.8.3 # Due a bug in DataAugmentation in newer versions 
# of tensorflow
# !pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (23.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.19.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8.3
#   Downloading tensorflow-2.8.3-cp38-cp38-manylinux2010_x86_64.whl (498.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.4/498.4 MB 2.4 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (0.31.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (2.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (23.1.21)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (15.0.6.1)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (3.3.0)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 97.1 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.51.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.15.0)
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (0.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.4.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.3) (4.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.3) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2.16.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.3) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.3) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, keras-preprocessing, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorflow-2.8.3 tensorflow-estimator-2.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.0-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.25.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.8.3)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (57.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.22.4)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (4.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.51.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.8.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (4.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (2.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.0->keras-tuner) (3.2.2)
# Installing collected packages: kt-legacy, jedi, keras-tuner
# Successfully installed jedi-0.18.2 keras-tuner-1.3.0 kt-legacy-1.0.4

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow_addons.optimizers import AdamW
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
import pickle
import keras_tuner
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.3 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# !nvidia-smi
# Out:
# Mon Mar  6 16:08:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    63W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar  6 16:13:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    50W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # Prepare the data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
dataset_dir = "gdrive/MyDrive/hyper-kvasir-dataset-final"

# %%
def get_dataCategories(dataset_dir):
    import glob

    categories = []
    for folder_name in os.listdir(dataset_dir):
        if os.path.isdir(os.path.join(dataset_dir, folder_name)):
            nbr_files = len(
                glob.glob(os.path.join(dataset_dir, folder_name) + "/*.jpg")
            )
            categories.append(np.array([folder_name, nbr_files]))

    categories.sort(key=lambda a: a[0])
    cat = np.array(categories)

    return list(cat[:, 0]), list(cat[:, 1])

categories, nbr_files = get_dataCategories(dataset_dir)

# Create DataFrame
df = pd.DataFrame({"categorie": categories, "numbre of files": nbr_files})
print("number of categories: ", len(categories))
df
# Out:
# number of categories:  23
#                        categorie numbre of files
# 0                       barretts              41
# 1         barretts-short-segment              53
# 2                       bbps-0-1             646
# 3                       bbps-2-3            1158
# 4                          cecum            1027
# 5             dyed-lifted-polyps            1002
# 6         dyed-resection-margins             989
# 7                  esophagitis-a             413
# 8                esophagitis-b-d             260
# 9                    hemorrhoids               6
# 10                         ileum               9
# 11                impacted-stool             131
# 12                        polyps            1028
# 13                       pylorus            1029
# 14              retroflex-rectum             391
# 15             retroflex-stomach             774
# 16  ulcerative-colitis-grade-0-1              35
# 17    ulcerative-colitis-grade-1             201
# 18  ulcerative-colitis-grade-1-2              11
# 19    ulcerative-colitis-grade-2             443
# 20  ulcerative-colitis-grade-2-3              28
# 21    ulcerative-colitis-grade-3             133
# 22                        z-line             932

# %% [markdown]
# ## Obtaining the entire data and labels

# %%
def get_x_y(datadir, categories, img_wid, img_high):
    X, y = [], []
    for category in categories:
        path = os.path.join(datadir, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
                ima_resize_rgb = cv2.resize(img_array, (img_wid, img_high))

                X.append(ima_resize_rgb)
                y.append(class_num)

            except Exception as e:
                print(e)

    y = np.array(y)
    X = np.array(X)

    # reshape X into img_wid x img_high x 3
    X = X.reshape(X.shape[0], img_wid, img_high, 3)

    return X, y


img_wid, img_high = 224, 224
X, y = get_x_y(dataset_dir, categories, img_wid, img_high)

print(f"X: {X.shape}")
print(f"y: {y.shape}")
# Out:
# X: (10740, 224, 224, 3)
# y: (10740,)

# %% [markdown]
# ## Visualize the data

# %%
plt.figure(figsize=(12, 5))
st, end = 0, 500
for i in range(8):
    plt.subplot(2, 4, i + 1)
    idx = np.random.randint(st, end)
    st = end + 1
    end = (i + 2) * 500
    plt.imshow(X[idx][:, :, ::-1])
    plt.title(f"{i}. {categories[y[idx]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# ## Split the data into fold_0 and fold_1 (the official splits used in the paper)

# %%
Y = np.reshape(y, (len(y), 1))


X_fold_0, X_fold_1, y_fold_0, y_fold_1 = train_test_split(
    X, Y, train_size=0.5, random_state=42, stratify=Y
)

k_folds = [[X_fold_0, y_fold_0 ], [X_fold_1, y_fold_1]]

print(f"X_fold_0: {X_fold_0.shape}")
print(f"y_fold_0: {y_fold_0.shape}")
print(f"X_fold_1: {X_fold_1.shape}")
print(f"y_fold_1: {y_fold_1.shape}")
# Out:
# X_fold_0: (5370, 224, 224, 3)
# y_fold_0: (5370, 1)
# X_fold_1: (5370, 224, 224, 3)
# y_fold_1: (5370, 1)

# %% [markdown]
# # Building the ViT model
#
# [Model diagram](https://viso.ai/wp-content/uploads/2021/09/vision-transformer-vit.png)

# %% [markdown]
# ## Multi-Layer-Perceptron (MLP)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Patch creation layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# ## Hyper-parameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 250
image_size = 224  # We'll resize input images to this size
patch_size = 24  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier
seed = 1

# %% [markdown]
# ## Patch encoding layer

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# # Pre-tunning

# %%
from keras_tuner import RandomSearch

# tuner for function
tuner = RandomSearch(
    optimize_vit_classifier,
    objective='val_accuracy',
    max_trials=10000,
    overwrite=True,
    executions_per_trial=1)

# %%
tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best learning rate: {best_hps.get('learning_rate')}")
print(f"Best weight_decay: {best_hps.get('weight_decay')}")
print(f"Best projection_dim: {best_hps.get('projection_dim')}")
print(f"Best transfomers units: [{int(best_hps.get('projection_dim')) * 2}, {best_hps.get('projection_dim')}]")
print(f"transformer_layers: {best_hps.get('transformer_layers')}")
print(f"Best patch_size: {best_hps.get('patch_size')}")
print(f"Best number of patches: {(image_size // int(best_hps.get('patch_size'))) ** 2}")
print(f"Best seed: {best_hps.get('seed')}")

# %% [markdown]
# # Using W&D Tunning

# %%
# !pip install wandb
# !wandb login
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.10-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.25.1)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=e760cbee5630b55013bddea8cc4d28e2ef25eb8dd3188740694b6f6e6c766e6c
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.16.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.10
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint
import os

os.environ['WANDB_NOTEBOOK_NAME'] = 'gdrive/MyDrive/Universidad/TFG/notebooks/2.2-rep-first-vit-tf-from-scratch-tunner-f1.ipynb'

wandb.login()
# Out:
# wandb: Currently logged in as: richardesp (ava-research-hyper-kvasir). Use `wandb login --relogin` to force relogin
# True

# %%
num_classes = 23
input_shape = (224, 224, 3)

def get_vit_classifier(seed: float, patch_size: int, projection_dim: int, transformers_layer: int,
                            learning_rate: float, weight_decay: float):

    # Five steps approach to select a initial seed
    import numpy.random
    np.random.seed(seed)

    import tensorflow as tf
    tf.random.set_seed(seed)

    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    num_patches = (image_size // patch_size) ** 2
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    transformer_units = [
      projection_dim * 2,
      projection_dim,
    ]

    # Create multiple layers of the Transformer block.
    for _ in range(transformers_layer):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)

    # Compiling the final  model 
    optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

    return model

# %%
sweep_config = {
    'method': 'bayes'
}


metric = {
    'name': 'val_accuracy',
    'goal': 'maximize'   
}

sweep_config['metric'] = metric

parameters_dict = {
    'seed': {
        'values': [1, 2, 3, 4, 5]
        },
    'patch_size': {
          'values': [12, 16, 20, 24]
        },
    'projection_dim': {
          'values': [16, 32, 64, 128]
        },
    'transfomers_layers': {
          'values': [4, 8, 12, 16]
        },
    'learning_rate': {
        'values': [0.00001, 0.0001, 0.001, 0.01]
    },
    'weight_decay': {
        'values': [0.00001, 0.0001, 0.001, 0.01]
    },
    'batch_size': {
        'values': [32, 64, 128, 256]
    }
}

sweep_config['parameters'] = parameters_dict


parameters_dict.update({
    'epochs': {
        'value': 30
    }
})

# %%
import pprint

pprint.pprint(sweep_config)
# Out:
# {'method': 'bayes',
#  'metric': {'goal': 'maximize', 'name': 'val_accuracy'},
#  'parameters': {'batch_size': {'values': [32, 64, 128, 256]},
#                 'epochs': {'value': 30},
#                 'learning_rate': {'values': [1e-05, 0.0001, 0.001, 0.01]},
#                 'patch_size': {'values': [12, 16, 20, 24]},
#                 'projection_dim': {'values': [16, 32, 64, 128]},
#                 'seed': {'values': [1, 2, 3, 4, 5]},
#                 'transfomers_layers': {'values': [4, 8, 12, 16]},
#                 'weight_decay': {'values': [1e-05, 0.0001, 0.001, 0.01]}}}

# %%
from tensorflow.keras.callbacks import EarlyStopping

def sweep_train(config_defaults=None):
    # Initialize wandb with a sample project name
    with wandb.init(config=config_defaults):  # this gets over-written in the Sweep

        # Specify the other hyperparameters to the configuration, if any
        wandb.config.architecture_name = "vit-scratch"
        wandb.config.dataset_name = "Hyper-Kvasir"

        # initialize model
        model = get_vit_classifier(wandb.config.seed, wandb.config.patch_size, wandb.config.projection_dim,
                                   wandb.config.transfomers_layers, wandb.config.learning_rate, wandb.config.weight_decay)

        # callback setup
        wandb_callbacks = [
            WandbMetricsLogger(), # We can add a checkpoint
            metrics,
            EarlyStopping(monitor='val_accuracy', patience=3)
        ]

        model.fit(X_train, 
                  y_train, 
                  batch_size=wandb.config.batch_size, 
                  epochs=wandb.config.epochs, 
                  validation_data=(X_test, y_test), 
                  callbacks=wandb_callbacks)

# %%
sweep_id = wandb.sweep(sweep_config, project="hyper-kvasir-optimization-models-f1", entity="ava-research-hyper-kvasir")
# Out:
# Create sweep with ID: yq5f6lll
# Sweep URL: https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll

# %%
wandb.agent(sweep_id, function=sweep_train, count=10000)
# Out:
# wandb: Agent Starting Run: bw4gfr3x with config:
# wandb: 	batch_size: 256
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0
</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/top-5-accuracy</td><td>▁▅▆▆▆▇▇▇████████</td></tr><tr><td>epoch/val_accuracy</td><td>▁▁▂▄▅▆▆▆▇▇▇█████</td></tr><tr><td>epoch/val_f1_macro</td><td>▂▁▃▄▅▅▆▆▆▆▆▇█▇█▇</td></tr><tr><td>epoch/val_f1_micro</td><td>▁▁▂▄▄▅▆▆▆▇▇▇▇▇█▇</td></tr><tr><td>epoch/val_loss</td><td>█▇▆▅▅▄▃▃▂▂▂▁▁▂▁▁</td></tr><tr><td>epoch/val_precision_macro</td><td>▃▁▃▃▅▅▆▆▆▆▅▇█▆▇▆</td></tr><tr><td>epoch/val_precision_micro</td><td>▁▁▂▄▄▅▆▆▆▇▇▇▇▇█▇</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▁▂▄▄▅▆▅▆▇▆▇█▆█▇</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▁▂▄▄▅▆▆▆▇▇▇▇▇█▇</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁▄▄▆▆▇▇▇▇██▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.62803</td></tr><tr><td>epoch/epoch</td><td>15</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.04172</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.96543</td></tr><tr><td>epoch/val_accuracy</td><td>0.67877</td></tr><tr><td>epoch/val_f1_macro</td><td>0.35476</td></tr><tr><td>epoch/val_f1_micro</td><td>0.64898</td></tr><tr><td>epoch/val_loss</td><td>0.81425</td></tr><tr><td>epoch/val_precision_macro</td><td>0.40296</td></tr><tr><td>epoch/val_precision_micro</td><td>0.64898</td></tr><tr><td>epoch/val_recall_macro</td><td>0.37923</td></tr><tr><td>epoch/val_recall_micro</td><td>0.64898</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.97858</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stoic-sweep-1</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/bw4gfr3x' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/bw4gfr3x</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_001903-bw4gfr3x/logs</code>
# wandb: Agent Starting Run: m3aah2ph with config:
# wandb: 	batch_size: 256
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.01
# wandb: 	patch_size: 12
# wandb: 	projection_dim: 128
# wandb: 	seed: 5
# wandb: 	transfomers_layers: 12
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_002056-m3aah2ph</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/m3aah2ph' target="_blank">denim-sweep-2</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/m3aah2ph' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/m3aah2ph</a>
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 132.2034 - accuracy: 0.1176 - top-5-accuracy: 0.4238 - val_f1_macro: 0.023364899758748395 - val_f1_micro: 0.11824953445065177
#        - val_precision_macro: 0.0480018927821676 - val_precision_micro: 0.11824953445065177 - val_recall_macro: 0.05318053241391845 - val_recall_micro: 0.11824953445065177
# 34/34 [==============================] - 39s 697ms/step - loss: 132.2034 - accuracy: 0.1176 - top-5-accuracy: 0.4238 - val_loss: 2.7333 - val_accuracy: 0.1280 - val_top-5-accuracy: 0.4777
# Epoch 2/30
# 34/34 [==============================] - ETA: 0s - loss: 2.6903 - accuracy: 0.1151 - top-5-accuracy: 0.4943 - val_f1_macro: 0.03152314727049736 - val_f1_micro: 0.11778398510242086
#        - val_precision_macro: 0.14868976405439283 - val_precision_micro: 0.11778398510242086 - val_recall_macro: 0.06268610661241826 - val_recall_micro: 0.11778398510242086
# 34/34 [==============================] - 20s 586ms/step - loss: 2.6903 - accuracy: 0.1151 - top-5-accuracy: 0.4943 - val_loss: 2.6098 - val_accuracy: 0.1220 - val_top-5-accuracy: 0.5400
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss:
td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.91574</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">denim-sweep-2</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/m3aah2ph' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/m3aah2ph</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_002056-m3aah2ph/logs</code>
# Run m3aah2ph errored: ResourceExhaustedError()
# wandb: ERROR Run m3aah2ph errored: ResourceExhaustedError()
# wandb: Agent Starting Run: ufe5j6l4 with config:
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	learning_rate: 1e-05
# wandb: 	patch_size: 24
# wandb: 	projection_dim: 32
# wandb: 	seed: 1
# wandb: 	transfomers_layers: 4
# wandb: 	weight_decay: 0.001
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_002349-ufe5j6l4</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/ufe5j6l4' target="_blank">eager-sweep-3</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/ufe5j6l4' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/ufe5j6l4</a>
# Epoch 1/30
# 67/68 [============================>.] - ETA: 0s - loss: 3.7979 - accuracy: 0.1191 - top-5-accuracy: 0.4011 - val_f1_macro: 0.14465440186055362 - val_f1_micro: 0.3542830540037244
#        - val_precision_macro: 0.1637520750380554 - val_precision_micro: 0.3542830540037244 - val_recall_macro: 0.17539319666198722 - val_recall_micro: 0.3542830540037244
# 68/68 [==============================] - 11s 77ms/step - loss: 3.7954 - accuracy: 0.1194 - top-5-accuracy: 0.4018 - val_loss: 2.0823 - val_accuracy: 0.4134 - val_top-5-accuracy: 0.8338
# Epoch 2/30
# 67/68 [============================>.] - ETA: 0s - loss: 2.6254 - accuracy: 0.2409 - top-5-accuracy: 0.6414 - val_f1_macro: 0.1604227660712224 - val_f1_micro: 0.3873370577281191
#        - val_precision_macro: 0.18786265161965723 - val_precision_micro: 0.38733705772811916 - val_recall_macro: 0.19314066118363274 - val_recall_micro: 0.38733705772811916
# 68/68 [==============================] - 3s 51ms/step - loss: 2.6247 - accuracy: 0.2408 - top-5-accuracy: 0.6418 - val_loss: 1.8887 - val_accuracy: 0.4437 - val_top-5-accuracy: 0.8845
# Epoch 3/30
# 67/68 [============================>.] - ETA: 0s - loss: 2.2077 - accuracy: 0.3239 - top-5-accuracy: 0.7565 - val_f1_macro: 0.1728569626195184 - val_f1_micro: 0.4082867783985103
#        - val_precision_macro: 0.1978308975235043 - val_precision_micro: 0.40828677839851024 - val_recall_macro: 0.20608546942056175 - val_recall_micro: 0.40828677839851024
# 68/68 [==============================] - 4s 52ms/step - loss: 2.2073 - accuracy: 0.3240 - top-5-accuracy: 0.7566 - val_loss: 1.8393 - val_accuracy: 0.4553 - val_top-5-accuracy: 0.9060
# Epoch 4/30
# 67/68 [============================>.] - ETA: 0s - loss: 2.0371 - accuracy: 0.3800 - top-5-accuracy: 0.8101 - val_f1_macro: 0.17484498566131843 - val_f1_micro: 0.41154562383612664
#        - val_precision_macro: 0.19807385200681404 - val_precision_micro: 0.41154562383612664 - val_recall_macro: 0.20969038859812308 - val_recall_micro: 0.41154562383612664
# 68/68 [==============================] - 4s 52ms/step - loss: 2.0373 - accuracy: 0.3798 - top-5-accuracy: 0.8101 - val_loss: 1.8346 - val_accuracy: 0.4558 - val_top-5-accuracy: 0.9115
# Epoch 5/30
# 67/68 [============================>.] - ETA: 0s - loss: 1.9527 - accuracy: 0.4090 - top-5-accuracy: 0.8465 - val_f1_macro: 0.1732040226539879 - val_f1_micro: 0.41201117318435754
#        - val_precision_macro: 0.1983459637105442 - val_precision_micro: 0.41201117318435754 - val_recall_macro: 0.21040688006742095 - val_recall_micro: 0.41201117318435754
# 68/68 [==============================] - 3s 50ms/step - loss: 1.9526 - accuracy: 0.4093 - top-5-accuracy: 0.8467 - val_loss: 1.8467 - val_accuracy: 0.4497 - val_top-5-accuracy: 0.9139
# Epoch 6/30
# 67/68 [============================>.] - ETA: 0s - loss: 1.9226 - accuracy: 0.4332 - top-5-accuracy: 0.8682 - val_f1_macro: 0.17318718952595893 - val_f1_micro: 0.41201117318435754
#        - val_precision_macro: 0.23701604229508144 - val_precision_micro: 0.41201117318435754 - val_recall_macro: 0.21116334947468338 - val_recall_micro: 0.41201117318435754
# 68/68 [==============================] - 3s 51ms/step - loss: 1.9224 - accuracy: 0.4332 - top-5-accuracy: 0.8684 - val_loss: 1.8687 - val_accuracy: 0.4437 - val_top-5-accuracy: 0.9097
# Epoch 7/30
# 67/68 [============================>.] - ETA: 0s - loss: 1.9180 - accuracy: 0.4396 - top-5-accuracy: 0.8740 - val_f1_macro: 0.17377516700430976 - val_f1_micro: 0.41527001862197394
#        - val_precision_macro: 0.22761245201141878 - val_precision_micro: 0.41527001862197394 - val_recall_macro: 0.21260291847989982 - val_recall_micro: 0.41527001862197394
# 68/68 [==============================] - 3s 51ms/step - loss: 1.9180 - accuracy: 0.4398 - top-5-accuracy: 0.8740 - val_loss: 1.8913 - val_accuracy: 0.4395 - val_top-5-accuracy: 0.9092
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▅▇▇██</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▂▁▁▁▁</td></tr><tr><td>epoch/top-5-accuracy</td><td>▁▅▆▇███</td></tr><tr><td>epoch/val_accuracy</td><td>▁▆██▇▆▅</td></tr><tr><td>epoch/val_f1_macro</td><td>▁▅█████</td></tr><tr><td>epoch/val_f1_micro</td><td>▁▅▇████</td></tr><tr><td>epoch/val_loss</td><td>█▃▁▁▁▂▃</td></tr><tr><td>epoch/val_precision_macro</td><td>▁▃▄▄▄█▇</td></tr><tr><td>epoch/val_precision_micro</td><td>▁▅▇████</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▄▇▇███</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▅▇████</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁▅▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.43983</td></tr><tr><td>epoch/epoch</td><td>6</td></tr><tr><td>epoch/learning_rate</td><td>1e-05</td></tr><tr><td>epoch/loss</td><td>1.91803</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.87395</td></tr><tr><td>epoch/val_accuracy</td><td>0.43948</td></tr><tr><td>epoch/val_f1_macro</td><td>0.17378</td></tr><tr><td>epoch/val_f1_micro</td><td>0.41527</td></tr><tr><td>epoch/val_loss</td><td>1.89129</td></tr><tr><td>epoch/val_precision_macro</td><td>0.22761</td></tr><tr><td>epoch/val_precision_micro</td><td>0.41527</td></tr><tr><td>epoch/val_recall_macro</td><td>0.2126</td></tr><tr><td>epoch/val_recall_micro</td><td>0.41527</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.90922</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-3</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/ufe5j6l4' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/ufe5j6l4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_002349-ufe5j6l4/logs</code>
# wandb: Agent Starting Run: 3olxp1xy with config:
# wandb: 	batch_size: 256
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.01
# wandb: 	patch_size: 12
# wandb: 	projection_dim: 16
# wandb: 	seed: 2
# wandb: 	transfomers_layers: 16
# wandb: 	weight_decay: 1e-05
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_002431-3olxp1xy</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/3olxp1xy' target="_blank">crisp-sweep-4</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/3olxp1xy' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/3olxp1xy</a>
# Epoch 1/30
# 34/34 [==============================] - ETA: 0s - loss: 13.0911 - accuracy: 0.1920 - top-5-accuracy: 0.5560 - val_f1_macro: 0.12737791924679123 - val_f1_micro: 0.30121042830540035
#        - val_precision_macro: 0.18248290421586477 - val_precision_micro: 0.30121042830540035 - val_recall_macro: 0.15433684367577225 - val_recall_micro: 0.30121042830540035
# 34/34 [==============================] - 37s 524ms/step - loss: 13.0911 - accuracy: 0.1920 - top-5-accuracy: 0.5560 - val_loss: 2.0511 - val_accuracy: 0.3440 - val_top-5-accuracy: 0.7277
# Epoch 2/30
# 34/34 [==============================] - ETA: 0s - loss: 2.5287 - accuracy: 0.1941 - top-5-accuracy: 0.6164 - val_f1_macro: 0.10386720066663578 - val_f1_micro: 0.2574487895716946
#        - val_precision_macro: 0.1314530000588976 - val_precision_micro: 0.2574487895716946 - val_recall_macro: 0.1325005187192745 - val_recall_micro: 0.2574487895716946
# 34/34 [==============================] - 13s 377ms/step - loss: 2.5287 - accuracy: 0.1941 - top-5-accuracy: 0.6164 - val_loss: 2.1290 - val_accuracy: 0.2905 - val_top-5-accuracy: 0.7561
# Epoch 3/30
# 34/34 [==============================] - ETA: 0s - loss: 2.4265 - accuracy: 0.2098 - top-5-accuracy: 0.6283 - val_f1_macro: 0.0645672208970766 - val_f1_micro: 0.2276536312849162
#        - val_precision_macro: 0.11103388133333905 - val_precision_micro: 0.2276536312849162 - val_recall_macro: 0.10823113146651946 - val_recall_micro: 0.2276536312849162
# 34/34 [==============================] - 13s 377ms/step - loss: 2.4265 - accuracy: 0.2098 - top-5-accuracy: 0.6283 - val_loss: 2.2664 - val_accuracy: 0.2402 - val_top-5-accuracy: 0.7561
# Epoch 4/30
# 34/34 [==============================] - ETA: 0s - loss: 2.3398 - accuracy: 0.2213 - top-5-accuracy: 0.6738 - val_f1_macro: 0.11243750276688229 - val_f1_micro: 0.2951582867783985
#        - val_precision_macro: 0.18611263503237485 - val_precision_micro: 0.2951582867783985 - val_recall_macro: 0.15126812236852663 - val_recall_micro: 0.2951582867783985
# 34/34 [==============================] - 13s 375ms/step - loss: 2.3398 - accuracy: 0.2213 - top-5-accuracy: 0.6738 - val_loss: 2.0366 - val_accuracy: 0.3436 - val_top-5-accuracy: 0.8343
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.012 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.067870…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▂▅█</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▆▆▆▆▆▆▆███████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▁▁▁</td></tr><tr><td>epoch/top-5-accuracy</td><td>▁▅▅█</td></tr><tr><td>epoch/val_accuracy</td><td>█▄▁█</td></tr><tr><td>epoch/val_f1_macro</td><td>█▅▁▆</td></tr><tr><td>epoch/val_f1_micro</td><td>█▄▁▇</td></tr><tr><td>epoch/val_loss</td><td>▁▄█▁</td></tr><tr><td>epoch/val_precision_macro</td><td>█▃▁█</td></tr><tr><td>epoch/val_precision_micro</td><td>█▄▁▇</td></tr><tr><td>epoch/val_recall_macro</td><td>█▅▁█</td></tr><tr><td>epoch/val_recall_micro</td><td>█▄▁▇</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁▃▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.22125</td></tr><tr><td>epoch/epoch</td><td>3</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>2.33983</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.67377</td></tr><tr><td>epoch/val_accuracy</td><td>0.34358</td></tr><tr><td>epoch/val_f1_macro</td><td>0.11244</td></tr><tr><td>epoch/val_f1_micro</td><td>0.29516</td></tr><tr><td>epoch/val_loss</td><td>2.03656</td></tr><tr><td>epoch/val_precision_macro</td><td>0.18611</td></tr><tr><td>epoch/val_precision_micro</td><td>0.29516</td></tr><tr><td>epoch/val_recall_macro</td><td>0.15127</td></tr><tr><td>epoch/val_recall_micro</td><td>0.29516</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.83426</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-sweep-4</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/3olxp1xy' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/3olxp1xy</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_002431-3olxp1xy/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vmsbu1d9 with config:
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	learning_rate: 1e-05
# wandb: 	patch_size: 24
# wandb: 	projection_dim: 32
# wandb: 	seed: 4
# wandb: 	transfomers_layers: 8
# wandb: 	weight_decay: 0.0001
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_002607-vmsbu1d9</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vmsbu1d9' target="_blank">fallen-sweep-5</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vmsbu1d9' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vmsbu1d9</a>
# Epoch 1/30
# 134/135 [============================>.] - ETA: 0s - loss: 3.7668 - accuracy: 0.1328 - top-5-accuracy: 0.4443 - val_f1_macro: 0.13920263459184223 - val_f1_micro: 0.35986964618249534
#        - val_precision_macro: 0.16535380715825204 - val_precision_micro: 0.35986964618249534 - val_recall_macro: 0.17906250645402486 - val_recall_micro: 0.35986964618249534
# 135/135 [==============================] - 22s 80ms/step - loss: 3.7666 - accuracy: 0.1328 - top-5-accuracy: 0.4441 - val_loss: 1.9655 - val_accuracy: 0.3841 - val_top-5-accuracy: 0.8333
# Epoch 2/30
# 135/135 [==============================] - ETA: 0s - loss: 2.8090 - accuracy: 0.2486 - top-5-accuracy: 0.6562 - val_f1_macro: 0.16452757077421537 - val_f1_micro: 0.3952513966480447
#        - val_precision_macro: 0.19744184147235788 - val_precision_micro: 0.3952513966480447 - val_recall_macro: 0.2004588146337735 - val_recall_micro: 0.3952513966480447
# 135/135 [==============================] - 8s 58ms/step - loss: 2.8090 - accuracy: 0.2486 - top-5-accuracy: 0.6562 - val_loss: 1.6984 - val_accuracy: 0.4381 - val_top-5-accuracy: 0.8887
# Epoch 3/30
# 135/135 [==============================] - ETA: 0s - loss: 2.4322 - accuracy: 0.3013 - top-5-accuracy: 0.7412 - val_f1_macro: 0.19547466123718102 - val_f1_micro: 0.45251396648044695
#        - val_precision_macro: 0.2699983939005289 - val_precision_micro: 0.45251396648044695 - val_recall_macro: 0.22978269162603732 - val_recall_micro: 0.45251396648044695
# 135/135 [==============================] - 8s 59ms/step - loss: 2.4322 - accuracy: 0.3013 - top-5-accuracy: 0.7412 - val_loss: 1.5768 - val_accuracy: 0.4614 - val_top-5-accuracy: 0.9097
# Epoch 4/30
td></tr><tr><td>epoch/val_precision_micro</td><td>▁▄▆▇█▇██</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▃▅▆▇█▇█</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▄▆▇█▇██</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁▄▆▇███▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.58147</td></tr><tr><td>epoch/epoch</td><td>7</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.21906</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.95077</td></tr><tr><td>epoch/val_accuracy</td><td>0.58613</td></tr><tr><td>epoch/val_f1_macro</td><td>0.329</td></tr><tr><td>epoch/val_f1_micro</td><td>0.57728</td></tr><tr><td>epoch/val_loss</td><td>1.11476</td></tr><tr><td>epoch/val_precision_macro</td><td>0.36345</td></tr><tr><td>epoch/val_precision_micro</td><td>0.57728</td></tr><tr><td>epoch/val_recall_macro</td><td>0.35023</td></tr><tr><td>epoch/val_recall_micro</td><td>0.57728</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.95996</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polar-sweep-80</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/hzl6xqdk' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/hzl6xqdk</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_032718-hzl6xqdk/logs</code>
# wandb: Agent Starting Run: yzx9nedw with config:
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.01
# wandb: 	patch_size: 16
# wandb: 	projection_dim: 16
# wandb: 	seed: 3
# wandb: 	transfomers_layers: 4
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_032800-yzx9nedw</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/yzx9nedw' target="_blank">wild-sweep-81</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/yzx9nedw' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/yzx9nedw</a>
# Epoch 1/30
# 135/135 [==============================] - ETA: 0s - loss: 4.2556 - accuracy: 0.3040 - top-5-accuracy: 0.7315 - val_f1_macro: 0.18722220049713154 - val_f1_micro: 0.41061452513966484
#        - val_precision_macro: 0.2476572578268659 - val_precision_micro: 0.4106145251396648 - val_recall_macro: 0.21099756317927676 - val_recall_micro: 0.4106145251396648
# 135/135 [==============================] - 12s 53ms/step - loss: 4.2556 - accuracy: 0.3040 - top-5-accuracy: 0.7315 - val_loss: 1.6086 - val_accuracy: 0.4320 - val_top-5-accuracy: 0.9101
# Epoch 2/30
# 135/135 [==============================] - ETA: 0s - loss: 1.7150 - accuracy: 0.4504 - top-5-accuracy: 0.8868 - val_f1_macro: 0.21297702517975237 - val_f1_micro: 0.4594972067039106
#        - val_precision_macro: 0.23287741778698792 - val_precision_micro: 0.4594972067039106 - val_recall_macro: 0.24600843735184694 - val_recall_micro: 0.4594972067039106
# 135/135 [==============================] - 5s 39ms/step - loss: 1.7150 - accuracy: 0.4504 - top-5-accuracy: 0.8868 - val_loss: 1.4562 - val_accuracy: 0.4651 - val_top-5-accuracy: 0.9195
# Epoch 3/30
# 135/135 [==============================] - ETA: 0s - loss: 1.5680 - accuracy: 0.4789 - top-5-accuracy: 0.9074 - val_f1_macro: 0.24341696639083582 - val_f1_micro: 0.5181564245810056
#        - val_precision_macro: 0.27602481899330145 - val_precision_micro: 0.5181564245810056 - val_recall_macro: 0.2803236348252346 - val_recall_micro: 0.5181564245810056
# 135/135 [==============================] - 5s 39ms/step - loss: 1.5680 - accuracy: 0.4789 - top-5-accuracy: 0.9074 - val_loss: 1.3218 - val_accuracy: 0.5535 - val_top-5-accuracy: 0.9344
# Epoch 4/30
# 135/135 [==============================] - ETA: 0s - loss: 1.4936 - accuracy: 0.4992 - top-5-accuracy: 0.9200 - val_f1_macro: 0.26668441390134845 - val_f1_micro: 0.5186219739292365
#        - val_precision_macro: 0.28352012031228285 - val_precision_micro: 0.5186219739292365 - val_recall_macro: 0.2871570326667049 - val_recall_micro: 0.5186219739292365
# 135/135 [==============================] - 5s 40ms/step - loss: 1.4936 - accuracy: 0.4992 - top-5-accuracy: 0.9200 - val_loss: 1.2987 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.9372
# Epoch 5/30
# 135/135 [==============================] - ETA: 0s - loss: 1.4644 - accuracy: 0.5070 - top-5-accuracy: 0.9250 - val_f1_macro: 0.25076534926451033 - val_f1_micro: 0.5121042830540037
#        - val_precision_macro: 0.3020732921521715 - val_precision_micro: 0.5121042830540037 - val_recall_macro: 0.2786209172823173 - val_recall_micro: 0.5121042830540037
# 135/135 [==============================] - 5s 39ms/step - loss: 1.4644 - accuracy: 0.5070 - top-5-accuracy: 0.9250 - val_loss: 1.3790 - val_accuracy: 0.5284 - val_top-5-accuracy: 0.9437
# Epoch 6/30
# 135/135 [==============================] - ETA: 0s - loss: 1.4737 - accuracy: 0.5023 - top-5-accuracy: 0.9205 - val_f1_macro: 0.2344376920740773 - val_f1_micro: 0.50512104283054
#        - val_precision_macro: 0.2801328755711455 - val_precision_micro: 0.50512104283054 - val_recall_macro: 0.289656551995872 - val_recall_micro: 0.50512104283054
# 135/135 [==============================] - 5s 39ms/step - loss: 1.4737 - accuracy: 0.5023 - top-5-accuracy: 0.9205 - val_loss: 1.3740 - val_accuracy: 0.5307 - val_top-5-accuracy: 0.9255
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▆▇███</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▄▄▄▄▄▄▅▅▅▅▅▅▅▇▇▇▇▇▇▇██████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▂▁▁▁▁</td></tr><tr><td>epoch/top-5-accuracy</td><td>▁▇▇███</td></tr><tr><td>epoch/val_accuracy</td><td>▁▃█▇▇▇</td></tr><tr><td>epoch/val_f1_macro</td><td>▁▃▆█▇▅</td></tr><tr><td>epoch/val_f1_micro</td><td>▁▄███▇</td></tr><tr><td>epoch/val_loss</td><td>█▅▂▁▃▃</td></tr><tr><td>epoch/val_precision_macro</td><td>▂▁▅▆█▆</td></tr><tr><td>epoch/val_precision_micro</td><td>▁▄███▇</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▄▇█▇█</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▄███▇</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁▃▆▇█▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.50233</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.47371</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.92051</td></tr><tr><td>epoch/val_accuracy</td><td>0.53073</td></tr><tr><td>epoch/val_f1_macro</td><td>0.23444</td></tr><tr><td>epoch/val_f1_micro</td><td>0.50512</td></tr><tr><td>epoch/val_loss</td><td>1.374</td></tr><tr><td>epoch/val_precision_macro</td><td>0.28013</td></tr><tr><td>epoch/val_precision_micro</td><td>0.50512</td></tr><tr><td>epoch/val_recall_macro</td><td>0.28966</td></tr><tr><td>epoch/val_recall_micro</td><td>0.50512</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.92551</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wild-sweep-81</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/yzx9nedw' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/yzx9nedw</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_032800-yzx9nedw/logs</code>
# wandb: Agent Starting Run: oqx89sk0 with config:
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.0001
# wandb: 	patch_size: 20
# wandb: 	projection_dim: 128
# wandb: 	seed: 4
# wandb: 	transfomers_layers: 12
# wandb: 	weight_decay: 0.01
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_032852-oqx89sk0</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/oqx89sk0' target="_blank">icy-sweep-82</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/oqx89sk0' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/oqx89sk0</a>
# Epoch 1/30
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
#  View run <strong style="color:#cdcd00">icy-sweep-82</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/oqx89sk0' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/oqx89sk0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_032852-oqx89sk0/logs</code>
# Run oqx89sk0 errored: ResourceExhaustedError()
# wandb: ERROR Run oqx89sk0 errored: ResourceExhaustedError()
# wandb: Agent Starting Run: 32bp7sef with config:
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.0001
# wandb: 	patch_size: 16
# wandb: 	projection_dim: 64
# wandb: 	seed: 3
# wandb: 	transfomers_layers: 12
# wandb: 	weight_decay: 0.001
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_032929-32bp7sef</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/32bp7sef' target="_blank">distinctive-sweep-83</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/32bp7sef' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/32bp7sef</a>
# Epoch 1/30
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
#  View run <strong style="color:#cdcd00">distinctive-sweep-83</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/32bp7sef' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/32bp7sef</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230214_032929-32bp7sef/logs</code>
# Run 32bp7sef errored: ResourceExhaustedError()
# wandb: ERROR Run 32bp7sef errored: ResourceExhaustedError()
# wandb: Agent Starting Run: vakk5fsh with config:
# wandb: 	batch_size: 256
# wandb: 	epochs: 30
# wandb: 	learning_rate: 0.0001
# wandb: 	patch_size: 16
# wandb: 	projection_dim: 32
# wandb: 	seed: 3
# wandb: 	transfomers_layers: 8
# wandb: 	weight_decay: 0.0001
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230214_033016-vakk5fsh</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vakk5fsh' target="_blank">dulcet-sweep-84</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1</a>
#  View sweep at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/sweeps/yq5f6lll</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vakk5fsh' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-optimization-models-f1/runs/vakk5fsh</a>

# %%
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# GPU is available

# %% [markdown]
# # Performing the cross-validation using the official 2-fold

# %%
# !pip install wandb
# !wandb login
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.10-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.8 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (8.1.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.25.1)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=0f4a7ac2686e84d5960fba1046ded665a8e79210d29342c9f14de87742258636
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.16.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.10
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb
from wandb.keras import WandbCallback

# %% [markdown]
# ## Models to test

# %%
models = [
    {
        "name": "devoted-sweep-75",
        "batch_size": 256,
        "learning_rate": 0.001,
        "patch_size": 20,
        "projection_dim": 128,
        "seed": 3,
        "transformers_layers": 8,
        "weight_decay": 0.0001
    },
    {
        "name": "devoted-sweep-6",
        "batch_size": 32,
        "learning_rate": 0.0001,
        "patch_size": 20,
        "projection_dim": 32,
        "seed": 5,
        "transformers_layers": 4,
        "weight_decay": 0.00001
    },
    {
        "name": "earnest-sweep-25",
        "batch_size": 256,
        "learning_rate": 0.001,
        "patch_size": 20,
        "projection_dim": 64,
        "seed": 4,
        "transformers_layers": 12,
        "weight_decay": 0.00001
    },
    {
        "name": "swift-sweep-9",
        "batch_size": 256,
        "learning_rate": 0.001,
        "patch_size": 20,
        "projection_dim": 16,
        "seed": 1,
        "transformers_layers": 12,
        "weight_decay": 0.00001
    },
    {
        "name": "vocal-sweep-74",
        "batch_size": 64,
        "learning_rate": 0.0001,
        "patch_size": 20,
        "projection_dim": 16,
        "seed": 1,
        "transformers_layers": 4,
        "weight_decay": 0.00001
    },
    {
        "name": "eager-sweep-40",
        "batch_size": 64,
        "learning_rate": 0.0001,
        "patch_size": 16,
        "projection_dim": 16,
        "seed": 1,
        "transformers_layers": 12,
        "weight_decay": 0.0001
    },
]

# %%
num_epochs = 1000
patience = 10
monitor = "val_loss"

# %%
num_classes = 23
input_shape = (224, 224, 3)

def get_vit_classifier(seed: float, patch_size: int, projection_dim: int, transformers_layer: int,
                            learning_rate: float, weight_decay: float):

    # Five steps approach to select a initial seed
    import numpy.random
    np.random.seed(seed)

    import tensorflow as tf
    tf.random.set_seed(seed)

    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    num_patches = (image_size // patch_size) ** 2
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    transformer_units = [
      projection_dim * 2,
      projection_dim,
    ]

    # Create multiple layers of the Transformer block.
    for _ in range(transformers_layer):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)

    # Compiling the final  model 
    optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

    return model

# %%
for model_dict in models:
  macro_f1_scores_per_fold = []
  micro_f1_scores_per_fold = []
  macro_precision_scores_per_fold = []
  micro_precision_scores_per_fold = []
  macro_recall_scores_per_fold = []
  micro_recall_scores_per_fold = []

  print('------------------------------------------------------------------------')
  print(f'Model: {model_dict["name"]}')

  for index_i, k_fold_i in enumerate(k_folds):
    X_test, y_test = k_fold_i

    for index_j, k_fold_j in enumerate(k_folds): 
      if index_i == index_j: continue

      X_train, y_train = k_fold_j

    print('------------------------------------------------------------------------')
    print(f'Training for fold {index_i + 1} ...')

    config = {
      "architecture": model_dict["name"],
      "num_epochs": num_epochs, 
      "learning_rate": model_dict["learning_rate"], 
      "batch_size": model_dict["batch_size"],
      "seed": model_dict["seed"],
      "patch_size": model_dict["patch_size"],
      "projection_dim": model_dict["projection_dim"],
      "transformers_layer": model_dict["transformers_layers"],
      "weight_decay": model_dict["weight_decay"],
      "batch_size": model_dict["batch_size"],
      "monitor": monitor,
      "patience": patience,
      "dataset": f"Split {index_i}"
    }
    wandb.init(project="hyper-kvasir-official-split", entity="ava-research-hyper-kvasir", config=config)

    # Data augmentation
    image_size = 224

    data_augmentation = keras.Sequential(
        [
            keras.layers.Normalization(),
            keras.layers.Resizing(image_size, image_size),
            keras.layers.RandomFlip("horizontal"),
            keras.layers.RandomRotation(factor=0.02),
            keras.layers.RandomZoom(
                height_factor=0.2, width_factor=0.2
            ),
        ],
        name="data_augmentation",
    )

    # Compute the mean and the variance of the training data for normalization.
    data_augmentation.layers[0].adapt(X_train)

    from sklearn.metrics import f1_score, precision_score, recall_score

    class MetricsCallback(keras.callbacks.Callback):
        def __init__(self):
            super(MetricsCallback, self).__init__()

        def  on_train_begin(self,logs={}):
          self.f1_macro = []
          self.f1_micro = []
          self.precision_macro = []
          self.precision_micro = []
          self.recall_macro = []
          self.recall_micro = []

        def on_epoch_end(self, epoch, logs=None):
          y_pred = self.model.predict(X_test).round().argmax(axis=1)
          y_true = y_test

          score_f1_macro = f1_score(y_true, y_pred, average='macro')
          score_f1_micro = f1_score(y_true, y_pred, average='micro')
          score_precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
          score_precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
          score_recall_macro = recall_score(y_true, y_pred, average='macro')
          score_recall_micro = recall_score(y_true, y_pred, average='micro')

          self.f1_macro.append(score_f1_macro)
          self.f1_micro.append(score_f1_micro)
          self.precision_macro.append(score_precision_macro)
          self.precision_micro.append(score_precision_micro)
          self.recall_macro.append(score_recall_macro)
          self.recall_micro.append(score_recall_micro)

          best_f1_score_macro = max(self.f1_macro)
          best_f1_score_macro_epoch = self.f1_macro.index(best_f1_score_macro)

          best_f1_score_micro = max(self.f1_micro)
          best_f1_score_micro_epoch = self.f1_micro.index(best_f1_score_micro)

          # We have to calculate the F1 score at the end of every epoch, because
          # tensorflow works by batches for another metrics computing, so it's
          # required to create a custom callback to perform F1 score

          print(f""" - val_f1_macro: {score_f1_macro} - val_f1_micro: {score_f1_micro}
          - val_precision_macro: {score_precision_macro} - val_precision_micro: {score_precision_micro} - val_recall_macro: {score_recall_macro} - val_recall_micro: {score_recall_micro}
          - val_best_f1_score_macro: {best_f1_score_macro} (epoch: {best_f1_score_macro_epoch}) - val_best_f1_score_micro: {best_f1_score_micro} (epoch: {best_f1_score_micro})""")

          wandb.log({'epoch/val_f1_macro': score_f1_macro}, commit=True)
          wandb.log({'epoch/val_f1_micro': score_f1_micro}, commit=True)
          wandb.log({'epoch/val_precision_macro': score_precision_macro}, commit=True)
          wandb.log({'epoch/val_precision_micro': score_precision_micro}, commit=True)
          wandb.log({'epoch/val_recall_macro': score_recall_macro}, commit=True)
          wandb.log({'epoch/val_recall_micro': score_recall_micro}, commit=True)
          wandb.log({'best_f1_score_macro': best_f1_score_macro}, commit=True)
          wandb.log({'best_f1_score_micro': best_f1_score_micro}, commit=True)

    metrics = MetricsCallback()

    model = get_vit_classifier(seed=model_dict["seed"], patch_size=model_dict["patch_size"], projection_dim=model_dict["projection_dim"], transformers_layer=model_dict["transformers_layers"], 
                              learning_rate=model_dict["learning_rate"], weight_decay=model_dict["weight_decay"])
    
    early_stopper = tf.keras.callbacks.EarlyStopping(monitor=monitor, 
                                                 patience=patience, 
                                                 restore_best_weights=True)

    history = model.fit(
        x=X_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(X_test, y_test), 
        callbacks=[metrics, early_stopper], # Add WandbCallback() to create artifacts
    )

    y_pred = model.predict(X_test).round().argmax(axis=1)
    y_true = y_test
    macro_f1_scores_per_fold.append(f1_score(y_true, y_pred, average='macro'))
    micro_f1_scores_per_fold.append(f1_score(y_true, y_pred, average='micro'))
    macro_precision_scores_per_fold.append(precision_score(y_true, y_pred, average='macro', zero_division=0))
    micro_precision_scores_per_fold.append(precision_score(y_true, y_pred, average='micro', zero_division=0))
    macro_recall_scores_per_fold.append(recall_score(y_true, y_pred, average='macro'))
    micro_recall_scores_per_fold.append(recall_score(y_true, y_pred, average='micro'))

    wandb.run.finish()

  # Deleting the final splits
  del X_test, y_test, X_train, y_train

  config = {
      "architecture": model_dict["name"],
      "num_epochs": num_epochs, 
      "learning_rate": model_dict["learning_rate"], 
      "batch_size": model_dict["batch_size"],
      "seed": model_dict["seed"],
      "patch_size": model_dict["patch_size"],
      "projection_dim": model_dict["projection_dim"],
      "transformers_layer": model_dict["transformers_layers"],
      "weight_decay": model_dict["weight_decay"],
      "batch_size": model_dict["batch_size"],
      "monitor": monitor,
      "patience": patience,
      "dataset": "Final average splits"
  }
  wandb.init(project="hyper-kvasir-official-split", entity="ava-research-hyper-kvasir", config=config)

  wandb.log({'final/avg_f1_macro': sum(macro_f1_scores_per_fold) / len(macro_f1_scores_per_fold)}, commit=True)
  wandb.log({'final/avg_f1_micro': sum(micro_f1_scores_per_fold) / len(micro_f1_scores_per_fold)}, commit=True)
  wandb.log({'final/avg_precision_macro': sum(macro_precision_scores_per_fold) / len(macro_precision_scores_per_fold)}, commit=True)
  wandb.log({'final/avg_precision_micro': sum(micro_precision_scores_per_fold) / len(micro_precision_scores_per_fold)}, commit=True)
  wandb.log({'final/avg_recall_macro': sum(macro_recall_scores_per_fold) / len(macro_recall_scores_per_fold)}, commit=True)
  wandb.log({'final/avg_recall_micro': sum(micro_recall_scores_per_fold) / len(micro_recall_scores_per_fold)}, commit=True)

  wandb.run.finish()
# Out:
# ------------------------------------------------------------------------
# Model: devoted-sweep-75
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Finishing last run (ID:lsv9yb41) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
#  View run <strong style="color:#cdcd00">solar-haze-18</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsv9yb41' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsv9yb41</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230307_210126-lsv9yb41/logs</code>
# Successfully finished last run (ID:lsv9yb41). Initializing new run:<br/>
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230307_210238-hwotl8oc</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/hwotl8oc' target="_blank">dulcet-wood-19</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/hwotl8oc' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/hwotl8oc</a>
# Epoch 1/1000
# 21/21 [==============================] - ETA: 0s - loss: 3.9953 - accuracy: 0.2939 - top-5-accuracy: 0.6840 - val_f1_macro: 0.24581633627663438 - val_f1_micro: 0.49441340782122906
#           - val_precision_macro: 0.2867124426823727 - val_precision_micro: 0.49441340782122906 - val_recall_macro: 0.2599344432364511 - val_recall_micro: 0.49441340782122906
#           - val_best_f1_score_macro: 0.24581633627663438 (epoch: 0) - val_best_f1_score_micro: 0.49441340782122906 (epoch: 0.49441340782122906)
# 21/21 [==============================] - 21s 541ms/step - loss: 3.9953 - accuracy: 0.2939 - top-5-accuracy: 0.6840 - val_loss: 1.6215 - val_accuracy: 0.5261 - val_top-5-accuracy: 0.9132
# Epoch 2/1000
# 21/21 [==============================] - ETA: 0s - loss: 1.8451 - accuracy: 0.4438 - top-5-accuracy: 0.8654 - val_f1_macro: 0.2832499356685753 - val_f1_micro: 0.574487895716946
#           - val_precision_macro: 0.300649354197817 - val_precision_micro: 0.574487895716946 - val_recall_macro: 0.2982631330841911 - val_recall_micro: 0.574487895716946
#           - val_best_f1_score_macro: 0.2832499356685753 (epoch: 1) - val_best_f1_score_micro: 0.574487895716946 (epoch: 0.574487895716946)
# 21/21 [==============================] - 7s 353ms/step - loss: 1.8451 - accuracy: 0.4438 - top-5-accuracy: 0.8654 - val_loss: 1.2928 - val_accuracy: 0.5955 - val_top-5-accuracy: 0.9453
# Epoch 3/1000
# 21/21 [==============================] - ETA: 0s - loss: 1
td></tr><tr><td>epoch/val_precision_micro</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█▇▇████████████████</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▂▄▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇█▇▇██▇█████████████</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█▇▇████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_f1_score_macro</td><td>0.48073</td></tr><tr><td>best_f1_score_micro</td><td>0.77542</td></tr><tr><td>epoch/val_f1_macro</td><td>0.47625</td></tr><tr><td>epoch/val_f1_micro</td><td>0.76425</td></tr><tr><td>epoch/val_precision_macro</td><td>0.52354</td></tr><tr><td>epoch/val_precision_micro</td><td>0.76425</td></tr><tr><td>epoch/val_recall_macro</td><td>0.47032</td></tr><tr><td>epoch/val_recall_micro</td><td>0.76425</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-shape-35</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/65i305k0' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/65i305k0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230307_223830-65i305k0/logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669274900020053, max=1.0…
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230307_225710-lsrm2667</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsrm2667' target="_blank">rich-energy-36</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsrm2667' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsrm2667</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>final/avg_f1_macro</td><td>▁</td></tr><tr><td>final/avg_f1_micro</td><td>▁</td></tr><tr><td>final/avg_precision_macro</td><td>▁</td></tr><tr><td>final/avg_precision_micro</td><td>▁</td></tr><tr><td>final/avg_recall_macro</td><td>▁</td></tr><tr><td>final/avg_recall_micro</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>final/avg_f1_macro</td><td>0.46797</td></tr><tr><td>final/avg_f1_micro</td><td>0.76425</td></tr><tr><td>final/avg_precision_macro</td><td>0.48443</td></tr><tr><td>final/avg_precision_micro</td><td>0.76425</td></tr><tr><td>final/avg_recall_macro</td><td>0.46612</td></tr><tr><td>final/avg_recall_micro</td><td>0.76425</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-energy-36</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsrm2667' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/lsrm2667</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230307_225710-lsrm2667/logs</code>

# %%
wandb.init(project="hyper-kvasir-official-split", entity="ava-research-hyper-kvasir", notes="Final average splits")

wandb.log({'final/avg_f1_macro': sum(macro_f1_scores_per_fold) / len(macro_f1_scores_per_fold)}, commit=True)
wandb.log({'final/avg_f1_micro': sum(micro_f1_scores_per_fold) / len(micro_f1_scores_per_fold)}, commit=True)
wandb.log({'final/avg_precision_macro': sum(macro_precision_scores_per_fold) / len(macro_precision_scores_per_fold)}, commit=True)
wandb.log({'final/avg_precision_micro': sum(micro_precision_scores_per_fold) / len(micro_precision_scores_per_fold)}, commit=True)
wandb.log({'final/avg_recall_macro': sum(macro_recall_scores_per_fold) / len(macro_recall_scores_per_fold)}, commit=True)
wandb.log({'final/avg_recall_micro': sum(micro_recall_scores_per_fold) / len(micro_recall_scores_per_fold)}, commit=True)

wandb.run.finish()
# Out:
# Finishing last run (ID:oapr5sej) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_f1_score_macro</td><td>▁▅▇▇▇▇██████████████████████████████████</td></tr><tr><td>best_f1_score_micro</td><td>▁▅▇▇████████████████████████████████████</td></tr><tr><td>epoch/val_f1_macro</td><td>▁▄▇▇▇▇██▇█▇█▇██▇██▇███▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch/val_f1_micro</td><td>▁▄▇█████▇███▇██▇██▇███▇▇████▇▇█▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch/val_precision_macro</td><td>▁▄▅▅▅▅▆▆▇▅▅▆▆▅▅▅▅▆▅▅▅▆▅▅▅▅▅█▄▅▅▆▄▅▅▄▆▅▄▄</td></tr><tr><td>epoch/val_precision_micro</td><td>▁▄▇█████▇███▇██▇██▇███▇▇████▇▇█▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch/val_recall_macro</td><td>▁▃▇▇▇▇██▇█▇█▇███▇█▇███▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>epoch/val_recall_micro</td><td>▁▄▇█████▇███▇██▇██▇███▇▇████▇▇█▇▇▇▇▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_f1_score_macro</td><td>0.50381</td></tr><tr><td>best_f1_score_micro</td><td>0.78417</td></tr><tr><td>epoch/val_f1_macro</td><td>0.47723</td></tr><tr><td>epoch/val_f1_micro</td><td>0.76425</td></tr><tr><td>epoch/val_precision_macro</td><td>0.48562</td></tr><tr><td>epoch/val_precision_micro</td><td>0.76425</td></tr><tr><td>epoch/val_recall_macro</td><td>0.47572</td></tr><tr><td>epoch/val_recall_micro</td><td>0.76425</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">clean-violet-9</strong> at: <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/oapr5sej' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/oapr5sej</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230306_175023-oapr5sej/logs</code>
# Successfully finished last run (ID:oapr5sej). Initializing new run:<br/>
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230306_184256-p1ghim8i</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/p1ghim8i' target="_blank">wild-pyramid-10</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/p1ghim8i' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/hyper-kvasir-official-split/runs/p1ghim8i</a>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-24-614d2648b3a4> in <module>
#       1 wandb.init(project="hyper-kvasir-official-split", entity="ava-research-hyper-kvasir", notes="Final average splits")
#       2
# ----> 3 wandb.log({'final/avg_f1_macro': sum(macro_f1_scores_per_fold) / len(macro_f1_scores_per_fold)}, commit=True)
#       4 wandb.log({'final/avg_f1_micro': sum(micro_f1_scores_per_fold) / len(micro_f1_scores_per_fold)}, commit=True)
#       5 wandb.log({'final/avg_precision_macro': sum(macro_precision_scores_per_fold) / len(macro_precision_scores_per_fold)}, commit=True)
#
# ZeroDivisionError: division by zero

# %%
with open(f'gdrive/MyDrive/Universidad/TFG/trainings/logs/{history_name}', "rb") as file_pi:
    history = pickle.load(file_pi)

# summarize history for accuracy
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import wandb

run = wandb.init()
artifact = run.use_artifact('ava-research-hyper-kvasir/hyper-kvasir/model-warm-frog-3:v21', type='model')
artifact_dir = artifact.download()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: richardesp (ava-research-hyper-kvasir). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>/content/wandb/run-20230207_184124-c751xbja</code>
# Syncing run <strong><a href='https://wandb.ai/ava-research-hyper-kvasir/uncategorized/runs/c751xbja' target="_blank">cerulean-deluge-2</a></strong> to <a href='https://wandb.ai/ava-research-hyper-kvasir/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ava-research-hyper-kvasir/uncategorized' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/uncategorized</a>
#  View run at <a href='https://wandb.ai/ava-research-hyper-kvasir/uncategorized/runs/c751xbja' target="_blank">https://wandb.ai/ava-research-hyper-kvasir/uncategorized/runs/c751xbja</a>
# wandb: Downloading large artifact model-warm-frog-3:v21, 521.54MB. 4 files...
# wandb:   4 of 4 files downloaded.
# Done. 0:0:4.9

# %%
model = keras.models.load_model('artifacts/model-warm-frog-3:v21')

# %%
model.evaluate(X_test, y_test)
# Out:
# 68/68 [==============================] - 6s 21ms/step - loss: 0.5700 - accuracy: 0.7905 - top-5-accuracy: 0.9874
# [0.5700362920761108, 0.7905027866363525, 0.9874301552772522]
