# %%
# !pip install -U keras-cv-attention-models # Library to use the pre-trained models
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-cv-attention-models
#   Downloading keras_cv_attention_models-1.3.11-py3-none-any.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.4/613.4 KB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.9/dist-packages (from keras-cv-attention-models) (4.8.3)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (from keras-cv-attention-models) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (3.1.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.51.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (23.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (3.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (2.11.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.22.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (3.19.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (23.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (15.0.6.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow->keras-cv-attention-models) (4.5.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (8.1.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (5.4.8)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (1.0.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (1.12.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (0.10.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (2.3)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (0.1.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (4.65.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->keras-cv-attention-models) (2.25.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow->keras-cv-attention-models) (0.38.4)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.9/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras-cv-attention-models) (5.12.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.9/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras-cv-attention-models) (3.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->tensorflow-datasets->keras-cv-attention-models) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->tensorflow-datasets->keras-cv-attention-models) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->tensorflow-datasets->keras-cv-attention-models) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->tensorflow-datasets->keras-cv-attention-models) (2022.12.7)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (2.16.2)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv-attention-models) (1.58.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->keras-cv-attention-models) (3.2.2)
# Installing collected packages: typeguard, tensorflow-addons, keras-cv-attention-models
# Successfully installed keras-cv-attention-models-1.3.11 tensorflow-addons-0.19.0 typeguard-2.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.9/dist-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar 13 11:06:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    56W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # Preparing the data

# %%
import os
import numpy as np
import pandas as pd
import cv2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
dataset_dir = "gdrive/MyDrive/hyper-kvasir-dataset-final"

# %%
def get_dataCategories(dataset_dir):
    import glob

    categories = []
    for folder_name in os.listdir(dataset_dir):
        if os.path.isdir(os.path.join(dataset_dir, folder_name)):
            nbr_files = len(
                glob.glob(os.path.join(dataset_dir, folder_name) + "/*.jpg")
            )
            categories.append(np.array([folder_name, nbr_files]))

    categories.sort(key=lambda a: a[0])
    cat = np.array(categories)

    return list(cat[:, 0]), list(cat[:, 1])

categories, nbr_files = get_dataCategories(dataset_dir)

# Create DataFrame
df = pd.DataFrame({"categorie": categories, "numbre of files": nbr_files})
print("number of categories: ", len(categories))
df
# Out:
# number of categories:  23
#                        categorie numbre of files
# 0                       barretts              41
# 1         barretts-short-segment              53
# 2                       bbps-0-1             646
# 3                       bbps-2-3            1158
# 4                          cecum            1027
# 5             dyed-lifted-polyps            1002
# 6         dyed-resection-margins             989
# 7                  esophagitis-a             413
# 8                esophagitis-b-d             260
# 9                    hemorrhoids               6
# 10                         ileum               9
# 11                impacted-stool             131
# 12                        polyps            1028
# 13                       pylorus            1029
# 14              retroflex-rectum             391
# 15             retroflex-stomach             774
# 16  ulcerative-colitis-grade-0-1              35
# 17    ulcerative-colitis-grade-1             201
# 18  ulcerative-colitis-grade-1-2              11
# 19    ulcerative-colitis-grade-2             443
# 20  ulcerative-colitis-grade-2-3              28
# 21    ulcerative-colitis-grade-3             133
# 22                        z-line             932

# %%
def get_x_y(datadir, categories, img_wid, img_high):
    X, y = [], []
    for category in categories:
        path = os.path.join(datadir, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
                ima_resize_rgb = cv2.resize(img_array, (img_wid, img_high))

                X.append(ima_resize_rgb)
                y.append(class_num)

            except Exception as e:
                print(e)

    y = np.array(y)
    X = np.array(X)

    # reshape X into img_wid x img_high x 3
    X = X.reshape(X.shape[0], img_wid, img_high, 3)

    return X, y


img_wid, img_high = 224, 224
X, y = get_x_y(dataset_dir, categories, img_wid, img_high)

print(f"X: {X.shape}")
print(f"y: {y.shape}")
# Out:
# X: (10740, 224, 224, 3)
# y: (10740,)

# %% [markdown]
# ## Split the data into train and test

# %%
from sklearn.model_selection import train_test_split

Y = np.reshape(y, (len(y), 1))


X_train, X_test, y_train, y_test = train_test_split(
    X, Y, train_size=0.5, random_state=42, stratify=Y
)

print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (5370, 224, 224, 3)
# y_train: (5370, 1)
# X_test: (5370, 224, 224, 3)
# y_test: (5370, 1)

# %% [markdown]
# # Preparing the pre-trained model
#
# [Pre-trained models repository](https://github.com/leondgarse/keras_cv_attention_models)

# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import sklearn

# %% [markdown]
# ## MobileVit model

# %%
from keras_cv_attention_models import mobilevit

# %%
model_1 = mobilevit.MobileViT_XS(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/mobilevit/mobilevit_xs_imagenet.h5
# 10087008/10087008 [==============================] - 0s 0us/step
# >>>> Load pretrained from: /root/.keras/models/mobilevit_xs_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #353 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (384, 23). Received saved weight with shape (384, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #353 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)

# %% [markdown]
# ## BotNet model

# %%
from keras_cv_attention_models import botnet

# %%
model_2 = botnet.BotNetSE33T(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# WARNING:tensorflow:Skipping loading weights for layer #96 (named stack2_block3_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack2_block3_deep_2_mhsa_pos_emb/r_height:0. Weight expects shape (32, 55). Received saved weight with shape (32, 63)
# WARNING:tensorflow:Skipping loading weights for layer #96 (named stack2_block3_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack2_block3_deep_2_mhsa_pos_emb/r_width:0. Weight expects shape (32, 55). Received saved weight with shape (32, 63)
# WARNING:tensorflow:Skipping loading weights for layer #158 (named stack3_block3_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack3_block3_deep_2_mhsa_pos_emb/r_height:0. Weight expects shape (64, 27). Received saved weight with shape (64, 31)
# WARNING:tensorflow:Skipping loading weights for layer #158 (named stack3_block3_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack3_block3_deep_2_mhsa_pos_emb/r_width:0. Weight expects shape (64, 27). Received saved weight with shape (64, 31)
# WARNING:tensorflow:Skipping loading weights for layer #184 (named stack4_block1_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack4_block1_deep_2_mhsa_pos_emb/r_height:0. Weight expects shape (128, 27). Received saved weight with shape (128, 31)
# WARNING:tensorflow:Skipping loading weights for layer #184 (named stack4_block1_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack4_block1_deep_2_mhsa_pos_emb/r_width:0. Weight expects shape (128, 27). Received saved weight with shape (128, 31)
# WARNING:tensorflow:Skipping loading weights for layer #213 (named stack4_block2_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack4_block2_deep_2_mhsa_pos_emb/r_height:0. Weight expects shape (128, 13). Received saved weight with shape (128, 15)
# WARNING:tensorflow:Skipping loading weights for layer #213 (named stack4_block2_deep_2_mhsa_pos_emb) due to mismatch in shape for weight stack4_block2_deep_2_mhsa_pos_emb/r_width:0. Weight expects shape (128, 13). Received saved weight with shape (128, 15)
# WARNING:tensorflow:Skipping loading weights for layer #232 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1280, 23). Received saved weight with shape (1280, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #232 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)
# >>>> Load pretrained from: /root/.keras/models/botnet_se33t_256_imagenet.h5
# >>>> Reload mismatched weights: 256 -> (224, 224)
# >>>> Reload layer: stack2_block3_deep_2_mhsa_pos_emb
# >>>> Reload layer: stack3_block3_deep_2_mhsa_pos_emb
# >>>> Reload layer: stack4_block1_deep_2_mhsa_pos_emb
# >>>> Reload layer: stack4_block2_deep_2_mhsa_pos_emb

# %% [markdown]
# ## CMT model

# %%
from keras_cv_attention_models import cmt

# %%
model_3 = cmt.CMTTiny_torch(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/cmt/cmt_tiny_torch_160_imagenet.h5
# 39606832/39606832 [==============================] - 1s 0us/step
# WARNING:tensorflow:Skipping loading weights for layer #30 (named stack1_pos_emb) due to mismatch in shape for weight positional_embedding:0. Weight expects shape (1, 3136, 49). Received saved weight with shape (1, 1600, 25)
# >>>> Load pretrained from: /root/.keras/models/cmt_tiny_torch_160_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #103 (named stack2_pos_emb) due to mismatch in shape for weight positional_embedding:0. Weight expects shape (2, 784, 49). Received saved weight with shape (2, 400, 25)
# WARNING:tensorflow:Skipping loading weights for layer #176 (named stack3_pos_emb) due to mismatch in shape for weight positional_embedding:0. Weight expects shape (4, 196, 49). Received saved weight with shape (4, 100, 25)
# WARNING:tensorflow:Skipping loading weights for layer #527 (named stack4_pos_emb) due to mismatch in shape for weight positional_embedding:0. Weight expects shape (8, 49, 49). Received saved weight with shape (8, 25, 25)
# WARNING:tensorflow:Skipping loading weights for layer #585 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1280, 23). Received saved weight with shape (1280, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #585 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)
# >>>> Reload mismatched weights: 160 -> (224, 224)
# >>>> Reload layer: stack1_pos_emb
# >>>> Reload layer: stack2_pos_emb
# >>>> Reload layer: stack3_pos_emb
# >>>> Reload layer: stack4_pos_emb

# %% [markdown]
# ## CoAtNet model

# %%
from keras_cv_attention_models import coatnet

# %%
model_4 = coatnet.CoAtNet0(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/coatnet/coatnet0_224_imagenet.h5
# 93747824/93747824 [==============================] - 2s 0us/step
# >>>> Load pretrained from: /root/.keras/models/coatnet0_224_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #259 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (768, 23). Received saved weight with shape (768, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #259 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)

# %% [markdown]
# ## ConvNeXt model

# %%
from keras_cv_attention_models import convnext

# %%
model_5 = convnext.ConvNeXtLarge(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/convnext/convnext_large_224_imagenet.h5
# 791935624/791935624 [==============================] - 46s 0us/step
# >>>> Load pretrained from: /root/.keras/models/convnext_large_224_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #334 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1536, 23). Received saved weight with shape (1536, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #334 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)

# %% [markdown]
# ## DaViT model

# %%
from keras_cv_attention_models import davit

# %%
model_6 = davit.DaViT_B(input_shape=(224, 224, 3), num_classes=23, pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/davit/davit_b_imagenet.h5
# 353318056/353318056 [==============================] - 5s 0us/step
# >>>> Load pretrained from: /root/.keras/models/davit_b_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #780 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1024, 23). Received saved weight with shape (1024, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #780 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (23,). Received saved weight with shape (1000,)

# %% [markdown]
# # Custom metrics to add to the model

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

class MetricsCallback(keras.callbacks.Callback):
        def __init__(self):
            super(MetricsCallback, self).__init__()

        def  on_train_begin(self,logs={}):
          self.f1_macro = []
          self.f1_micro = []
          self.precision_macro = []
          self.precision_micro = []
          self.recall_macro = []
          self.recall_micro = []

        def on_epoch_end(self, epoch, logs=None):
          y_pred = self.model.predict(X_test).round().argmax(axis=1)
          y_true = y_test

          score_f1_macro = f1_score(y_true, y_pred, average='macro')
          score_f1_micro = f1_score(y_true, y_pred, average='micro')
          score_precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
          score_precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
          score_recall_macro = recall_score(y_true, y_pred, average='macro')
          score_recall_micro = recall_score(y_true, y_pred, average='micro')

          self.f1_macro.append(score_f1_macro)
          self.f1_micro.append(score_f1_micro)
          self.precision_macro.append(score_precision_macro)
          self.precision_micro.append(score_precision_micro)
          self.recall_macro.append(score_recall_macro)
          self.recall_micro.append(score_recall_micro)

          best_f1_score_macro = max(self.f1_macro)
          best_f1_score_macro_epoch = self.f1_macro.index(best_f1_score_macro)

          best_f1_score_micro = max(self.f1_micro)
          best_f1_score_micro_epoch = self.f1_micro.index(best_f1_score_micro)

          # We have to calculate the F1 score at the end of every epoch, because
          # tensorflow works by batches for another metrics computing, so it's
          # required to create a custom callback to perform F1 score

          print(f""" - val_f1_macro: {score_f1_macro} - val_f1_micro: {score_f1_micro}
          - val_precision_macro: {score_precision_macro} - val_precision_micro: {score_precision_micro} - val_recall_macro: {score_recall_macro} - val_recall_micro: {score_recall_micro}
          - val_best_f1_score_macro: {best_f1_score_macro} (epoch: {best_f1_score_macro_epoch}) - val_best_f1_score_micro: {best_f1_score_micro} (epoch: {best_f1_score_micro})""")

# %% [markdown]
# # Training

# %% [markdown]
# ## MobileVit

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_1.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_1.summary()
# Out:
# Model: "mobilevit_xs"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_pad (ZeroPadding2D)       (None, 226, 226, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 16  432         ['stem_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 16  64          ['stem_conv[0][0]']
#                                 )
#
#  stem_swish (Activation)        (None, 112, 112, 16  0           ['stem_bn[0][0]']
#                                 )
#
#  stack1_block1_deep_1_conv (Con  (None, 112, 112, 64  1024       ['stem_swish[0][0]']
#  v2D)                           )
#
#  stack1_block1_deep_1_bn (Batch  (None, 112, 112, 64  256        ['stack1_block1_deep_1_conv[0][0]
#  Normalization)                 )                                ']
#
#  stack1_block1_deep_1_swish (Ac  (None, 112, 112, 64  0          ['stack1_block1_deep_1_bn[0][0]']
#  tivation)                      )
#
#  stack1_block1_deep_2_pad (Zero  (None, 114, 114, 64  0          ['stack1_block1_deep_1_swish[0][0
#  Padding2D)                     )                                ]']
#
#  stack1_block1_deep_2_dw_conv (  (None, 112, 112, 64  576        ['stack1_block1_deep_2_pad[0][0]'
#  DepthwiseConv2D)               )                                ]
#
#  stack1_block1_deep_2_bn (Batch  (None, 112, 112, 64  256        ['stack1_block1_deep_2_dw_conv[0]
#  Normalization)                 )                                [0]']
#
#  stack1_block1_deep_2_swish (Ac  (None, 112, 112, 64  0          ['stack1_block1_deep_2_bn[0][0]']
#  tivation)                      )
#
#  stack1_block1_deep_3_conv (Con  (None, 112, 112, 32  2048       ['stack1_block1_deep_2_swish[0][0
#  v2D)                           )                                ]']
#
#  stack1_block1_deep_3_bn (Batch  (None, 112, 112, 32  128        ['stack1_block1_deep_3_conv[0][0]
#  Normalization)                 )                                ']
#
#  stack2_block1_deep_1_conv (Con  (None, 112, 112, 12  4096       ['stack1_block1_deep_3_bn[0][0]']
#  v2D)                           8)
#
#  stack2_block1_deep_1_bn (Batch  (None, 112, 112, 12  512        ['stack2_block1_deep_1_conv[0][0]
#  Normalization)                 8)                               ']
#
#  stack2_block1_deep_1_swish (Ac  (None, 112, 112, 12  0          ['stack2_block1_deep_1_bn[0][0]']
#  tivation)                      8)
#
#  stack2_block1_deep_2_pad (Zero  (None, 114, 114, 12  0          ['stack2_block1_deep_1_swish[0][0
#  Padding2D)                     8)                               ]']
#
#  stack2_block1_deep_2_dw_conv (  (None, 56, 56, 128)  1152       ['stack2_block1_deep_2_pad[0][0]'
#  DepthwiseConv2D)                                                ]
#
#  stack2_block1_deep_2_bn (Batch  (None, 56, 56, 128)  512        ['stack2_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack2_block1_deep_2_swish (Ac  (None, 56, 56, 128)  0          ['stack2_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block1_deep_3_conv (Con  (None, 56, 56, 48)  6144        ['stack2_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block1_deep_3_bn (Batch  (None, 56, 56, 48)  192         ['stack2_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_1_conv (Con  (None, 56, 56, 192)  9216       ['stack2_block1_deep_3_bn[0][0]']
#  v2D)
#
#  stack2_block2_deep_1_bn (Batch  (None, 56, 56, 192)  768        ['stack2_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_1_swish (Ac  (None, 56, 56, 192)  0          ['stack2_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block2_deep_2_pad (Zero  (None, 58, 58, 192)  0          ['stack2_block2_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack2_block2_deep_2_dw_conv (  (None, 56, 56, 192)  1728       ['stack2_block2_deep_2_pad[0][0]'
#  DepthwiseConv2D)                                                ]
#
#  stack2_block2_deep_2_bn (Batch  (None, 56, 56, 192)  768        ['stack2_block2_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack2_block2_deep_2_swish (Ac  (None, 56, 56, 192)  0          ['stack2_block2_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block2_deep_3_conv (Con  (None, 56, 56, 48)  9216        ['stack2_block2_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block2_deep_3_bn (Batch  (None, 56, 56, 48)  192         ['stack2_block2_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  add (Add)                      (None, 56, 56, 48)   0           ['stack2_block1_deep_3_bn[0][0]',
#                                                                   'stack2_block2_deep_3_bn[0][0]']
#
#  stack2_block3_deep_1_conv (Con  (None, 56, 56, 192)  9216       ['add[0][0]']
#  v2D)
#
#  stack2_block3_deep_1_bn (Batch  (None, 56, 56, 192)  768        ['stack2_block3_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block3_deep_1_swish (Ac  (None, 56, 56, 192)  0          ['stack2_block3_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block3_deep_2_pad (Zero  (None, 58, 58, 192)  0          ['stack2_block3_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack2_block3_deep_2_dw_conv (  (None, 56, 56, 192)  1728       ['stack2_block3_deep_2_pad[0][0]'
#  DepthwiseConv2D)                                                ]
#
#  stack2_block3_deep_2_bn (Batch  (None, 56, 56, 192)  768        ['stack2_block3_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack2_block3_deep_2_swish (Ac  (None, 56, 56, 192)  0          ['stack2_block3_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block3_deep_3_conv (Con  (None, 56, 56, 48)  9216        ['stack2_block3_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block3_deep_3_bn (Batch  (None, 56, 56, 48)  192         ['stack2_block3_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  add_1 (Add)                    (None, 56, 56, 48)   0           ['add[0][0]',
#                                                                   'stack2_block3_deep_3_bn[0][0]']
#
#  stack3_block1_deep_1_conv (Con  (None, 56, 56, 192)  9216       ['add_1[0][0]']
#  v2D)
#
#  stack3_block1_deep_1_bn (Batch  (None, 56, 56, 192)  768        ['stack3_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block1_deep_1_swish (Ac  (None, 56, 56, 192)  0          ['stack3_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack3_block1_deep_2_pad (Zero  (None, 58, 58, 192)  0          ['stack3_block1_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack3_block1_deep_2_dw_conv (  (None, 28, 28, 192)  1728       ['stack3_block1_deep_2_pad[0][0]'
#  DepthwiseConv2D)                                                ]
#
#  stack3_block1_deep_2_bn (Batch  (None, 28, 28, 192)  768        ['stack3_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack3_block1_deep_2_swish (Ac  (None, 28, 28, 192)  0          ['stack3_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack3_block1_deep_3_conv (Con  (None, 28, 28, 64)  12288       ['stack3_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack3_block1_deep_3_bn (Batch  (None, 28, 28, 64)  256         ['stack3_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block2_pre_1_pad (ZeroP  (None, 30, 30, 64)  0           ['stack3_block1_deep_3_bn[0][0]']
#  adding2D)
#
#  stack3_block2_pre_1_conv (Conv  (None, 28, 28, 64)  36864       ['stack3_block2_pre_1_pad[0][0]']
#  2D)
#
#  stack3_block2_pre_1_bn (BatchN  (None, 28, 28, 64)  256         ['stack3_block2_pre_1_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack3_block2_pre_1_swish (Act  (None, 28, 28, 64)  0           ['stack3_block2_pre_1_bn[0][0]']
#  ivation)
#
#  stack3_block2_pre_2_conv (Conv  (None, 28, 28, 96)  6144        ['stack3_block2_pre_1_swish[0][0]
#  2D)                                                             ']
#
#  tf.reshape (TFOpLambda)        (None, 14, 2, 96)    0           ['stack3_block2_pre_2_conv[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose (TFOpLa  (None, 2, 14, 96)   0           ['tf.reshape[0][0]']
#  mbda)
#
#  tf.reshape_1 (TFOpLambda)      (None, 14, 4, 1344)  0           ['tf.compat.v1.transpose[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 4, 14, 1344)  0          ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.reshape_2 (TFOpLambda)      (None, 14, 14, 96)   0           ['tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  stack3_block2_attn_ln (LayerNo  (None, 14, 14, 96)  192         ['tf.reshape_2[0][0]']
#  rmalization)
#
#  stack3_block2_attn_mhsa_qkv (D  (None, 14, 14, 288)  27936      ['stack3_block2_attn_ln[0][0]']
#  ense)
#
#  tf.reshape_3 (TFOpLambda)      (None, 196, 288)     0           ['stack3_block2_attn_mhsa_qkv[0][
#                                                                  0]']
#
#  tf.split (TFOpLambda)          [(None, 196, 96),    0           ['tf.reshape_3[0][0]']
#                                  (None, 196, 96),
#                                  (None, 196, 96)]
#
#  tf.reshape_4 (TFOpLambda)      (None, 196, 4, 24)   0           ['tf.split[0][0]']
#
#  tf.reshape_5 (TFOpLambda)      (None, 196, 4, 24)   0           ['tf.split[0][1]']
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 4, 196, 24)  0           ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 4, 24, 196)  0           ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.linalg.matmul (TFOpLambda)  (None, 4, 196, 196)  0           ['tf.compat.v1.transpose_2[0][0]'
#                                                                  , 'tf.compat.v1.transpose_3[0][0]
#                                                                  ']
#
#  tf.math.multiply (TFOpLambda)  (None, 4, 196, 196)  0           ['tf.linalg.matmul[0][0]']
#
#  tf.reshape_6 (TFOpLambda)      (None, 196, 4, 24)   0           ['tf.split[0][2]']
#
#  stack3_block2_attn_mhsa_attent  (None, 4, 196, 196)  0          ['tf.math.multiply[0][0]']
#  ion_scores (Softmax)
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 4, 196, 24)  0           ['tf.reshape_6[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_1 (TFOpLambda  (None, 4, 196, 24)  0           ['stack3_block2_attn_mhsa_attenti
#  )                                                               on_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_4[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 196, 4, 24)  0           ['tf.linalg.matmul_1[0][0]']
#  Lambda)
#
#  tf.reshape_7 (TFOpLambda)      (None, 14, 14, 96)   0           ['tf.compat.v1.transpose_5[0][0]'
#                                                                  ]
#
#  stack3_block2_attn_mhsa_output  (None, 14, 14, 96)  9312        ['tf.reshape_7[0][0]']
#   (Dense)
#
#  stack3_block2_1_output (Add)   (None, 14, 14, 96)   0           ['tf.reshape_2[0][0]',
#                                                                   'stack3_block2_attn_mhsa_output[
#                                                                  0][0]']
#
#  stack3_block2_mlp_ln (LayerNor  (None, 14, 14, 96)  192         ['stack3_block2_1_output[0][0]']
#  malization)
#
#  stack3_block2_mlp_Dense_0 (Den  (None, 14, 14, 192)  18624      ['stack3_block2_mlp_ln[0][0]']
#  se)
#
#  stack3_block2_mlp_swish (Activ  (None, 14, 14, 192)  0          ['stack3_block2_mlp_Dense_0[0][0]
#  ation)                                                          ']
#
#  stack3_block2_mlp_Dense_1 (Den  (None, 14, 14, 96)  18528       ['stack3_block2_mlp_swish[0][0]']
#  se)
#
#  stack3_block2_2_output (Add)   (None, 14, 14, 96)   0           ['stack3_block2_1_output[0][0]',
#                                                                   'stack3_block2_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack3_block3_attn_ln (LayerNo  (None, 14, 14, 96)  192         ['stack3_block2_2_output[0][0]']
#  rmalization)
#
#  stack3_block3_attn_mhsa_qkv (D  (None, 14, 14, 288)  27936      ['stack3_block3_attn_ln[0][0]']
#  ense)
#
#  tf.reshape_8 (TFOpLambda)      (None, 196, 288)     0           ['stack3_block3_attn_mhsa_qkv[0][
#                                                                  0]']
#
#  tf.split_1 (TFOpLambda)        [(None, 196, 96),    0           ['tf.reshape_8[0][0]']
#                                  (None, 196, 96),
#                                  (None, 196, 96)]
#
#  tf.reshape_9 (TFOpLambda)      (None, 196, 4, 24)   0           ['tf.split_1[0][0]']
#
#  tf.reshape_10 (TFOpLambda)     (None, 196, 4, 24)   0           ['tf.split_1[0][1]']
#
#  tf.compat.v1.transpose_6 (TFOp  (None, 4, 196, 24)  0           ['tf.reshape_9[0][0]']
#  Lambda)
#
#  tf.compat.v1.transpose_7 (TFOp  (None, 4, 24, 196)  0           ['tf.reshape_10[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 4, 196, 196)  0          ['tf.compat.v1.transpose_6[0][0]'
#  )                                                               , 'tf.compat.v1.transpose_7[0][0]
#                                                                  ']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 4, 196, 196)  0          ['tf.linalg.matmul_2[0][0]']
#  )
#
#  tf.reshape_11 (TFOpLambda)     (None, 196, 4, 24)   0           ['tf.split_1[0][2]']
#
#  stack3_block3_attn_mhsa_attent  (None, 4, 196, 196)  0          ['tf.math.multiply_1[0][0]']
#  ion_scores (Softmax)
#
#  tf.compat.v1.transpose_8 (TFOp  (None, 4, 196, 24)  0           ['tf.reshape_11[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 4, 196, 24)  0           ['stack3_block3_attn_mhsa_attenti
#  )                                                               on_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_8[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_9 (TFOp  (None, 196, 4, 24)  0           ['tf.linalg.matmul_3[0][0]']
#  Lambda)
#
#  tf.reshape_12 (TFOpLambda)     (None, 14, 14, 96)   0           ['tf.compat.v1.transpose_9[0][0]'
#                                                                  ]
#
#  stack3_block3_attn_mhsa_output  (None, 14, 14, 96)  9312        ['tf.reshape_12[0][0]']
#   (Dense)
#
#  stack3_block3_1_output (Add)   (None, 14, 14, 96)   0           ['stack3_block2_2_output[0][0]',
#                                                                   'stack3_block3_attn_mhsa_output[
#                                                                  0][0]']
#
#  stack3_block3_mlp_ln (LayerNor  (None, 14, 14, 96)  192         ['stack3_block3_1_output[0][0]']
#  malization)
#
#  stack3_block3_mlp_Dense_0 (Den  (None, 14, 14, 192)  18624      ['stack3_block3_mlp_ln[0][0]']
#  se)
#
#  stack3_block3_mlp_swish (Activ  (None, 14, 14, 192)  0          ['stack3_block3_mlp_Dense_0[0][0]
#  ation)                                                          ']
#
#  stack3_block3_mlp_Dense_1 (Den  (None, 14, 14, 96)  18528       ['stack3_block3_mlp_swish[0][0]']
#  se)
#
#  stack3_block3_2_output (Add)   (None, 14, 14, 96)   0           ['stack3_block3_1_output[0][0]',
#                                                                   'stack3_block3_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack3_block3_post_ln (LayerNo  (None, 14, 14, 96)  192         ['stack3_block3_2_output[0][0]']
#  rmalization)
#
#  tf.reshape_13 (TFOpLambda)     (None, 4, 14, 1344)  0           ['stack3_block3_post_ln[0][0]']
#
#  tf.compat.v1.transpose_10 (TFO  (None, 14, 4, 1344)  0          ['tf.reshape_13[0][0]']
#  pLambda)
#
#  tf.reshape_14 (TFOpLambda)     (None, 2, 14, 96)    0           ['tf.compat.v1.transpose_10[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_11 (TFO  (None, 14, 2, 96)   0           ['tf.reshape_14[0][0]']
#  pLambda)
#
#  tf.reshape_15 (TFOpLambda)     (None, 28, 28, 96)   0           ['tf.compat.v1.transpose_11[0][0]
#                                                                  ']
#
#  stack3_block3_post_1_conv (Con  (None, 28, 28, 64)  6144        ['tf.reshape_15[0][0]']
#  v2D)
#
#  stack3_block3_post_1_bn (Batch  (None, 28, 28, 64)  256         ['stack3_block3_post_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block3_post_1_swish (Ac  (None, 28, 28, 64)  0           ['stack3_block3_post_1_bn[0][0]']
#  tivation)
#
#  tf.concat (TFOpLambda)         (None, 28, 28, 128)  0           ['stack3_block1_deep_3_bn[0][0]',
#                                                                   'stack3_block3_post_1_swish[0][0
#                                                                  ]']
#
#  stack3_block3_post_2_pad (Zero  (None, 30, 30, 128)  0          ['tf.concat[0][0]']
#  Padding2D)
#
#  stack3_block3_post_2_conv (Con  (None, 28, 28, 64)  73728       ['stack3_block3_post_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack3_block3_post_2_bn (Batch  (None, 28, 28, 64)  256         ['stack3_block3_post_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block3_post_2_swish (Ac  (None, 28, 28, 64)  0           ['stack3_block3_post_2_bn[0][0]']
#  tivation)
#
#  stack3_block3_output (Activati  (None, 28, 28, 64)  0           ['stack3_block3_post_2_swish[0][0
#  on)                                                             ]']
#
#  stack4_block1_deep_1_conv (Con  (None, 28, 28, 256)  16384      ['stack3_block3_output[0][0]']
#  v2D)
#
#  stack4_block1_deep_1_bn (Batch  (None, 28, 28, 256)  1024       ['stack4_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack4_block1_deep_1_swish (Ac  (None, 28, 28, 256)  0          ['stack4_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack4_block1_deep_2_pad (Zero  (None, 30, 30, 256)  0          ['stack4_block1_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack4_block1_deep_2_dw_conv (  (None, 14, 14, 256)  2304       ['stack4_block1_deep_2_pad[0][0]'
#  DepthwiseConv2D)                                                ]
#
#  stack4_block1_deep_2_bn (Batch  (None, 14, 14, 256)  1024       ['stack4_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack4_block1_deep_2_swish (Ac  (None, 14, 14, 256)  0          ['stack4_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack4_block1_deep_3_conv (Con  (None, 14, 14, 80)  20480       ['stack4_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack4_block1_deep_3_bn (Batch  (None, 14, 14, 80)  320         ['stack4_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack4_block2_pre_1_pad (ZeroP  (None, 16, 16, 80)  0           ['stack4_block1_deep_3_bn[0][0]']
#  adding2D)
#
#  stack4_block2_pre_1_conv (Conv  (None, 14, 14, 80)  57600       ['stack4_block2_pre_1_pad[0][0]']
#  2D)
#
#  stack4_block2_pre_1_bn (BatchN  (None, 14, 14, 80)  320         ['stack4_block2_pre_1_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block2_pre_1_swish (Act  (None, 14, 14, 80)  0           ['stack4_block2_pre_1_bn[0][0]']
#  ivation)
#
#  stack4_block2_pre_2_conv (Conv  (None, 14, 14, 120)  9600       ['stack4_block2_pre_1_swish[0][0]
#  2D)                                                             ']
#
#  tf.reshape_16 (TFOpLambda)     (None, 7, 2, 120)    0           ['stack4_block2_pre_2_conv[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_12 (TFO  (None, 2, 7, 120)   0           ['tf.reshape_16[0][0]']
#  pLambda)
#
#  tf.reshape_17 (TFOpLambda)     (None, 7, 4, 840)    0           ['tf.compat.v1.transpose_12[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_13 (TFO  (None, 4, 7, 840)   0           ['tf.reshape_17[0][0]']
#  pLambda)
#
#  tf.reshape_18 (TFOpLambda)     (None, 7, 7, 120)    0           ['tf.compat.v1.transpose_13[0][0]
#                                                                  ']
#
#  stack4_block2_attn_ln (LayerNo  (None, 7, 7, 120)   240         ['tf.reshape_18[0][0]']
#  rmalization)
#
#  stack4_block2_attn_mhsa_qkv (D  (None, 7, 7, 360)   43560       ['stack4_block2_attn_ln[0][0]']
#  ense)
#
#  tf.reshape_19 (TFOpLambda)     (None, 49, 360)      0           ['stack4_block2_attn_mhsa_qkv[0][
#                                                                  0]']
#
#  tf.split_2 (TFOpLambda)        [(None, 49, 120),    0           ['tf.reshape_19[0][0]']
#                                  (None, 49, 120),
#                                  (None, 49, 120)]
#
#  tf.reshape_20 (TFOpLambda)     (None, 49, 4, 30)    0           ['tf.split_2[0][0]']
#
#  tf.reshape_21 (TFOpLambda)     (None, 49, 4, 30)    0           ['tf.split_2[0][1]']
#
#  tf.compat.v1.transpose_14 (TFO  (None, 4, 49, 30)   0           ['tf.reshape_20[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_15 (TFO  (None, 4, 30, 49)   0           ['tf.reshape_21[0][0]']
#  pLambda)
#
#  tf.linalg.matmul_4 (TFOpLambda  (None, 4, 49, 49)   0           ['tf.compat.v1.transpose_14[0][0]
#  )                                                               ',
#                                                                   'tf.compat.v1.transpose_15[0][0]
#                                                                  ']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 4, 49, 49)   0           ['tf.linalg.matmul_4[0][0]']
#  )
#
#  tf.reshape_22 (TFOpLambda)     (None, 49, 4, 30)    0           ['tf.split_2[0][2]']
#
#  stack4_block2_attn_mhsa_attent  (None, 4, 49, 49)   0           ['tf.math.multiply_2[0][0]']
#  ion_scores (Softmax)
#
#  tf.compat.v1.transpose_16 (TFO  (None, 4, 49, 30)   0           ['tf.reshape_22[0][0]']
#  pLambda)
#
#  tf.linalg.matmul_5 (TFOpLambda  (None, 4, 49, 30)   0           ['stack4_block2_attn_mhsa_attenti
#  )                                                               on_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_16[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_17 (TFO  (None, 49, 4, 30)   0           ['tf.linalg.matmul_5[0][0]']
#  pLambda)
#
#  tf.reshape_23 (TFOpLambda)     (None, 7, 7, 120)    0           ['tf.compat.v1.transpose_17[0][0]
#                                                                  ']
#
#  stack4_block2_attn_mhsa_output  (None, 7, 7, 120)   14520       ['tf.reshape_23[0][0]']
#   (Dense)
# ...
#  tf.reshape_54 (TFOpLambda)     (None, 4, 4, 144)    0           ['tf.compat.v1.transpose_41[0][0]
#                                                                  ']
#
#  stack5_block3_attn_mhsa_output  (None, 4, 4, 144)   20880       ['tf.reshape_54[0][0]']
#   (Dense)
#
#  stack5_block3_1_output (Add)   (None, 4, 4, 144)    0           ['stack5_block2_2_output[0][0]',
#                                                                   'stack5_block3_attn_mhsa_output[
#                                                                  0][0]']
#
#  stack5_block3_mlp_ln (LayerNor  (None, 4, 4, 144)   288         ['stack5_block3_1_output[0][0]']
#  malization)
#
#  stack5_block3_mlp_Dense_0 (Den  (None, 4, 4, 288)   41760       ['stack5_block3_mlp_ln[0][0]']
#  se)
#
#  stack5_block3_mlp_swish (Activ  (None, 4, 4, 288)   0           ['stack5_block3_mlp_Dense_0[0][0]
#  ation)                                                          ']
#
#  stack5_block3_mlp_Dense_1 (Den  (None, 4, 4, 144)   41616       ['stack5_block3_mlp_swish[0][0]']
#  se)
#
#  stack5_block3_2_output (Add)   (None, 4, 4, 144)    0           ['stack5_block3_1_output[0][0]',
#                                                                   'stack5_block3_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack5_block4_attn_ln (LayerNo  (None, 4, 4, 144)   288         ['stack5_block3_2_output[0][0]']
#  rmalization)
#
#  stack5_block4_attn_mhsa_qkv (D  (None, 4, 4, 432)   62640       ['stack5_block4_attn_ln[0][0]']
#  ense)
#
#  tf.reshape_55 (TFOpLambda)     (None, 16, 432)      0           ['stack5_block4_attn_mhsa_qkv[0][
#                                                                  0]']
#
#  tf.split_8 (TFOpLambda)        [(None, 16, 144),    0           ['tf.reshape_55[0][0]']
#                                  (None, 16, 144),
#                                  (None, 16, 144)]
#
#  tf.reshape_56 (TFOpLambda)     (None, 16, 4, 36)    0           ['tf.split_8[0][0]']
#
#  tf.reshape_57 (TFOpLambda)     (None, 16, 4, 36)    0           ['tf.split_8[0][1]']
#
#  tf.compat.v1.transpose_42 (TFO  (None, 4, 16, 36)   0           ['tf.reshape_56[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_43 (TFO  (None, 4, 36, 16)   0           ['tf.reshape_57[0][0]']
#  pLambda)
#
#  tf.linalg.matmul_16 (TFOpLambd  (None, 4, 16, 16)   0           ['tf.compat.v1.transpose_42[0][0]
#  a)                                                              ',
#                                                                   'tf.compat.v1.transpose_43[0][0]
#                                                                  ']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 4, 16, 16)   0           ['tf.linalg.matmul_16[0][0]']
#  )
#
#  tf.reshape_58 (TFOpLambda)     (None, 16, 4, 36)    0           ['tf.split_8[0][2]']
#
#  stack5_block4_attn_mhsa_attent  (None, 4, 16, 16)   0           ['tf.math.multiply_8[0][0]']
#  ion_scores (Softmax)
#
#  tf.compat.v1.transpose_44 (TFO  (None, 4, 16, 36)   0           ['tf.reshape_58[0][0]']
#  pLambda)
#
#  tf.linalg.matmul_17 (TFOpLambd  (None, 4, 16, 36)   0           ['stack5_block4_attn_mhsa_attenti
#  a)                                                              on_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_44[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_45 (TFO  (None, 16, 4, 36)   0           ['tf.linalg.matmul_17[0][0]']
#  pLambda)
#
#  tf.reshape_59 (TFOpLambda)     (None, 4, 4, 144)    0           ['tf.compat.v1.transpose_45[0][0]
#                                                                  ']
#
#  stack5_block4_attn_mhsa_output  (None, 4, 4, 144)   20880       ['tf.reshape_59[0][0]']
#   (Dense)
#
#  stack5_block4_1_output (Add)   (None, 4, 4, 144)    0           ['stack5_block3_2_output[0][0]',
#                                                                   'stack5_block4_attn_mhsa_output[
#                                                                  0][0]']
#
#  stack5_block4_mlp_ln (LayerNor  (None, 4, 4, 144)   288         ['stack5_block4_1_output[0][0]']
#  malization)
#
#  stack5_block4_mlp_Dense_0 (Den  (None, 4, 4, 288)   41760       ['stack5_block4_mlp_ln[0][0]']
#  se)
#
#  stack5_block4_mlp_swish (Activ  (None, 4, 4, 288)   0           ['stack5_block4_mlp_Dense_0[0][0]
#  ation)                                                          ']
#
#  stack5_block4_mlp_Dense_1 (Den  (None, 4, 4, 144)   41616       ['stack5_block4_mlp_swish[0][0]']
#  se)
#
#  stack5_block4_2_output (Add)   (None, 4, 4, 144)    0           ['stack5_block4_1_output[0][0]',
#                                                                   'stack5_block4_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack5_block4_post_ln (LayerNo  (None, 4, 4, 144)   288         ['stack5_block4_2_output[0][0]']
#  rmalization)
#
#  tf.reshape_60 (TFOpLambda)     (None, 4, 4, 576)    0           ['stack5_block4_post_ln[0][0]']
#
#  tf.compat.v1.transpose_46 (TFO  (None, 4, 4, 576)   0           ['tf.reshape_60[0][0]']
#  pLambda)
#
#  tf.reshape_61 (TFOpLambda)     (None, 2, 4, 144)    0           ['tf.compat.v1.transpose_46[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_47 (TFO  (None, 4, 2, 144)   0           ['tf.reshape_61[0][0]']
#  pLambda)
#
#  tf.reshape_62 (TFOpLambda)     (None, 8, 8, 144)    0           ['tf.compat.v1.transpose_47[0][0]
#                                                                  ']
#
#  tf.image.resize_1 (TFOpLambda)  (None, 7, 7, 144)   0           ['tf.reshape_62[0][0]']
#
#  stack5_block4_post_1_conv (Con  (None, 7, 7, 96)    13824       ['tf.image.resize_1[0][0]']
#  v2D)
#
#  stack5_block4_post_1_bn (Batch  (None, 7, 7, 96)    384         ['stack5_block4_post_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack5_block4_post_1_swish (Ac  (None, 7, 7, 96)    0           ['stack5_block4_post_1_bn[0][0]']
#  tivation)
#
#  tf.concat_2 (TFOpLambda)       (None, 7, 7, 192)    0           ['stack5_block1_deep_3_bn[0][0]',
#                                                                   'stack5_block4_post_1_swish[0][0
#                                                                  ]']
#
#  stack5_block4_post_2_pad (Zero  (None, 9, 9, 192)   0           ['tf.concat_2[0][0]']
#  Padding2D)
#
#  stack5_block4_post_2_conv (Con  (None, 7, 7, 96)    165888      ['stack5_block4_post_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack5_block4_post_2_bn (Batch  (None, 7, 7, 96)    384         ['stack5_block4_post_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack5_block4_post_2_swish (Ac  (None, 7, 7, 96)    0           ['stack5_block4_post_2_bn[0][0]']
#  tivation)
#
#  stack5_block4_output (Activati  (None, 7, 7, 96)    0           ['stack5_block4_post_2_swish[0][0
#  on)                                                             ]']
#
#  features_conv (Conv2D)         (None, 7, 7, 384)    36864       ['stack5_block4_output[0][0]']
#
#  features_bn (BatchNormalizatio  (None, 7, 7, 384)   1536        ['features_conv[0][0]']
#  n)
#
#  features_swish (Activation)    (None, 7, 7, 384)    0           ['features_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 384)         0           ['features_swish[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 23)           8855        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1,950,151
# Trainable params: 1,941,703
# Non-trainable params: 8,448
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_1.fit(X_train, 
                  y_train, 
                  batch_size=256, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
#  6/34 [====>.........................] - ETA: 12s - loss: 2.4473 - accuracy: 0.4616 - top-5-accuracy: 0.7305
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1835s vs `on_train_batch_end` time: 0.2316s). Check your callbacks.
# 68/68 [==============================] - 5s 34ms/step
#  - val_f1_macro: 0.49050621616909174 - val_f1_micro: 0.7160148975791435
#           - val_precision_macro: 0.569724917388824 - val_precision_micro: 0.7160148975791434 - val_recall_macro: 0.4836733192990695 - val_recall_micro: 0.7160148975791434
#           - val_best_f1_score_macro: 0.49050621616909174 (epoch: 0) - val_best_f1_score_micro: 0.7160148975791435 (epoch: 0.7160148975791435)
# 34/34 [==============================] - 45s 778ms/step - loss: 0.9884 - accuracy: 0.7450 - top-5-accuracy: 0.9349 - val_loss: 0.6756 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9791
# Epoch 2/5
# 68/68 [==============================] - 2s 32ms/step
#  - val_f1_macro: 0.5527775655740709 - val_f1_micro: 0.8384543761638734
#           - val_precision_macro: 0.6337172259303451 - val_precision_micro: 0.8384543761638734 - val_recall_macro: 0.5437500870023153 - val_recall_micro: 0.8384543761638734
#           - val_best_f1_score_macro: 0.5527775655740709 (epoch: 1) - val_best_f1_score_micro: 0.8384543761638734 (epoch: 0.8384543761638734)
# 34/34 [==============================] - 19s 568ms/step - loss: 0.3380 - accuracy: 0.8872 - top-5-accuracy: 0.9944 - val_loss: 0.3682 - val_accuracy: 0.8669 - val_top-5-accuracy: 0.9949
# Epoch 3/5
# 68/68 [==============================] - 2s 31ms/step
#  - val_f1_macro: 0.488789831360106 - val_f1_micro: 0.8226256983240223
#           - val_precision_macro: 0.5306893379072324 - val_precision_micro: 0.8226256983240223 - val_recall_macro: 0.5026850397823966 - val_recall_micro: 0.8226256983240223
#           - val_best_f1_score_macro: 0.5527775655740709 (epoch: 1) - val_best_f1_score_micro: 0.8384543761638734 (epoch: 0.8384543761638734)
# 34/34 [==============================] - 19s 567ms/step - loss: 0.2653 - accuracy: 0.9085 - top-5-accuracy: 0.9976 - val_loss: 0.5951 - val_accuracy: 0.8347 - val_top-5-accuracy: 0.9874
# Epoch 4/5
# 68/68 [==============================] - 2s 32ms/step
#  - val_f1_macro: 0.5728642975033353 - val_f1_micro: 0.8598696461824954
#           - val_precision_macro: 0.5965847052320318 - val_precision_micro: 0.8598696461824954 - val_recall_macro: 0.5917479225511518 - val_recall_micro: 0.8598696461824954
#           - val_best_f1_score_macro: 0.5728642975033353 (epoch: 3) - val_best_f1_score_micro: 0.8598696461824954 (epoch: 0.8598696461824954)
# 34/34 [==============================] - 19s 569ms/step - loss: 0.2416 - accuracy: 0.9182 - top-5-accuracy: 0.9978 - val_loss: 0.3802 - val_accuracy: 0.8766 - val_top-5-accuracy: 0.9963
# Epoch 5/5
# 68/68 [==============================] - 2s 32ms/step
#  - val_f1_macro: 0.5255277040410635 - val_f1_micro: 0.7839851024208566
#           - val_precision_macro: 0.6036324885998519 - val_precision_micro: 0.7839851024208566 - val_recall_macro: 0.5297651859732256 - val_recall_micro: 0.7839851024208566
#           - val_best_f1_score_macro: 0.5728642975033353 (epoch: 3) - val_best_f1_score_micro: 0.8598696461824954 (epoch: 0.8598696461824954)
# 34/34 [==============================] - 19s 567ms/step - loss: 0.2044 - accuracy: 0.9305 - top-5-accuracy: 0.9983 - val_loss: 0.6388 - val_accuracy: 0.8049 - val_top-5-accuracy: 0.9832

# %% [markdown]
# ## BotNet

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_2.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_2.summary()
# Out:
# Model: "botnet_se33t"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_1_pad (ZeroPadding2D)     (None, 226, 226, 3)  0           ['input_6[0][0]']
#
#  stem_1_conv (Conv2D)           (None, 112, 112, 24  648         ['stem_1_pad[0][0]']
#                                 )
#
#  stem_1_bn (BatchNormalization)  (None, 112, 112, 24  96         ['stem_1_conv[0][0]']
#                                 )
#
#  stem_1_swish (Activation)      (None, 112, 112, 24  0           ['stem_1_bn[0][0]']
#                                 )
#
#  stem_2_pad (ZeroPadding2D)     (None, 114, 114, 24  0           ['stem_1_swish[0][0]']
#                                 )
#
#  stem_2_conv (Conv2D)           (None, 112, 112, 32  6912        ['stem_2_pad[0][0]']
#                                 )
#
#  stem_2_bn (BatchNormalization)  (None, 112, 112, 32  128        ['stem_2_conv[0][0]']
#                                 )
#
#  stem_2_swish (Activation)      (None, 112, 112, 32  0           ['stem_2_bn[0][0]']
#                                 )
#
#  stem_3_pad (ZeroPadding2D)     (None, 114, 114, 32  0           ['stem_2_swish[0][0]']
#                                 )
#
#  stem_3_conv (Conv2D)           (None, 56, 56, 64)   18432       ['stem_3_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 56, 56, 64)   256         ['stem_3_conv[0][0]']
#
#  stem_swish (Activation)        (None, 56, 56, 64)   0           ['stem_bn[0][0]']
#
#  stack1_block1_deep_1_conv (Con  (None, 56, 56, 64)  4096        ['stem_swish[0][0]']
#  v2D)
#
#  stack1_block1_deep_1_bn (Batch  (None, 56, 56, 64)  256         ['stack1_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack1_block1_deep_1_swish (Ac  (None, 56, 56, 64)  0           ['stack1_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack1_block1_deep_2_pad (Zero  (None, 58, 58, 64)  0           ['stack1_block1_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack1_block1_deep_2_conv (Con  (None, 56, 56, 64)  36864       ['stack1_block1_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack1_block1_deep_2_bn (Batch  (None, 56, 56, 64)  256         ['stack1_block1_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack1_block1_deep_2_swish (Ac  (None, 56, 56, 64)  0           ['stack1_block1_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_8 (TFOpLam  (None, 1, 1, 64)    0           ['stack1_block1_deep_2_swish[0][0
#  bda)                                                            ]']
#
#  stack1_block1_deep_2_se_1_conv  (None, 1, 1, 8)     520         ['tf.math.reduce_mean_8[0][0]']
#   (Conv2D)
#
#  stack1_block1_deep_2_se_swish   (None, 1, 1, 8)     0           ['stack1_block1_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack1_block1_deep_2_se_2_conv  (None, 1, 1, 64)    576         ['stack1_block1_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack1_block1_deep_2_se_sigmoi  (None, 1, 1, 64)    0           ['stack1_block1_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack1_block1_deep_2_se_out (M  (None, 56, 56, 64)  0           ['stack1_block1_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack1_block1_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack1_block1_shortcut_conv (C  (None, 56, 56, 256)  16384      ['stem_swish[0][0]']
#  onv2D)
#
#  stack1_block1_deep_3_conv (Con  (None, 56, 56, 256)  16384      ['stack1_block1_deep_2_se_out[0][
#  v2D)                                                            0]']
#
#  stack1_block1_shortcut_bn (Bat  (None, 56, 56, 256)  1024       ['stack1_block1_shortcut_conv[0][
#  chNormalization)                                                0]']
#
#  stack1_block1_3_bn (BatchNorma  (None, 56, 56, 256)  1024       ['stack1_block1_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack1_block1_add (Add)        (None, 56, 56, 256)  0           ['stack1_block1_shortcut_bn[0][0]
#                                                                  ',
#                                                                   'stack1_block1_3_bn[0][0]']
#
#  stack1_block1_out_swish (Activ  (None, 56, 56, 256)  0          ['stack1_block1_add[0][0]']
#  ation)
#
#  stack1_block1_output (Activati  (None, 56, 56, 256)  0          ['stack1_block1_out_swish[0][0]']
#  on)
#
#  stack1_block2_deep_1_conv (Con  (None, 56, 56, 64)  16384       ['stack1_block1_output[0][0]']
#  v2D)
#
#  stack1_block2_deep_1_bn (Batch  (None, 56, 56, 64)  256         ['stack1_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack1_block2_deep_1_swish (Ac  (None, 56, 56, 64)  0           ['stack1_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack1_block2_deep_2_pad (Zero  (None, 58, 58, 64)  0           ['stack1_block2_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack1_block2_deep_2_conv (Con  (None, 56, 56, 64)  36864       ['stack1_block2_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack1_block2_deep_2_bn (Batch  (None, 56, 56, 64)  256         ['stack1_block2_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack1_block2_deep_2_swish (Ac  (None, 56, 56, 64)  0           ['stack1_block2_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_9 (TFOpLam  (None, 1, 1, 64)    0           ['stack1_block2_deep_2_swish[0][0
#  bda)                                                            ]']
#
#  stack1_block2_deep_2_se_1_conv  (None, 1, 1, 8)     520         ['tf.math.reduce_mean_9[0][0]']
#   (Conv2D)
#
#  stack1_block2_deep_2_se_swish   (None, 1, 1, 8)     0           ['stack1_block2_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack1_block2_deep_2_se_2_conv  (None, 1, 1, 64)    576         ['stack1_block2_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack1_block2_deep_2_se_sigmoi  (None, 1, 1, 64)    0           ['stack1_block2_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack1_block2_deep_2_se_out (M  (None, 56, 56, 64)  0           ['stack1_block2_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack1_block2_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack1_block2_deep_3_conv (Con  (None, 56, 56, 256)  16384      ['stack1_block2_deep_2_se_out[0][
#  v2D)                                                            0]']
#
#  stack1_block2_3_bn (BatchNorma  (None, 56, 56, 256)  1024       ['stack1_block2_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack1_block2_add (Add)        (None, 56, 56, 256)  0           ['stack1_block1_output[0][0]',
#                                                                   'stack1_block2_3_bn[0][0]']
#
#  stack1_block2_out_swish (Activ  (None, 56, 56, 256)  0          ['stack1_block2_add[0][0]']
#  ation)
#
#  stack1_block2_output (Activati  (None, 56, 56, 256)  0          ['stack1_block2_out_swish[0][0]']
#  on)
#
#  stack2_block1_deep_1_conv (Con  (None, 56, 56, 128)  32768      ['stack1_block2_output[0][0]']
#  v2D)
#
#  stack2_block1_deep_1_bn (Batch  (None, 56, 56, 128)  512        ['stack2_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block1_deep_1_swish (Ac  (None, 56, 56, 128)  0          ['stack2_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block1_deep_2_pad (Zero  (None, 58, 58, 128)  0          ['stack2_block1_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack2_block1_deep_2_conv (Con  (None, 28, 28, 128)  147456     ['stack2_block1_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack2_block1_deep_2_bn (Batch  (None, 28, 28, 128)  512        ['stack2_block1_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block1_deep_2_swish (Ac  (None, 28, 28, 128)  0          ['stack2_block1_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_10 (TFOpLa  (None, 1, 1, 128)   0           ['stack2_block1_deep_2_swish[0][0
#  mbda)                                                           ]']
#
#  stack2_block1_deep_2_se_1_conv  (None, 1, 1, 8)     1032        ['tf.math.reduce_mean_10[0][0]']
#   (Conv2D)
#
#  stack2_block1_deep_2_se_swish   (None, 1, 1, 8)     0           ['stack2_block1_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack2_block1_deep_2_se_2_conv  (None, 1, 1, 128)   1152        ['stack2_block1_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack2_block1_deep_2_se_sigmoi  (None, 1, 1, 128)   0           ['stack2_block1_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack2_block1_deep_2_se_out (M  (None, 28, 28, 128)  0          ['stack2_block1_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack2_block1_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack2_block1_shortcut_conv (C  (None, 28, 28, 512)  131072     ['stack1_block2_output[0][0]']
#  onv2D)
#
#  stack2_block1_deep_3_conv (Con  (None, 28, 28, 512)  65536      ['stack2_block1_deep_2_se_out[0][
#  v2D)                                                            0]']
#
#  stack2_block1_shortcut_bn (Bat  (None, 28, 28, 512)  2048       ['stack2_block1_shortcut_conv[0][
#  chNormalization)                                                0]']
#
#  stack2_block1_3_bn (BatchNorma  (None, 28, 28, 512)  2048       ['stack2_block1_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack2_block1_add (Add)        (None, 28, 28, 512)  0           ['stack2_block1_shortcut_bn[0][0]
#                                                                  ',
#                                                                   'stack2_block1_3_bn[0][0]']
#
#  stack2_block1_out_swish (Activ  (None, 28, 28, 512)  0          ['stack2_block1_add[0][0]']
#  ation)
#
#  stack2_block1_output (Activati  (None, 28, 28, 512)  0          ['stack2_block1_out_swish[0][0]']
#  on)
#
#  stack2_block2_deep_1_conv (Con  (None, 28, 28, 128)  65536      ['stack2_block1_output[0][0]']
#  v2D)
#
#  stack2_block2_deep_1_bn (Batch  (None, 28, 28, 128)  512        ['stack2_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_1_swish (Ac  (None, 28, 28, 128)  0          ['stack2_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block2_deep_2_pad (Zero  (None, 30, 30, 128)  0          ['stack2_block2_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack2_block2_deep_2_conv (Con  (None, 28, 28, 128)  147456     ['stack2_block2_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack2_block2_deep_2_bn (Batch  (None, 28, 28, 128)  512        ['stack2_block2_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_2_swish (Ac  (None, 28, 28, 128)  0          ['stack2_block2_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_11 (TFOpLa  (None, 1, 1, 128)   0           ['stack2_block2_deep_2_swish[0][0
#  mbda)                                                           ]']
#
#  stack2_block2_deep_2_se_1_conv  (None, 1, 1, 8)     1032        ['tf.math.reduce_mean_11[0][0]']
#   (Conv2D)
#
#  stack2_block2_deep_2_se_swish   (None, 1, 1, 8)     0           ['stack2_block2_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack2_block2_deep_2_se_2_conv  (None, 1, 1, 128)   1152        ['stack2_block2_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack2_block2_deep_2_se_sigmoi  (None, 1, 1, 128)   0           ['stack2_block2_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack2_block2_deep_2_se_out (M  (None, 28, 28, 128)  0          ['stack2_block2_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack2_block2_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack2_block2_deep_3_conv (Con  (None, 28, 28, 512)  65536      ['stack2_block2_deep_2_se_out[0][
#  v2D)                                                            0]']
#
#  stack2_block2_3_bn (BatchNorma  (None, 28, 28, 512)  2048       ['stack2_block2_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack2_block2_add (Add)        (None, 28, 28, 512)  0           ['stack2_block1_output[0][0]',
#                                                                   'stack2_block2_3_bn[0][0]']
#
#  stack2_block2_out_swish (Activ  (None, 28, 28, 512)  0          ['stack2_block2_add[0][0]']
#  ation)
#
#  stack2_block2_output (Activati  (None, 28, 28, 512)  0          ['stack2_block2_out_swish[0][0]']
#  on)
#
#  stack2_block3_deep_1_conv (Con  (None, 28, 28, 128)  65536      ['stack2_block2_output[0][0]']
#  v2D)
#
#  stack2_block3_deep_1_bn (Batch  (None, 28, 28, 128)  512        ['stack2_block3_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block3_deep_1_swish (Ac  (None, 28, 28, 128)  0          ['stack2_block3_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block3_deep_2_mhsa_qkv_  (None, 28, 28, 384)  49152      ['stack2_block3_deep_1_swish[0][0
#  conv (Conv2D)                                                   ]']
#
#  tf.split_52 (TFOpLambda)       [(None, 28, 28, 128  0           ['stack2_block3_deep_2_mhsa_qkv_c
#                                 ),                               onv[0][0]']
#                                  (None, 28, 28, 128
#                                 ),
#                                  (None, 28, 28, 128
#                                 )]
#
#  tf.reshape_285 (TFOpLambda)    (None, 784, 4, 32)   0           ['tf.split_52[0][0]']
#
#  tf.compat.v1.transpose_220 (TF  (None, 4, 784, 32)  0           ['tf.reshape_285[0][0]']
#  OpLambda)
#
#  tf.reshape_286 (TFOpLambda)    (None, 784, 4, 32)   0           ['tf.split_52[0][1]']
#
#  tf.compat.v1.transpose_221 (TF  (None, 4, 32, 784)  0           ['tf.reshape_286[0][0]']
#  OpLambda)
#
#  tf.reshape_288 (TFOpLambda)    (None, 4, 28, 28, 3  0           ['tf.compat.v1.transpose_220[0][0
#                                 2)                               ]']
#
#  tf.linalg.matmul_104 (TFOpLamb  (None, 4, 784, 784)  0          ['tf.compat.v1.transpose_220[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_221[0][0
#                                                                  ]']
#
#  stack2_block3_deep_2_mhsa_pos_  (None, 4, 28, 28, 2  3520       ['tf.reshape_288[0][0]']
#  emb (RelativePositionalEmbeddi  8, 28)
#  ng)
#
#  tf.math.multiply_52 (TFOpLambd  (None, 4, 784, 784)  0          ['tf.linalg.matmul_104[0][0]']
#  a)
#
#  tf.reshape_289 (TFOpLambda)    (None, 4, 784, 784)  0           ['stack2_block3_deep_2_mhsa_pos_e
#                                                                  mb[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 4, 784, 784)  0          ['tf.math.multiply_52[0][0]',
#  mbda)                                                            'tf.reshape_289[0][0]']
#
#  tf.reshape_287 (TFOpLambda)    (None, 784, 4, 32)   0           ['tf.split_52[0][2]']
#
#  stack2_block3_deep_2_mhsa_atte  (None, 4, 784, 784)  0          ['tf.__operators__.add_7[0][0]']
#  ntion_scores (Softmax)
#
#  tf.compat.v1.transpose_222 (TF  (None, 4, 784, 32)  0           ['tf.reshape_287[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_105 (TFOpLamb  (None, 4, 784, 32)  0           ['stack2_block3_deep_2_mhsa_atten
#  da)                                                             tion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_222[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_223 (TF  (None, 784, 4, 32)  0           ['tf.linalg.matmul_105[0][0]']
#  OpLambda)
#
#  tf.reshape_290 (TFOpLambda)    (None, 28, 28, 128)  0           ['tf.compat.v1.transpose_223[0][0
#                                                                  ]']
#
#  stack2_block3_deep_2_bn (Batch  (None, 28, 28, 128)  512        ['tf.reshape_290[0][0]']
#  Normalization)
#
#  stack2_block3_deep_2_swish (Ac  (None, 28, 28, 128)  0          ['stack2_block3_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block3_deep_3_conv (Con  (None, 28, 28, 512)  65536      ['stack2_block3_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block3_3_bn (BatchNorma  (None, 28, 28, 512)  2048       ['stack2_block3_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack2_block3_add (Add)        (None, 28, 28, 512)  0           ['stack2_block2_output[0][0]',
#                                                                   'stack2_block3_3_bn[0][0]']
#
#  stack2_block3_out_swish (Activ  (None, 28, 28, 512)  0          ['stack2_block3_add[0][0]']
#  ation)
#
#  stack2_block3_output (Activati  (None, 28, 28, 512)  0          ['stack2_block3_out_swish[0][0]']
#  on)
#
#  stack3_block1_deep_1_conv (Con  (None, 28, 28, 256)  131072     ['stack2_block3_output[0][0]']
#  v2D)
#
#  stack3_block1_deep_1_bn (Batch  (None, 28, 28, 256)  1024       ['stack3_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block1_deep_1_swish (Ac  (None, 28, 28, 256)  0          ['stack3_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack3_block1_deep_2_pad (Zero  (None, 30, 30, 256)  0          ['stack3_block1_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack3_block1_deep_2_conv (Con  (None, 14, 14, 256)  589824     ['stack3_block1_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack3_block1_deep_2_bn (Batch  (None, 14, 14, 256)  1024       ['stack3_block1_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block1_deep_2_swish (Ac  (None, 14, 14, 256)  0          ['stack3_block1_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_12 (TFOpLa  (None, 1, 1, 256)   0           ['stack3_block1_deep_2_swish[0][0
#  mbda)                                                           ]']
#
#  stack3_block1_deep_2_se_1_conv  (None, 1, 1, 16)    4112        ['tf.math.reduce_mean_12[0][0]']
#   (Conv2D)
#
#  stack3_block1_deep_2_se_swish   (None, 1, 1, 16)    0           ['stack3_block1_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack3_block1_deep_2_se_2_conv  (None, 1, 1, 256)   4352        ['stack3_block1_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack3_block1_deep_2_se_sigmoi  (None, 1, 1, 256)   0           ['stack3_block1_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack3_block1_deep_2_se_out (M  (None, 14, 14, 256)  0          ['stack3_block1_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack3_block1_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack3_block1_shortcut_conv (C  (None, 14, 14, 1024  524288     ['stack2_block3_output[0][0]']
#  onv2D)                         )
#
#  stack3_block1_deep_3_conv (Con  (None, 14, 14, 1024  262144     ['stack3_block1_deep_2_se_out[0][
#  v2D)                           )                                0]']
#
#  stack3_block1_shortcut_bn (Bat  (None, 14, 14, 1024  4096       ['stack3_block1_shortcut_conv[0][
#  chNormalization)               )                                0]']
#
#  stack3_block1_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['stack3_block1_deep_3_conv[0][0]
#  lization)                      )                                ']
#
#  stack3_block1_add (Add)        (None, 14, 14, 1024  0           ['stack3_block1_shortcut_bn[0][0]
#                                 )                                ',
#                                                                   'stack3_block1_3_bn[0][0]']
#
#  stack3_block1_out_swish (Activ  (None, 14, 14, 1024  0          ['stack3_block1_add[0][0]']
#  ation)                         )
#
#  stack3_block1_output (Activati  (None, 14, 14, 1024  0          ['stack3_block1_out_swish[0][0]']
#  on)                            )
#
#  stack3_block2_deep_1_conv (Con  (None, 14, 14, 256)  262144     ['stack3_block1_output[0][0]']
#  v2D)
#
#  stack3_block2_deep_1_bn (Batch  (None, 14, 14, 256)  1024       ['stack3_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block2_deep_1_swish (Ac  (None, 14, 14, 256)  0          ['stack3_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack3_block2_deep_2_pad (Zero  (None, 16, 16, 256)  0          ['stack3_block2_deep_1_swish[0][0
#  Padding2D)                                                      ]']
#
#  stack3_block2_deep_2_conv (Con  (None, 14, 14, 256)  589824     ['stack3_block2_deep_2_pad[0][0]'
#  v2D)                                                            ]
#
#  stack3_block2_deep_2_bn (Batch  (None, 14, 14, 256)  1024       ['stack3_block2_deep_2_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block2_deep_2_swish (Ac  (None, 14, 14, 256)  0          ['stack3_block2_deep_2_bn[0][0]']
#  tivation)
#
#  tf.math.reduce_mean_13 (TFOpLa  (None, 1, 1, 256)   0           ['stack3_block2_deep_2_swish[0][0
#  mbda)                                                           ]']
#
#  stack3_block2_deep_2_se_1_conv  (None, 1, 1, 16)    4112        ['tf.math.reduce_mean_13[0][0]']
#   (Conv2D)
#
#  stack3_block2_deep_2_se_swish   (None, 1, 1, 16)    0           ['stack3_block2_deep_2_se_1_conv[
#  (Activation)                                                    0][0]']
#
#  stack3_block2_deep_2_se_2_conv  (None, 1, 1, 256)   4352        ['stack3_block2_deep_2_se_swish[0
#   (Conv2D)                                                       ][0]']
#
#  stack3_block2_deep_2_se_sigmoi  (None, 1, 1, 256)   0           ['stack3_block2_deep_2_se_2_conv[
#  d (Activation)                                                  0][0]']
#
#  stack3_block2_deep_2_se_out (M  (None, 14, 14, 256)  0          ['stack3_block2_deep_2_swish[0][0
#  ultiply)                                                        ]',
#                                                                   'stack3_block2_deep_2_se_sigmoid
#                                                                  [0][0]']
#
#  stack3_block2_deep_3_conv (Con  (None, 14, 14, 1024  262144     ['stack3_block2_deep_2_se_out[0][
#  v2D)                           )                                0]']
#
#  stack3_block2_3_bn (BatchNorma  (None, 14, 14, 1024  4096       ['stack3_block2_deep_3_conv[0][0]
#  lization)                      )                                ']
#
#  stack3_block2_add (Add)        (None, 14, 14, 1024  0           ['stack3_block1_output[0][0]',
#                                 )                                 'stack3_block2_3_bn[0][0]']
#
#  stack3_block2_out_swish (Activ  (None, 14, 14, 1024  0          ['stack3_block2_add[0][0]']
#  ation)                         )
#
#  stack3_block2_output (Activati  (None, 14, 14, 1024  0          ['stack3_block2_out_swish[0][0]']
#  on)                            )
# ...
#  tf.math.multiply_54 (TFOpLambd  (None, 4, 196, 196)  0          ['tf.linalg.matmul_108[0][0]']
#  a)
#
#  tf.reshape_301 (TFOpLambda)    (None, 4, 196, 196)  0           ['stack4_block1_deep_2_mhsa_pos_e
#                                                                  mb[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 4, 196, 196)  0          ['tf.math.multiply_54[0][0]',
#  mbda)                                                            'tf.reshape_301[0][0]']
#
#  tf.reshape_299 (TFOpLambda)    (None, 196, 4, 128)  0           ['tf.split_54[0][2]']
#
#  stack4_block1_deep_2_mhsa_atte  (None, 4, 196, 196)  0          ['tf.__operators__.add_9[0][0]']
#  ntion_scores (Softmax)
#
#  tf.compat.v1.transpose_230 (TF  (None, 4, 196, 128)  0          ['tf.reshape_299[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_109 (TFOpLamb  (None, 4, 196, 128)  0          ['stack4_block1_deep_2_mhsa_atten
#  da)                                                             tion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_230[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_231 (TF  (None, 196, 4, 128)  0          ['tf.linalg.matmul_109[0][0]']
#  OpLambda)
#
#  tf.reshape_302 (TFOpLambda)    (None, 14, 14, 512)  0           ['tf.compat.v1.transpose_231[0][0
#                                                                  ]']
#
#  stack4_block1_deep_2_pool (Ave  (None, 7, 7, 512)   0           ['tf.reshape_302[0][0]']
#  ragePooling2D)
#
#  stack4_block1_deep_2_bn (Batch  (None, 7, 7, 512)   2048        ['stack4_block1_deep_2_pool[0][0]
#  Normalization)                                                  ']
#
#  stack4_block1_deep_2_swish (Ac  (None, 7, 7, 512)   0           ['stack4_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack4_block1_shortcut_conv (C  (None, 7, 7, 1536)  1572864     ['stack3_block3_output[0][0]']
#  onv2D)
#
#  stack4_block1_deep_3_conv (Con  (None, 7, 7, 1536)  786432      ['stack4_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack4_block1_shortcut_bn (Bat  (None, 7, 7, 1536)  6144        ['stack4_block1_shortcut_conv[0][
#  chNormalization)                                                0]']
#
#  stack4_block1_3_bn (BatchNorma  (None, 7, 7, 1536)  6144        ['stack4_block1_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack4_block1_add (Add)        (None, 7, 7, 1536)   0           ['stack4_block1_shortcut_bn[0][0]
#                                                                  ',
#                                                                   'stack4_block1_3_bn[0][0]']
#
#  stack4_block1_out_swish (Activ  (None, 7, 7, 1536)  0           ['stack4_block1_add[0][0]']
#  ation)
#
#  stack4_block1_output (Activati  (None, 7, 7, 1536)  0           ['stack4_block1_out_swish[0][0]']
#  on)
#
#  stack4_block2_deep_1_conv (Con  (None, 7, 7, 512)   786432      ['stack4_block1_output[0][0]']
#  v2D)
#
#  stack4_block2_deep_1_bn (Batch  (None, 7, 7, 512)   2048        ['stack4_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack4_block2_deep_1_swish (Ac  (None, 7, 7, 512)   0           ['stack4_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack4_block2_deep_2_mhsa_qkv_  (None, 7, 7, 1536)  786432      ['stack4_block2_deep_1_swish[0][0
#  conv (Conv2D)                                                   ]']
#
#  tf.split_55 (TFOpLambda)       [(None, 7, 7, 512),  0           ['stack4_block2_deep_2_mhsa_qkv_c
#                                  (None, 7, 7, 512),              onv[0][0]']
#                                  (None, 7, 7, 512)]
#
#  tf.reshape_303 (TFOpLambda)    (None, 49, 4, 128)   0           ['tf.split_55[0][0]']
#
#  tf.compat.v1.transpose_232 (TF  (None, 4, 49, 128)  0           ['tf.reshape_303[0][0]']
#  OpLambda)
#
#  tf.reshape_304 (TFOpLambda)    (None, 49, 4, 128)   0           ['tf.split_55[0][1]']
#
#  tf.compat.v1.transpose_233 (TF  (None, 4, 128, 49)  0           ['tf.reshape_304[0][0]']
#  OpLambda)
#
#  tf.reshape_306 (TFOpLambda)    (None, 4, 7, 7, 128  0           ['tf.compat.v1.transpose_232[0][0
#                                 )                                ]']
#
#  tf.linalg.matmul_110 (TFOpLamb  (None, 4, 49, 49)   0           ['tf.compat.v1.transpose_232[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_233[0][0
#                                                                  ]']
#
#  stack4_block2_deep_2_mhsa_pos_  (None, 4, 7, 7, 7,   3328       ['tf.reshape_306[0][0]']
#  emb (RelativePositionalEmbeddi  7)
#  ng)
#
#  tf.math.multiply_55 (TFOpLambd  (None, 4, 49, 49)   0           ['tf.linalg.matmul_110[0][0]']
#  a)
#
#  tf.reshape_307 (TFOpLambda)    (None, 4, 49, 49)    0           ['stack4_block2_deep_2_mhsa_pos_e
#                                                                  mb[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 4, 49, 49)   0           ['tf.math.multiply_55[0][0]',
#  ambda)                                                           'tf.reshape_307[0][0]']
#
#  tf.reshape_305 (TFOpLambda)    (None, 49, 4, 128)   0           ['tf.split_55[0][2]']
#
#  stack4_block2_deep_2_mhsa_atte  (None, 4, 49, 49)   0           ['tf.__operators__.add_10[0][0]']
#  ntion_scores (Softmax)
#
#  tf.compat.v1.transpose_234 (TF  (None, 4, 49, 128)  0           ['tf.reshape_305[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_111 (TFOpLamb  (None, 4, 49, 128)  0           ['stack4_block2_deep_2_mhsa_atten
#  da)                                                             tion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_234[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_235 (TF  (None, 49, 4, 128)  0           ['tf.linalg.matmul_111[0][0]']
#  OpLambda)
#
#  tf.reshape_308 (TFOpLambda)    (None, 7, 7, 512)    0           ['tf.compat.v1.transpose_235[0][0
#                                                                  ]']
#
#  stack4_block2_deep_2_bn (Batch  (None, 7, 7, 512)   2048        ['tf.reshape_308[0][0]']
#  Normalization)
#
#  stack4_block2_deep_2_swish (Ac  (None, 7, 7, 512)   0           ['stack4_block2_deep_2_bn[0][0]']
#  tivation)
#
#  stack4_block2_deep_3_conv (Con  (None, 7, 7, 1536)  786432      ['stack4_block2_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack4_block2_3_bn (BatchNorma  (None, 7, 7, 1536)  6144        ['stack4_block2_deep_3_conv[0][0]
#  lization)                                                       ']
#
#  stack4_block2_add (Add)        (None, 7, 7, 1536)   0           ['stack4_block1_output[0][0]',
#                                                                   'stack4_block2_3_bn[0][0]']
#
#  stack4_block2_out_swish (Activ  (None, 7, 7, 1536)  0           ['stack4_block2_add[0][0]']
#  ation)
#
#  stack4_block2_output (Activati  (None, 7, 7, 1536)  0           ['stack4_block2_out_swish[0][0]']
#  on)
#
#  features_conv (Conv2D)         (None, 7, 7, 1280)   1966080     ['stack4_block2_output[0][0]']
#
#  features_bn (BatchNormalizatio  (None, 7, 7, 1280)  5120        ['features_conv[0][0]']
#  n)
#
#  features_swish (Activation)    (None, 7, 7, 1280)   0           ['features_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['features_swish[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 23)           29463       ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 12,482,943
# Trainable params: 12,447,887
# Non-trainable params: 35,056
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_2.fit(X_train, 
                  y_train, 
                  batch_size=256, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
#  6/21 [=======>......................] - ETA: 6s - loss: 2.7148 - accuracy: 0.2747 - top-5-accuracy: 0.6035
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1760s vs `on_train_batch_end` time: 0.2265s). Check your callbacks.
# 168/168 [==============================] - 5s 22ms/step
#  - val_f1_macro: 0.05075291694504499 - val_f1_micro: 0.16815642458100558
#           - val_precision_macro: 0.09952055953467658 - val_precision_micro: 0.16815642458100558 - val_recall_macro: 0.08694614586458525 - val_recall_micro: 0.16815642458100558
#           - val_best_f1_score_macro: 0.05075291694504499 (epoch: 0) - val_best_f1_score_micro: 0.16815642458100558 (epoch: 0.16815642458100558)
# 21/21 [==============================] - 34s 1s/step - loss: 1.5478 - accuracy: 0.5540 - top-5-accuracy: 0.8495 - val_loss: 10.9424 - val_accuracy: 0.1760 - val_top-5-accuracy: 0.4525
# Epoch 2/5
# 168/168 [==============================] - 3s 20ms/step
#  - val_f1_macro: 0.3732691671516131 - val_f1_micro: 0.6612662942271881
#           - val_precision_macro: 0.4578227118484282 - val_precision_micro: 0.6612662942271881 - val_recall_macro: 0.4035504379083312 - val_recall_micro: 0.6612662942271881
#           - val_best_f1_score_macro: 0.3732691671516131 (epoch: 1) - val_best_f1_score_micro: 0.6612662942271881 (epoch: 0.6612662942271881)
# 21/21 [==============================] - 17s 813ms/step - loss: 0.6269 - accuracy: 0.7847 - top-5-accuracy: 0.9810 - val_loss: 1.2985 - val_accuracy: 0.6860 - val_top-5-accuracy: 0.9693
# Epoch 3/5
# 168/168 [==============================] - 3s 20ms/step
#  - val_f1_macro: 0.4767924931519783 - val_f1_micro: 0.7823091247672254
#           - val_precision_macro: 0.5209461281809672 - val_precision_micro: 0.7823091247672254 - val_recall_macro: 0.47870183118830884 - val_recall_micro: 0.7823091247672254
#           - val_best_f1_score_macro: 0.4767924931519783 (epoch: 2) - val_best_f1_score_micro: 0.7823091247672254 (epoch: 0.7823091247672254)
# 21/21 [==============================] - 17s 809ms/step - loss: 0.4590 - accuracy: 0.8425 - top-5-accuracy: 0.9911 - val_loss: 0.5229 - val_accuracy: 0.8285 - val_top-5-accuracy: 0.9903
# Epoch 4/5
# 168/168 [==============================] - 3s 20ms/step
#  - val_f1_macro: 0.5101741821498987 - val_f1_micro: 0.8128491620111733
#           - val_precision_macro: 0.5252713419611249 - val_precision_micro: 0.8128491620111732 - val_recall_macro: 0.521355153199936 - val_recall_micro: 0.8128491620111732
#           - val_best_f1_score_macro: 0.5101741821498987 (epoch: 3) - val_best_f1_score_micro: 0.8128491620111733 (epoch: 0.8128491620111733)
# 21/21 [==============================] - 17s 815ms/step - loss: 0.3425 - accuracy: 0.8754 - top-5-accuracy: 0.9953 - val_loss: 0.5293 - val_accuracy: 0.8346 - val_top-5-accuracy: 0.9881
# Epoch 5/5
# 168/168 [==============================] - 3s 20ms/step
#  - val_f1_macro: 0.518310615367013 - val_f1_micro: 0.8204841713221601
#           - val_precision_macro: 0.5512421208025295 - val_precision_micro: 0.8204841713221601 - val_recall_macro: 0.5314945557251698 - val_recall_micro: 0.8204841713221601
#           - val_best_f1_score_macro: 0.518310615367013 (epoch: 4) - val_best_f1_score_micro: 0.8204841713221601 (epoch: 0.8204841713221601)
# 21/21 [==============================] - 17s 809ms/step - loss: 0.2659 - accuracy: 0.9002 - top-5-accuracy: 0.9974 - val_loss: 0.5614 - val_accuracy: 0.8372 - val_top-5-accuracy: 0.9885

# %% [markdown]
# ## CMT model

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_3.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_3.summary()
# Out:
# Model: "cmt_tiny_torch"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_1_pad (ZeroPadding2D)     (None, 226, 226, 3)  0           ['input_10[0][0]']
#
#  stem_1_conv (Conv2D)           (None, 112, 112, 16  448         ['stem_1_pad[0][0]']
#                                 )
#
#  stem_1_gelu (Activation)       (None, 112, 112, 16  0           ['stem_1_conv[0][0]']
#                                 )
#
#  stem_1_bn (BatchNormalization)  (None, 112, 112, 16  64         ['stem_1_gelu[0][0]']
#                                 )
#
#  stem_2_pad (ZeroPadding2D)     (None, 114, 114, 16  0           ['stem_1_bn[0][0]']
#                                 )
#
#  stem_2_conv (Conv2D)           (None, 112, 112, 16  2320        ['stem_2_pad[0][0]']
#                                 )
#
#  stem_2_gelu (Activation)       (None, 112, 112, 16  0           ['stem_2_conv[0][0]']
#                                 )
#
#  stem_2_bn (BatchNormalization)  (None, 112, 112, 16  64         ['stem_2_gelu[0][0]']
#                                 )
#
#  stem_3_pad (ZeroPadding2D)     (None, 114, 114, 16  0           ['stem_2_bn[0][0]']
#                                 )
#
#  stem_3_conv (Conv2D)           (None, 112, 112, 16  2320        ['stem_3_pad[0][0]']
#                                 )
#
#  stem_3_gelu (Activation)       (None, 112, 112, 16  0           ['stem_3_conv[0][0]']
#                                 )
#
#  stem_3_bn (BatchNormalization)  (None, 112, 112, 16  64         ['stem_3_gelu[0][0]']
#                                 )
#
#  stack1_down_sampleconv (Conv2D  (None, 56, 56, 46)  2990        ['stem_3_bn[0][0]']
#  )
#
#  stack1_ln (LayerNormalization)  (None, 56, 56, 46)  92          ['stack1_down_sampleconv[0][0]']
#
#  stack1_block1_pad (ZeroPadding  (None, 58, 58, 46)  0           ['stack1_ln[0][0]']
#  2D)
#
#  stack1_block1_dw_conv (Depthwi  (None, 56, 56, 46)  460         ['stack1_block1_pad[0][0]']
#  seConv2D)
#
#  stack1_block1_lpu_out (Add)    (None, 56, 56, 46)   0           ['stack1_ln[0][0]',
#                                                                   'stack1_block1_dw_conv[0][0]']
#
#  stack1_block1_attn_ln (LayerNo  (None, 56, 56, 46)  92          ['stack1_block1_lpu_out[0][0]']
#  rmalization)
#
#  stack1_block1_light_mhsa_kv_sr  (None, 7, 7, 46)    2990        ['stack1_block1_attn_ln[0][0]']
#  _dw_conv (DepthwiseConv2D)
#
#  stack1_block1_light_mhsa_kv_sr  (None, 7, 7, 46)    184         ['stack1_block1_light_mhsa_kv_sr_
#  _bn (BatchNormalization)                                        dw_conv[0][0]']
#
#  stack1_block1_light_mhsa_key_v  (None, 7, 7, 92)    4324        ['stack1_block1_light_mhsa_kv_sr_
#  alue_conv (Conv2D)                                              bn[0][0]']
#
#  stack1_block1_light_mhsa_query  (None, 56, 56, 46)  2162        ['stack1_block1_attn_ln[0][0]']
#  _conv (Conv2D)
#
#  tf.split_110 (TFOpLambda)      [(None, 7, 7, 46),   0           ['stack1_block1_light_mhsa_key_va
#                                  (None, 7, 7, 46)]               lue_conv[0][0]']
#
#  tf.reshape_558 (TFOpLambda)    (None, 3136, 1, 46)  0           ['stack1_block1_light_mhsa_query_
#                                                                  conv[0][0]']
#
#  tf.reshape_559 (TFOpLambda)    (None, 49, 1, 46)    0           ['tf.split_110[0][0]']
#
#  tf.compat.v1.transpose_452 (TF  (None, 1, 3136, 46)  0          ['tf.reshape_558[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_453 (TF  (None, 1, 46, 49)   0           ['tf.reshape_559[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_220 (TFOpLamb  (None, 1, 3136, 49)  0          ['tf.compat.v1.transpose_452[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_453[0][0
#                                                                  ]']
#
#  tf.math.multiply_110 (TFOpLamb  (None, 1, 3136, 49)  0          ['tf.linalg.matmul_220[0][0]']
#  da)
#
#  stack1_pos_emb (BiasPositional  (None, 1, 3136, 49)  153664     ['tf.math.multiply_110[0][0]',
#  Embedding)                                                       'tf.math.multiply_111[0][0]']
#
#  tf.reshape_560 (TFOpLambda)    (None, 49, 1, 46)    0           ['tf.split_110[0][1]']
#
#  stack1_block1_light_mhsa_atten  (None, 1, 3136, 49)  0          ['stack1_pos_emb[0][0]']
#  tion_scores (Softmax)
#
#  tf.compat.v1.transpose_454 (TF  (None, 1, 49, 46)   0           ['tf.reshape_560[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_221 (TFOpLamb  (None, 1, 3136, 46)  0          ['stack1_block1_light_mhsa_attent
#  da)                                                             ion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_454[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_455 (TF  (None, 3136, 1, 46)  0          ['tf.linalg.matmul_221[0][0]']
#  OpLambda)
#
#  tf.reshape_561 (TFOpLambda)    (None, 56, 56, 46)   0           ['tf.compat.v1.transpose_455[0][0
#                                                                  ]']
#
#  stack1_block1_light_mhsa_outpu  (None, 56, 56, 46)  2162        ['tf.reshape_561[0][0]']
#  t (Dense)
#
#  stack1_block1_attn_out (Add)   (None, 56, 56, 46)   0           ['stack1_block1_lpu_out[0][0]',
#                                                                   'stack1_block1_light_mhsa_output
#                                                                  [0][0]']
#
#  stack1_block1_ffn_ln (LayerNor  (None, 56, 56, 46)  92          ['stack1_block1_attn_out[0][0]']
#  malization)
#
#  stack1_block1_ffn_1_conv (Conv  (None, 56, 56, 165)  7755       ['stack1_block1_ffn_ln[0][0]']
#  2D)
#
#  stack1_block1_ffn_1_gelu (Acti  (None, 56, 56, 165)  0          ['stack1_block1_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack1_block1_ffn_1_bn (BatchN  (None, 56, 56, 165)  660        ['stack1_block1_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block1_ffn_pad (ZeroPad  (None, 58, 58, 165)  0          ['stack1_block1_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack1_block1_ffn_dw_conv (Dep  (None, 56, 56, 165)  1650       ['stack1_block1_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack1_block1_ffn_dw_add (Add)  (None, 56, 56, 165)  0          ['stack1_block1_ffn_1_bn[0][0]',
#                                                                   'stack1_block1_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack1_block1_ffn_2_gelu (Acti  (None, 56, 56, 165)  0          ['stack1_block1_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack1_block1_ffn_2_bn (BatchN  (None, 56, 56, 165)  660        ['stack1_block1_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block1_ffn_3_conv (Conv  (None, 56, 56, 46)  7636        ['stack1_block1_ffn_2_bn[0][0]']
#  2D)
#
#  stack1_block1_ffn_3_bn (BatchN  (None, 56, 56, 46)  184         ['stack1_block1_ffn_3_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block1_ffn_output (Add)  (None, 56, 56, 46)  0           ['stack1_block1_attn_out[0][0]',
#                                                                   'stack1_block1_ffn_3_bn[0][0]']
#
#  stack1_block2_pad (ZeroPadding  (None, 58, 58, 46)  0           ['stack1_block1_ffn_output[0][0]'
#  2D)                                                             ]
#
#  stack1_block2_dw_conv (Depthwi  (None, 56, 56, 46)  460         ['stack1_block2_pad[0][0]']
#  seConv2D)
#
#  stack1_block2_lpu_out (Add)    (None, 56, 56, 46)   0           ['stack1_block1_ffn_output[0][0]'
#                                                                  , 'stack1_block2_dw_conv[0][0]']
#
#  stack1_block2_attn_ln (LayerNo  (None, 56, 56, 46)  92          ['stack1_block2_lpu_out[0][0]']
#  rmalization)
#
#  stack1_block2_light_mhsa_kv_sr  (None, 7, 7, 46)    2990        ['stack1_block2_attn_ln[0][0]']
#  _dw_conv (DepthwiseConv2D)
#
#  stack1_block2_light_mhsa_kv_sr  (None, 7, 7, 46)    184         ['stack1_block2_light_mhsa_kv_sr_
#  _bn (BatchNormalization)                                        dw_conv[0][0]']
#
#  stack1_block2_light_mhsa_key_v  (None, 7, 7, 92)    4324        ['stack1_block2_light_mhsa_kv_sr_
#  alue_conv (Conv2D)                                              bn[0][0]']
#
#  stack1_block2_light_mhsa_query  (None, 56, 56, 46)  2162        ['stack1_block2_attn_ln[0][0]']
#  _conv (Conv2D)
#
#  tf.split_111 (TFOpLambda)      [(None, 7, 7, 46),   0           ['stack1_block2_light_mhsa_key_va
#                                  (None, 7, 7, 46)]               lue_conv[0][0]']
#
#  tf.reshape_562 (TFOpLambda)    (None, 3136, 1, 46)  0           ['stack1_block2_light_mhsa_query_
#                                                                  conv[0][0]']
#
#  tf.reshape_563 (TFOpLambda)    (None, 49, 1, 46)    0           ['tf.split_111[0][0]']
#
#  tf.compat.v1.transpose_456 (TF  (None, 1, 3136, 46)  0          ['tf.reshape_562[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_457 (TF  (None, 1, 46, 49)   0           ['tf.reshape_563[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_222 (TFOpLamb  (None, 1, 3136, 49)  0          ['tf.compat.v1.transpose_456[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_457[0][0
#                                                                  ]']
#
#  tf.math.multiply_111 (TFOpLamb  (None, 1, 3136, 49)  0          ['tf.linalg.matmul_222[0][0]']
#  da)
#
#  tf.reshape_564 (TFOpLambda)    (None, 49, 1, 46)    0           ['tf.split_111[0][1]']
#
#  stack1_block2_light_mhsa_atten  (None, 1, 3136, 49)  0          ['stack1_pos_emb[1][0]']
#  tion_scores (Softmax)
#
#  tf.compat.v1.transpose_458 (TF  (None, 1, 49, 46)   0           ['tf.reshape_564[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_223 (TFOpLamb  (None, 1, 3136, 46)  0          ['stack1_block2_light_mhsa_attent
#  da)                                                             ion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_458[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_459 (TF  (None, 3136, 1, 46)  0          ['tf.linalg.matmul_223[0][0]']
#  OpLambda)
#
#  tf.reshape_565 (TFOpLambda)    (None, 56, 56, 46)   0           ['tf.compat.v1.transpose_459[0][0
#                                                                  ]']
#
#  stack1_block2_light_mhsa_outpu  (None, 56, 56, 46)  2162        ['tf.reshape_565[0][0]']
#  t (Dense)
#
#  stack1_block2_attn_out (Add)   (None, 56, 56, 46)   0           ['stack1_block2_lpu_out[0][0]',
#                                                                   'stack1_block2_light_mhsa_output
#                                                                  [0][0]']
#
#  stack1_block2_ffn_ln (LayerNor  (None, 56, 56, 46)  92          ['stack1_block2_attn_out[0][0]']
#  malization)
#
#  stack1_block2_ffn_1_conv (Conv  (None, 56, 56, 165)  7755       ['stack1_block2_ffn_ln[0][0]']
#  2D)
#
#  stack1_block2_ffn_1_gelu (Acti  (None, 56, 56, 165)  0          ['stack1_block2_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack1_block2_ffn_1_bn (BatchN  (None, 56, 56, 165)  660        ['stack1_block2_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block2_ffn_pad (ZeroPad  (None, 58, 58, 165)  0          ['stack1_block2_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack1_block2_ffn_dw_conv (Dep  (None, 56, 56, 165)  1650       ['stack1_block2_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack1_block2_ffn_dw_add (Add)  (None, 56, 56, 165)  0          ['stack1_block2_ffn_1_bn[0][0]',
#                                                                   'stack1_block2_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack1_block2_ffn_2_gelu (Acti  (None, 56, 56, 165)  0          ['stack1_block2_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack1_block2_ffn_2_bn (BatchN  (None, 56, 56, 165)  660        ['stack1_block2_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block2_ffn_3_conv (Conv  (None, 56, 56, 46)  7636        ['stack1_block2_ffn_2_bn[0][0]']
#  2D)
#
#  stack1_block2_ffn_3_bn (BatchN  (None, 56, 56, 46)  184         ['stack1_block2_ffn_3_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack1_block2_ffn_output (Add)  (None, 56, 56, 46)  0           ['stack1_block2_attn_out[0][0]',
#                                                                   'stack1_block2_ffn_3_bn[0][0]']
#
#  stack2_down_sampleconv (Conv2D  (None, 28, 28, 92)  17020       ['stack1_block2_ffn_output[0][0]'
#  )                                                               ]
#
#  stack2_ln (LayerNormalization)  (None, 28, 28, 92)  184         ['stack2_down_sampleconv[0][0]']
#
#  stack2_block1_pad (ZeroPadding  (None, 30, 30, 92)  0           ['stack2_ln[0][0]']
#  2D)
#
#  stack2_block1_dw_conv (Depthwi  (None, 28, 28, 92)  920         ['stack2_block1_pad[0][0]']
#  seConv2D)
#
#  stack2_block1_lpu_out (Add)    (None, 28, 28, 92)   0           ['stack2_ln[0][0]',
#                                                                   'stack2_block1_dw_conv[0][0]']
#
#  stack2_block1_attn_ln (LayerNo  (None, 28, 28, 92)  184         ['stack2_block1_lpu_out[0][0]']
#  rmalization)
#
#  stack2_block1_light_mhsa_kv_sr  (None, 7, 7, 92)    1564        ['stack2_block1_attn_ln[0][0]']
#  _dw_conv (DepthwiseConv2D)
#
#  stack2_block1_light_mhsa_kv_sr  (None, 7, 7, 92)    368         ['stack2_block1_light_mhsa_kv_sr_
#  _bn (BatchNormalization)                                        dw_conv[0][0]']
#
#  stack2_block1_light_mhsa_key_v  (None, 7, 7, 184)   17112       ['stack2_block1_light_mhsa_kv_sr_
#  alue_conv (Conv2D)                                              bn[0][0]']
#
#  stack2_block1_light_mhsa_query  (None, 28, 28, 92)  8556        ['stack2_block1_attn_ln[0][0]']
#  _conv (Conv2D)
#
#  tf.split_112 (TFOpLambda)      [(None, 7, 7, 92),   0           ['stack2_block1_light_mhsa_key_va
#                                  (None, 7, 7, 92)]               lue_conv[0][0]']
#
#  tf.reshape_566 (TFOpLambda)    (None, 784, 2, 46)   0           ['stack2_block1_light_mhsa_query_
#                                                                  conv[0][0]']
#
#  tf.reshape_567 (TFOpLambda)    (None, 49, 2, 46)    0           ['tf.split_112[0][0]']
#
#  tf.compat.v1.transpose_460 (TF  (None, 2, 784, 46)  0           ['tf.reshape_566[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_461 (TF  (None, 2, 46, 49)   0           ['tf.reshape_567[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_224 (TFOpLamb  (None, 2, 784, 49)  0           ['tf.compat.v1.transpose_460[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_461[0][0
#                                                                  ]']
#
#  tf.math.multiply_112 (TFOpLamb  (None, 2, 784, 49)  0           ['tf.linalg.matmul_224[0][0]']
#  da)
#
#  stack2_pos_emb (BiasPositional  (None, 2, 784, 49)  76832       ['tf.math.multiply_112[0][0]',
#  Embedding)                                                       'tf.math.multiply_113[0][0]']
#
#  tf.reshape_568 (TFOpLambda)    (None, 49, 2, 46)    0           ['tf.split_112[0][1]']
#
#  stack2_block1_light_mhsa_atten  (None, 2, 784, 49)  0           ['stack2_pos_emb[0][0]']
#  tion_scores (Softmax)
#
#  tf.compat.v1.transpose_462 (TF  (None, 2, 49, 46)   0           ['tf.reshape_568[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_225 (TFOpLamb  (None, 2, 784, 46)  0           ['stack2_block1_light_mhsa_attent
#  da)                                                             ion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_462[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_463 (TF  (None, 784, 2, 46)  0           ['tf.linalg.matmul_225[0][0]']
#  OpLambda)
#
#  tf.reshape_569 (TFOpLambda)    (None, 28, 28, 92)   0           ['tf.compat.v1.transpose_463[0][0
#                                                                  ]']
#
#  stack2_block1_light_mhsa_outpu  (None, 28, 28, 92)  8556        ['tf.reshape_569[0][0]']
#  t (Dense)
#
#  stack2_block1_attn_out (Add)   (None, 28, 28, 92)   0           ['stack2_block1_lpu_out[0][0]',
#                                                                   'stack2_block1_light_mhsa_output
#                                                                  [0][0]']
#
#  stack2_block1_ffn_ln (LayerNor  (None, 28, 28, 92)  184         ['stack2_block1_attn_out[0][0]']
#  malization)
#
#  stack2_block1_ffn_1_conv (Conv  (None, 28, 28, 331)  30783      ['stack2_block1_ffn_ln[0][0]']
#  2D)
#
#  stack2_block1_ffn_1_gelu (Acti  (None, 28, 28, 331)  0          ['stack2_block1_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack2_block1_ffn_1_bn (BatchN  (None, 28, 28, 331)  1324       ['stack2_block1_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack2_block1_ffn_pad (ZeroPad  (None, 30, 30, 331)  0          ['stack2_block1_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack2_block1_ffn_dw_conv (Dep  (None, 28, 28, 331)  3310       ['stack2_block1_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack2_block1_ffn_dw_add (Add)  (None, 28, 28, 331)  0          ['stack2_block1_ffn_1_bn[0][0]',
#                                                                   'stack2_block1_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack2_block1_ffn_2_gelu (Acti  (None, 28, 28, 331)  0          ['stack2_block1_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack2_block1_ffn_2_bn (BatchN  (None, 28, 28, 331)  1324       ['stack2_block1_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack2_block1_ffn_3_conv (Conv  (None, 28, 28, 92)  30544       ['stack2_block1_ffn_2_bn[0][0]']
#  2D)
#
#  stack2_block1_ffn_3_bn (BatchN  (None, 28, 28, 92)  368         ['stack2_block1_ffn_3_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack2_block1_ffn_output (Add)  (None, 28, 28, 92)  0           ['stack2_block1_attn_out[0][0]',
#                                                                   'stack2_block1_ffn_3_bn[0][0]']
#
#  stack2_block2_pad (ZeroPadding  (None, 30, 30, 92)  0           ['stack2_block1_ffn_output[0][0]'
#  2D)                                                             ]
#
#  stack2_block2_dw_conv (Depthwi  (None, 28, 28, 92)  920         ['stack2_block2_pad[0][0]']
#  seConv2D)
#
#  stack2_block2_lpu_out (Add)    (None, 28, 28, 92)   0           ['stack2_block1_ffn_output[0][0]'
#                                                                  , 'stack2_block2_dw_conv[0][0]']
#
#  stack2_block2_attn_ln (LayerNo  (None, 28, 28, 92)  184         ['stack2_block2_lpu_out[0][0]']
#  rmalization)
#
#  stack2_block2_light_mhsa_kv_sr  (None, 7, 7, 92)    1564        ['stack2_block2_attn_ln[0][0]']
#  _dw_conv (DepthwiseConv2D)
#
#  stack2_block2_light_mhsa_kv_sr  (None, 7, 7, 92)    368         ['stack2_block2_light_mhsa_kv_sr_
#  _bn (BatchNormalization)                                        dw_conv[0][0]']
#
#  stack2_block2_light_mhsa_key_v  (None, 7, 7, 184)   17112       ['stack2_block2_light_mhsa_kv_sr_
#  alue_conv (Conv2D)                                              bn[0][0]']
#
#  stack2_block2_light_mhsa_query  (None, 28, 28, 92)  8556        ['stack2_block2_attn_ln[0][0]']
#  _conv (Conv2D)
#
#  tf.split_113 (TFOpLambda)      [(None, 7, 7, 92),   0           ['stack2_block2_light_mhsa_key_va
#                                  (None, 7, 7, 92)]               lue_conv[0][0]']
#
#  tf.reshape_570 (TFOpLambda)    (None, 784, 2, 46)   0           ['stack2_block2_light_mhsa_query_
#                                                                  conv[0][0]']
#
#  tf.reshape_571 (TFOpLambda)    (None, 49, 2, 46)    0           ['tf.split_113[0][0]']
#
#  tf.compat.v1.transpose_464 (TF  (None, 2, 784, 46)  0           ['tf.reshape_570[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_465 (TF  (None, 2, 46, 49)   0           ['tf.reshape_571[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_226 (TFOpLamb  (None, 2, 784, 49)  0           ['tf.compat.v1.transpose_464[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_465[0][0
#                                                                  ]']
#
#  tf.math.multiply_113 (TFOpLamb  (None, 2, 784, 49)  0           ['tf.linalg.matmul_226[0][0]']
#  da)
#
#  tf.reshape_572 (TFOpLambda)    (None, 49, 2, 46)    0           ['tf.split_113[0][1]']
#
#  stack2_block2_light_mhsa_atten  (None, 2, 784, 49)  0           ['stack2_pos_emb[1][0]']
#  tion_scores (Softmax)
#
#  tf.compat.v1.transpose_466 (TF  (None, 2, 49, 46)   0           ['tf.reshape_572[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_227 (TFOpLamb  (None, 2, 784, 46)  0           ['stack2_block2_light_mhsa_attent
#  da)                                                             ion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_466[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_467 (TF  (None, 784, 2, 46)  0           ['tf.linalg.matmul_227[0][0]']
#  OpLambda)
#
#  tf.reshape_573 (TFOpLambda)    (None, 28, 28, 92)   0           ['tf.compat.v1.transpose_467[0][0
#                                                                  ]']
#
#  stack2_block2_light_mhsa_outpu  (None, 28, 28, 92)  8556        ['tf.reshape_573[0][0]']
#  t (Dense)
#
#  stack2_block2_attn_out (Add)   (None, 28, 28, 92)   0           ['stack2_block2_lpu_out[0][0]',
#                                                                   'stack2_block2_light_mhsa_output
#                                                                  [0][0]']
#
#  stack2_block2_ffn_ln (LayerNor  (None, 28, 28, 92)  184         ['stack2_block2_attn_out[0][0]']
#  malization)
#
#  stack2_block2_ffn_1_conv (Conv  (None, 28, 28, 331)  30783      ['stack2_block2_ffn_ln[0][0]']
#  2D)
#
#  stack2_block2_ffn_1_gelu (Acti  (None, 28, 28, 331)  0          ['stack2_block2_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack2_block2_ffn_1_bn (BatchN  (None, 28, 28, 331)  1324       ['stack2_block2_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack2_block2_ffn_pad (ZeroPad  (None, 30, 30, 331)  0          ['stack2_block2_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack2_block2_ffn_dw_conv (Dep  (None, 28, 28, 331)  3310       ['stack2_block2_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack2_block2_ffn_dw_add (Add)  (None, 28, 28, 331)  0          ['stack2_block2_ffn_1_bn[0][0]',
#                                                                   'stack2_block2_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack2_block2_ffn_2_gelu (Acti  (None, 28, 28, 331)  0          ['stack2_block2_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack2_block2_ffn_2_bn (BatchN  (None, 28, 28, 331)  1324       ['stack2_block2_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
# ...
#
#  stack4_block1_attn_out (Add)   (None, 7, 7, 368)    0           ['stack4_block1_lpu_out[0][0]',
#                                                                   'stack4_block1_light_mhsa_output
#                                                                  [0][0]']
#
#  stack4_block1_ffn_ln (LayerNor  (None, 7, 7, 368)   736         ['stack4_block1_attn_out[0][0]']
#  malization)
#
#  stack4_block1_ffn_1_conv (Conv  (None, 7, 7, 1324)  488556      ['stack4_block1_ffn_ln[0][0]']
#  2D)
#
#  stack4_block1_ffn_1_gelu (Acti  (None, 7, 7, 1324)  0           ['stack4_block1_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack4_block1_ffn_1_bn (BatchN  (None, 7, 7, 1324)  5296        ['stack4_block1_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block1_ffn_pad (ZeroPad  (None, 9, 9, 1324)  0           ['stack4_block1_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack4_block1_ffn_dw_conv (Dep  (None, 7, 7, 1324)  13240       ['stack4_block1_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack4_block1_ffn_dw_add (Add)  (None, 7, 7, 1324)  0           ['stack4_block1_ffn_1_bn[0][0]',
#                                                                   'stack4_block1_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack4_block1_ffn_2_gelu (Acti  (None, 7, 7, 1324)  0           ['stack4_block1_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack4_block1_ffn_2_bn (BatchN  (None, 7, 7, 1324)  5296        ['stack4_block1_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block1_ffn_3_conv (Conv  (None, 7, 7, 368)   487600      ['stack4_block1_ffn_2_bn[0][0]']
#  2D)
#
#  stack4_block1_ffn_3_bn (BatchN  (None, 7, 7, 368)   1472        ['stack4_block1_ffn_3_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block1_ffn_output (Add)  (None, 7, 7, 368)   0           ['stack4_block1_attn_out[0][0]',
#                                                                   'stack4_block1_ffn_3_bn[0][0]']
#
#  stack4_block2_pad (ZeroPadding  (None, 9, 9, 368)   0           ['stack4_block1_ffn_output[0][0]'
#  2D)                                                             ]
#
#  stack4_block2_dw_conv (Depthwi  (None, 7, 7, 368)   3680        ['stack4_block2_pad[0][0]']
#  seConv2D)
#
#  stack4_block2_lpu_out (Add)    (None, 7, 7, 368)    0           ['stack4_block1_ffn_output[0][0]'
#                                                                  , 'stack4_block2_dw_conv[0][0]']
#
#  stack4_block2_attn_ln (LayerNo  (None, 7, 7, 368)   736         ['stack4_block2_lpu_out[0][0]']
#  rmalization)
#
#  stack4_block2_light_mhsa_key_v  (None, 7, 7, 736)   271584      ['stack4_block2_attn_ln[0][0]']
#  alue_conv (Conv2D)
#
#  stack4_block2_light_mhsa_query  (None, 7, 7, 368)   135792      ['stack4_block2_attn_ln[0][0]']
#  _conv (Conv2D)
#
#  tf.split_125 (TFOpLambda)      [(None, 7, 7, 368),  0           ['stack4_block2_light_mhsa_key_va
#                                  (None, 7, 7, 368)]              lue_conv[0][0]']
#
#  tf.reshape_618 (TFOpLambda)    (None, 49, 8, 46)    0           ['stack4_block2_light_mhsa_query_
#                                                                  conv[0][0]']
#
#  tf.reshape_619 (TFOpLambda)    (None, 49, 8, 46)    0           ['tf.split_125[0][0]']
#
#  tf.compat.v1.transpose_512 (TF  (None, 8, 49, 46)   0           ['tf.reshape_618[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_513 (TF  (None, 8, 46, 49)   0           ['tf.reshape_619[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_250 (TFOpLamb  (None, 8, 49, 49)   0           ['tf.compat.v1.transpose_512[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_513[0][0
#                                                                  ]']
#
#  tf.math.multiply_125 (TFOpLamb  (None, 8, 49, 49)   0           ['tf.linalg.matmul_250[0][0]']
#  da)
#
#  tf.reshape_620 (TFOpLambda)    (None, 49, 8, 46)    0           ['tf.split_125[0][1]']
#
#  stack4_block2_light_mhsa_atten  (None, 8, 49, 49)   0           ['stack4_pos_emb[1][0]']
#  tion_scores (Softmax)
#
#  tf.compat.v1.transpose_514 (TF  (None, 8, 49, 46)   0           ['tf.reshape_620[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_251 (TFOpLamb  (None, 8, 49, 46)   0           ['stack4_block2_light_mhsa_attent
#  da)                                                             ion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_514[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_515 (TF  (None, 49, 8, 46)   0           ['tf.linalg.matmul_251[0][0]']
#  OpLambda)
#
#  tf.reshape_621 (TFOpLambda)    (None, 7, 7, 368)    0           ['tf.compat.v1.transpose_515[0][0
#                                                                  ]']
#
#  stack4_block2_light_mhsa_outpu  (None, 7, 7, 368)   135792      ['tf.reshape_621[0][0]']
#  t (Dense)
#
#  stack4_block2_attn_out (Add)   (None, 7, 7, 368)    0           ['stack4_block2_lpu_out[0][0]',
#                                                                   'stack4_block2_light_mhsa_output
#                                                                  [0][0]']
#
#  stack4_block2_ffn_ln (LayerNor  (None, 7, 7, 368)   736         ['stack4_block2_attn_out[0][0]']
#  malization)
#
#  stack4_block2_ffn_1_conv (Conv  (None, 7, 7, 1324)  488556      ['stack4_block2_ffn_ln[0][0]']
#  2D)
#
#  stack4_block2_ffn_1_gelu (Acti  (None, 7, 7, 1324)  0           ['stack4_block2_ffn_1_conv[0][0]'
#  vation)                                                         ]
#
#  stack4_block2_ffn_1_bn (BatchN  (None, 7, 7, 1324)  5296        ['stack4_block2_ffn_1_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block2_ffn_pad (ZeroPad  (None, 9, 9, 1324)  0           ['stack4_block2_ffn_1_bn[0][0]']
#  ding2D)
#
#  stack4_block2_ffn_dw_conv (Dep  (None, 7, 7, 1324)  13240       ['stack4_block2_ffn_pad[0][0]']
#  thwiseConv2D)
#
#  stack4_block2_ffn_dw_add (Add)  (None, 7, 7, 1324)  0           ['stack4_block2_ffn_1_bn[0][0]',
#                                                                   'stack4_block2_ffn_dw_conv[0][0]
#                                                                  ']
#
#  stack4_block2_ffn_2_gelu (Acti  (None, 7, 7, 1324)  0           ['stack4_block2_ffn_dw_add[0][0]'
#  vation)                                                         ]
#
#  stack4_block2_ffn_2_bn (BatchN  (None, 7, 7, 1324)  5296        ['stack4_block2_ffn_2_gelu[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block2_ffn_3_conv (Conv  (None, 7, 7, 368)   487600      ['stack4_block2_ffn_2_bn[0][0]']
#  2D)
#
#  stack4_block2_ffn_3_bn (BatchN  (None, 7, 7, 368)   1472        ['stack4_block2_ffn_3_conv[0][0]'
#  ormalization)                                                   ]
#
#  stack4_block2_ffn_output (Add)  (None, 7, 7, 368)   0           ['stack4_block2_attn_out[0][0]',
#                                                                   'stack4_block2_ffn_3_bn[0][0]']
#
#  features_conv (Conv2D)         (None, 7, 7, 1280)   472320      ['stack4_block2_ffn_output[0][0]'
#                                                                  ]
#
#  features_bn (BatchNormalizatio  (None, 7, 7, 1280)  5120        ['features_conv[0][0]']
#  n)
#
#  features_swish (Activation)    (None, 7, 7, 1280)   0           ['features_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['features_swish[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 23)           29463       ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 8,507,641
# Trainable params: 8,454,009
# Non-trainable params: 53,632
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_3.fit(X_train, 
                  y_train, 
                  batch_size=128, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
# 168/168 [==============================] - 11s 43ms/step
#  - val_f1_macro: 0.4634533083546173 - val_f1_micro: 0.7541899441340782
#           - val_precision_macro: 0.5234864125221871 - val_precision_micro: 0.7541899441340782 - val_recall_macro: 0.45137467673170745 - val_recall_micro: 0.7541899441340782
#           - val_best_f1_score_macro: 0.4634533083546173 (epoch: 0) - val_best_f1_score_micro: 0.7541899441340782 (epoch: 0.7541899441340782)
# 42/42 [==============================] - 40s 938ms/step - loss: 0.8095 - accuracy: 0.7428 - top-5-accuracy: 0.9527 - val_loss: 0.5409 - val_accuracy: 0.8117 - val_top-5-accuracy: 0.9894
# Epoch 2/5
# 168/168 [==============================] - 7s 42ms/step
#  - val_f1_macro: 0.4979252317064144 - val_f1_micro: 0.8108007448789571
#           - val_precision_macro: 0.5653687287010227 - val_precision_micro: 0.8108007448789571 - val_recall_macro: 0.512170582754925 - val_recall_micro: 0.8108007448789571
#           - val_best_f1_score_macro: 0.4979252317064144 (epoch: 1) - val_best_f1_score_micro: 0.8108007448789571 (epoch: 0.8108007448789571)
# 42/42 [==============================] - 30s 717ms/step - loss: 0.3756 - accuracy: 0.8670 - top-5-accuracy: 0.9937 - val_loss: 0.4918 - val_accuracy: 0.8400 - val_top-5-accuracy: 0.9914
# Epoch 3/5
# 168/168 [==============================] - 7s 42ms/step
#  - val_f1_macro: 0.5488917577095586 - val_f1_micro: 0.8461824953445065
#           - val_precision_macro: 0.5911441804259413 - val_precision_micro: 0.8461824953445065 - val_recall_macro: 0.5416340926224218 - val_recall_micro: 0.8461824953445065
#           - val_best_f1_score_macro: 0.5488917577095586 (epoch: 2) - val_best_f1_score_micro: 0.8461824953445065 (epoch: 0.8461824953445065)
# 42/42 [==============================] - 30s 716ms/step - loss: 0.2796 - accuracy: 0.9028 - top-5-accuracy: 0.9968 - val_loss: 0.3869 - val_accuracy: 0.8715 - val_top-5-accuracy: 0.9948
# Epoch 4/5
# 168/168 [==============================] - 7s 42ms/step
#  - val_f1_macro: 0.5328871734660354 - val_f1_micro: 0.8610800744878957
#           - val_precision_macro: 0.5955493062733013 - val_precision_micro: 0.8610800744878957 - val_recall_macro: 0.5417294917748244 - val_recall_micro: 0.8610800744878957
#           - val_best_f1_score_macro: 0.5488917577095586 (epoch: 2) - val_best_f1_score_micro: 0.8610800744878957 (epoch: 0.8610800744878957)
# 42/42 [==============================] - 30s 716ms/step - loss: 0.1895 - accuracy: 0.9369 - top-5-accuracy: 0.9983 - val_loss: 0.4641 - val_accuracy: 0.8702 - val_top-5-accuracy: 0.9903
# Epoch 5/5
# 168/168 [==============================] - 7s 42ms/step
#  - val_f1_macro: 0.5295320970197251 - val_f1_micro: 0.8296089385474861
#           - val_precision_macro: 0.5605598007364897 - val_precision_micro: 0.8296089385474861 - val_recall_macro: 0.5391957298654283 - val_recall_micro: 0.8296089385474861
#           - val_best_f1_score_macro: 0.5488917577095586 (epoch: 2) - val_best_f1_score_micro: 0.8610800744878957 (epoch: 0.8610800744878957)
# 42/42 [==============================] - 30s 717ms/step - loss: 0.1753 - accuracy: 0.9391 - top-5-accuracy: 0.9993 - val_loss: 0.5312 - val_accuracy: 0.8488 - val_top-5-accuracy: 0.9903

# %% [markdown]
# ## CoAtNet

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_4.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_4.summary()
# Out:
# Model: "coatnet0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_1_pad (ZeroPadding2D)     (None, 226, 226, 3)  0           ['input_14[0][0]']
#
#  stem_1_conv (Conv2D)           (None, 112, 112, 64  1728        ['stem_1_pad[0][0]']
#                                 )
#
#  stem_1_bn (BatchNormalization)  (None, 112, 112, 64  256        ['stem_1_conv[0][0]']
#                                 )
#
#  stem_1_gelu (Activation)       (None, 112, 112, 64  0           ['stem_1_bn[0][0]']
#                                 )
#
#  stem_2_pad (ZeroPadding2D)     (None, 114, 114, 64  0           ['stem_1_gelu[0][0]']
#                                 )
#
#  stem_2_conv (Conv2D)           (None, 112, 112, 64  36864       ['stem_2_pad[0][0]']
#                                 )
#
#  stack_1_block_1_preact_bn (Bat  (None, 112, 112, 64  256        ['stem_2_conv[0][0]']
#  chNormalization)               )
#
#  stack_1_block_1_expand_pad (Ze  (None, 112, 112, 64  0          ['stack_1_block_1_preact_bn[0][0]
#  roPadding2D)                   )                                ']
#
#  stack_1_block_1_expand_conv (C  (None, 112, 112, 25  16384      ['stack_1_block_1_expand_pad[0][0
#  onv2D)                         6)                               ]']
#
#  stack_1_block_1_expand_bn (Bat  (None, 112, 112, 25  1024       ['stack_1_block_1_expand_conv[0][
#  chNormalization)               6)                               0]']
#
#  stack_1_block_1_expand_gelu (A  (None, 112, 112, 25  0          ['stack_1_block_1_expand_bn[0][0]
#  ctivation)                     6)                               ']
#
#  stack_1_block_1_MB_pad (ZeroPa  (None, 114, 114, 25  0          ['stack_1_block_1_expand_gelu[0][
#  dding2D)                       6)                               0]']
#
#  stack_1_block_1_MB_dw_conv (De  (None, 56, 56, 256)  2304       ['stack_1_block_1_MB_pad[0][0]']
#  pthwiseConv2D)
#
#  stack_1_block_1_MB_dw_bn (Batc  (None, 56, 56, 256)  1024       ['stack_1_block_1_MB_dw_conv[0][0
#  hNormalization)                                                 ]']
#
#  stack_1_block_1_MB_dw_gelu (Ac  (None, 56, 56, 256)  0          ['stack_1_block_1_MB_dw_bn[0][0]'
#  tivation)                                                       ]
#
#  tf.math.reduce_mean_31 (TFOpLa  (None, 1, 1, 256)   0           ['stack_1_block_1_MB_dw_gelu[0][0
#  mbda)                                                           ]']
#
#  stack_1_block_1_se_1_conv (Con  (None, 1, 1, 16)    4112        ['tf.math.reduce_mean_31[0][0]']
#  v2D)
#
#  stack_1_block_1_se_gelu (Activ  (None, 1, 1, 16)    0           ['stack_1_block_1_se_1_conv[0][0]
#  ation)                                                          ']
#
#  stack_1_block_1_se_2_conv (Con  (None, 1, 1, 256)   4352        ['stack_1_block_1_se_gelu[0][0]']
#  v2D)
#
#  stack_1_block_1_se_sigmoid (Ac  (None, 1, 1, 256)   0           ['stack_1_block_1_se_2_conv[0][0]
#  tivation)                                                       ']
#
#  stack_1_block_1_se_out (Multip  (None, 56, 56, 256)  0          ['stack_1_block_1_MB_dw_gelu[0][0
#  ly)                                                             ]',
#                                                                   'stack_1_block_1_se_sigmoid[0][0
#                                                                  ]']
#
#  stack_1_block_1_shortcut_pool   (None, 56, 56, 64)  0           ['stem_2_conv[0][0]']
#  (MaxPooling2D)
#
#  stack_1_block_1_MB_pw_pad (Zer  (None, 56, 56, 256)  0          ['stack_1_block_1_se_out[0][0]']
#  oPadding2D)
#
#  stack_1_block_1_shortcut_conv   (None, 56, 56, 96)  6144        ['stack_1_block_1_shortcut_pool[0
#  (Conv2D)                                                        ][0]']
#
#  stack_1_block_1_MB_pw_conv (Co  (None, 56, 56, 96)  24576       ['stack_1_block_1_MB_pw_pad[0][0]
#  nv2D)                                                           ']
#
#  stack_1_block_1_output (Add)   (None, 56, 56, 96)   0           ['stack_1_block_1_shortcut_conv[0
#                                                                  ][0]',
#                                                                   'stack_1_block_1_MB_pw_conv[0][0
#                                                                  ]']
#
#  stack_1_block_2_preact_bn (Bat  (None, 56, 56, 96)  384         ['stack_1_block_1_output[0][0]']
#  chNormalization)
#
#  stack_1_block_2_expand_pad (Ze  (None, 56, 56, 96)  0           ['stack_1_block_2_preact_bn[0][0]
#  roPadding2D)                                                    ']
#
#  stack_1_block_2_expand_conv (C  (None, 56, 56, 384)  36864      ['stack_1_block_2_expand_pad[0][0
#  onv2D)                                                          ]']
#
#  stack_1_block_2_expand_bn (Bat  (None, 56, 56, 384)  1536       ['stack_1_block_2_expand_conv[0][
#  chNormalization)                                                0]']
#
#  stack_1_block_2_expand_gelu (A  (None, 56, 56, 384)  0          ['stack_1_block_2_expand_bn[0][0]
#  ctivation)                                                      ']
#
#  stack_1_block_2_MB_pad (ZeroPa  (None, 58, 58, 384)  0          ['stack_1_block_2_expand_gelu[0][
#  dding2D)                                                        0]']
#
#  stack_1_block_2_MB_dw_conv (De  (None, 56, 56, 384)  3456       ['stack_1_block_2_MB_pad[0][0]']
#  pthwiseConv2D)
#
#  stack_1_block_2_MB_dw_bn (Batc  (None, 56, 56, 384)  1536       ['stack_1_block_2_MB_dw_conv[0][0
#  hNormalization)                                                 ]']
#
#  stack_1_block_2_MB_dw_gelu (Ac  (None, 56, 56, 384)  0          ['stack_1_block_2_MB_dw_bn[0][0]'
#  tivation)                                                       ]
#
#  tf.math.reduce_mean_32 (TFOpLa  (None, 1, 1, 384)   0           ['stack_1_block_2_MB_dw_gelu[0][0
#  mbda)                                                           ]']
#
#  stack_1_block_2_se_1_conv (Con  (None, 1, 1, 24)    9240        ['tf.math.reduce_mean_32[0][0]']
#  v2D)
#
#  stack_1_block_2_se_gelu (Activ  (None, 1, 1, 24)    0           ['stack_1_block_2_se_1_conv[0][0]
#  ation)                                                          ']
#
#  stack_1_block_2_se_2_conv (Con  (None, 1, 1, 384)   9600        ['stack_1_block_2_se_gelu[0][0]']
#  v2D)
#
#  stack_1_block_2_se_sigmoid (Ac  (None, 1, 1, 384)   0           ['stack_1_block_2_se_2_conv[0][0]
#  tivation)                                                       ']
#
#  stack_1_block_2_se_out (Multip  (None, 56, 56, 384)  0          ['stack_1_block_2_MB_dw_gelu[0][0
#  ly)                                                             ]',
#                                                                   'stack_1_block_2_se_sigmoid[0][0
#                                                                  ]']
#
#  stack_1_block_2_MB_pw_pad (Zer  (None, 56, 56, 384)  0          ['stack_1_block_2_se_out[0][0]']
#  oPadding2D)
#
#  stack_1_block_2_MB_pw_conv (Co  (None, 56, 56, 96)  36864       ['stack_1_block_2_MB_pw_pad[0][0]
#  nv2D)                                                           ']
#
#  stack_1_block_2_output (Add)   (None, 56, 56, 96)   0           ['stack_1_block_1_output[0][0]',
#                                                                   'stack_1_block_2_MB_pw_conv[0][0
#                                                                  ]']
#
#  stack_2_block_1_preact_bn (Bat  (None, 56, 56, 96)  384         ['stack_1_block_2_output[0][0]']
#  chNormalization)
#
#  stack_2_block_1_expand_pad (Ze  (None, 56, 56, 96)  0           ['stack_2_block_1_preact_bn[0][0]
#  roPadding2D)                                                    ']
#
#  stack_2_block_1_expand_conv (C  (None, 56, 56, 384)  36864      ['stack_2_block_1_expand_pad[0][0
#  onv2D)                                                          ]']
#
#  stack_2_block_1_expand_bn (Bat  (None, 56, 56, 384)  1536       ['stack_2_block_1_expand_conv[0][
#  chNormalization)                                                0]']
#
#  stack_2_block_1_expand_gelu (A  (None, 56, 56, 384)  0          ['stack_2_block_1_expand_bn[0][0]
#  ctivation)                                                      ']
#
#  stack_2_block_1_MB_pad (ZeroPa  (None, 58, 58, 384)  0          ['stack_2_block_1_expand_gelu[0][
#  dding2D)                                                        0]']
#
#  stack_2_block_1_MB_dw_conv (De  (None, 28, 28, 384)  3456       ['stack_2_block_1_MB_pad[0][0]']
#  pthwiseConv2D)
#
#  stack_2_block_1_MB_dw_bn (Batc  (None, 28, 28, 384)  1536       ['stack_2_block_1_MB_dw_conv[0][0
#  hNormalization)                                                 ]']
#
#  stack_2_block_1_MB_dw_gelu (Ac  (None, 28, 28, 384)  0          ['stack_2_block_1_MB_dw_bn[0][0]'
#  tivation)                                                       ]
#
#  tf.math.reduce_mean_33 (TFOpLa  (None, 1, 1, 384)   0           ['stack_2_block_1_MB_dw_gelu[0][0
#  mbda)                                                           ]']
#
#  stack_2_block_1_se_1_conv (Con  (None, 1, 1, 24)    9240        ['tf.math.reduce_mean_33[0][0]']
#  v2D)
#
#  stack_2_block_1_se_gelu (Activ  (None, 1, 1, 24)    0           ['stack_2_block_1_se_1_conv[0][0]
#  ation)                                                          ']
#
#  stack_2_block_1_se_2_conv (Con  (None, 1, 1, 384)   9600        ['stack_2_block_1_se_gelu[0][0]']
#  v2D)
#
#  stack_2_block_1_se_sigmoid (Ac  (None, 1, 1, 384)   0           ['stack_2_block_1_se_2_conv[0][0]
#  tivation)                                                       ']
#
#  stack_2_block_1_se_out (Multip  (None, 28, 28, 384)  0          ['stack_2_block_1_MB_dw_gelu[0][0
#  ly)                                                             ]',
#                                                                   'stack_2_block_1_se_sigmoid[0][0
#                                                                  ]']
#
#  stack_2_block_1_shortcut_pool   (None, 28, 28, 96)  0           ['stack_1_block_2_output[0][0]']
#  (MaxPooling2D)
#
#  stack_2_block_1_MB_pw_pad (Zer  (None, 28, 28, 384)  0          ['stack_2_block_1_se_out[0][0]']
#  oPadding2D)
#
#  stack_2_block_1_shortcut_conv   (None, 28, 28, 192)  18432      ['stack_2_block_1_shortcut_pool[0
#  (Conv2D)                                                        ][0]']
#
#  stack_2_block_1_MB_pw_conv (Co  (None, 28, 28, 192)  73728      ['stack_2_block_1_MB_pw_pad[0][0]
#  nv2D)                                                           ']
#
#  stack_2_block_1_output (Add)   (None, 28, 28, 192)  0           ['stack_2_block_1_shortcut_conv[0
#                                                                  ][0]',
#                                                                   'stack_2_block_1_MB_pw_conv[0][0
#                                                                  ]']
#
#  stack_2_block_2_preact_bn (Bat  (None, 28, 28, 192)  768        ['stack_2_block_1_output[0][0]']
#  chNormalization)
#
#  stack_2_block_2_expand_pad (Ze  (None, 28, 28, 192)  0          ['stack_2_block_2_preact_bn[0][0]
#  roPadding2D)                                                    ']
#
#  stack_2_block_2_expand_conv (C  (None, 28, 28, 768)  147456     ['stack_2_block_2_expand_pad[0][0
#  onv2D)                                                          ]']
#
#  stack_2_block_2_expand_bn (Bat  (None, 28, 28, 768)  3072       ['stack_2_block_2_expand_conv[0][
#  chNormalization)                                                0]']
#
#  stack_2_block_2_expand_gelu (A  (None, 28, 28, 768)  0          ['stack_2_block_2_expand_bn[0][0]
#  ctivation)                                                      ']
#
#  stack_2_block_2_MB_pad (ZeroPa  (None, 30, 30, 768)  0          ['stack_2_block_2_expand_gelu[0][
#  dding2D)                                                        0]']
#
#  stack_2_block_2_MB_dw_conv (De  (None, 28, 28, 768)  6912       ['stack_2_block_2_MB_pad[0][0]']
#  pthwiseConv2D)
#
#  stack_2_block_2_MB_dw_bn (Batc  (None, 28, 28, 768)  3072       ['stack_2_block_2_MB_dw_conv[0][0
#  hNormalization)                                                 ]']
#
#  stack_2_block_2_MB_dw_gelu (Ac  (None, 28, 28, 768)  0          ['stack_2_block_2_MB_dw_bn[0][0]'
#  tivation)                                                       ]
#
#  tf.math.reduce_mean_34 (TFOpLa  (None, 1, 1, 768)   0           ['stack_2_block_2_MB_dw_gelu[0][0
#  mbda)                                                           ]']
#
#  stack_2_block_2_se_1_conv (Con  (None, 1, 1, 48)    36912       ['tf.math.reduce_mean_34[0][0]']
#  v2D)
#
#  stack_2_block_2_se_gelu (Activ  (None, 1, 1, 48)    0           ['stack_2_block_2_se_1_conv[0][0]
#  ation)                                                          ']
#
#  stack_2_block_2_se_2_conv (Con  (None, 1, 1, 768)   37632       ['stack_2_block_2_se_gelu[0][0]']
#  v2D)
#
#  stack_2_block_2_se_sigmoid (Ac  (None, 1, 1, 768)   0           ['stack_2_block_2_se_2_conv[0][0]
#  tivation)                                                       ']
#
#  stack_2_block_2_se_out (Multip  (None, 28, 28, 768)  0          ['stack_2_block_2_MB_dw_gelu[0][0
#  ly)                                                             ]',
#                                                                   'stack_2_block_2_se_sigmoid[0][0
#                                                                  ]']
#
#  stack_2_block_2_MB_pw_pad (Zer  (None, 28, 28, 768)  0          ['stack_2_block_2_se_out[0][0]']
#  oPadding2D)
#
#  stack_2_block_2_MB_pw_conv (Co  (None, 28, 28, 192)  147456     ['stack_2_block_2_MB_pw_pad[0][0]
#  nv2D)                                                           ']
#
#  stack_2_block_2_output (Add)   (None, 28, 28, 192)  0           ['stack_2_block_1_output[0][0]',
#                                                                   'stack_2_block_2_MB_pw_conv[0][0
#                                                                  ]']
#
#  stack_2_block_3_preact_bn (Bat  (None, 28, 28, 192)  768        ['stack_2_block_2_output[0][0]']
#  chNormalization)
#
#  stack_2_block_3_expand_pad (Ze  (None, 28, 28, 192)  0          ['stack_2_block_3_preact_bn[0][0]
#  roPadding2D)                                                    ']
#
#  stack_2_block_3_expand_conv (C  (None, 28, 28, 768)  147456     ['stack_2_block_3_expand_pad[0][0
#  onv2D)                                                          ]']
#
#  stack_2_block_3_expand_bn (Bat  (None, 28, 28, 768)  3072       ['stack_2_block_3_expand_conv[0][
#  chNormalization)                                                0]']
#
#  stack_2_block_3_expand_gelu (A  (None, 28, 28, 768)  0          ['stack_2_block_3_expand_bn[0][0]
#  ctivation)                                                      ']
#
#  stack_2_block_3_MB_pad (ZeroPa  (None, 30, 30, 768)  0          ['stack_2_block_3_expand_gelu[0][
#  dding2D)                                                        0]']
#
#  stack_2_block_3_MB_dw_conv (De  (None, 28, 28, 768)  6912       ['stack_2_block_3_MB_pad[0][0]']
#  pthwiseConv2D)
#
#  stack_2_block_3_MB_dw_bn (Batc  (None, 28, 28, 768)  3072       ['stack_2_block_3_MB_dw_conv[0][0
#  hNormalization)                                                 ]']
#
#  stack_2_block_3_MB_dw_gelu (Ac  (None, 28, 28, 768)  0          ['stack_2_block_3_MB_dw_bn[0][0]'
#  tivation)                                                       ]
#
#  tf.math.reduce_mean_35 (TFOpLa  (None, 1, 1, 768)   0           ['stack_2_block_3_MB_dw_gelu[0][0
#  mbda)                                                           ]']
#
#  stack_2_block_3_se_1_conv (Con  (None, 1, 1, 48)    36912       ['tf.math.reduce_mean_35[0][0]']
#  v2D)
#
#  stack_2_block_3_se_gelu (Activ  (None, 1, 1, 48)    0           ['stack_2_block_3_se_1_conv[0][0]
#  ation)                                                          ']
#
#  stack_2_block_3_se_2_conv (Con  (None, 1, 1, 768)   37632       ['stack_2_block_3_se_gelu[0][0]']
#  v2D)
#
#  stack_2_block_3_se_sigmoid (Ac  (None, 1, 1, 768)   0           ['stack_2_block_3_se_2_conv[0][0]
#  tivation)                                                       ']
#
#  stack_2_block_3_se_out (Multip  (None, 28, 28, 768)  0          ['stack_2_block_3_MB_dw_gelu[0][0
#  ly)                                                             ]',
#                                                                   'stack_2_block_3_se_sigmoid[0][0
#                                                                  ]']
#
#  stack_2_block_3_MB_pw_pad (Zer  (None, 28, 28, 768)  0          ['stack_2_block_3_se_out[0][0]']
#  oPadding2D)
#
#  stack_2_block_3_MB_pw_conv (Co  (None, 28, 28, 192)  147456     ['stack_2_block_3_MB_pw_pad[0][0]
#  nv2D)                                                           ']
#
#  stack_2_block_3_output (Add)   (None, 28, 28, 192)  0           ['stack_2_block_2_output[0][0]',
#                                                                   'stack_2_block_3_MB_pw_conv[0][0
#                                                                  ]']
#
#  stack_3_block_1_preact_ln (Lay  (None, 28, 28, 192)  384        ['stack_2_block_3_output[0][0]']
#  erNormalization)
#
#  stack_3_block_1_pool (MaxPooli  (None, 14, 14, 192)  0          ['stack_3_block_1_preact_ln[0][0]
#  ng2D)                                                           ']
#
#  stack_3_block_1_mhsa_qkv_conv   (None, 14, 14, 576)  110592     ['stack_3_block_1_pool[0][0]']
#  (Conv2D)
#
#  tf.split_170 (TFOpLambda)      [(None, 14, 14, 192  0           ['stack_3_block_1_mhsa_qkv_conv[0
#                                 ),                               ][0]']
#                                  (None, 14, 14, 192
#                                 ),
#                                  (None, 14, 14, 192
#                                 )]
#
#  tf.reshape_810 (TFOpLambda)    (None, 196, 6, 32)   0           ['tf.split_170[0][0]']
#
#  tf.reshape_811 (TFOpLambda)    (None, 196, 6, 32)   0           ['tf.split_170[0][1]']
#
#  tf.compat.v1.transpose_692 (TF  (None, 6, 196, 32)  0           ['tf.reshape_810[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_693 (TF  (None, 6, 32, 196)  0           ['tf.reshape_811[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_340 (TFOpLamb  (None, 6, 196, 196)  0          ['tf.compat.v1.transpose_692[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_693[0][0
#                                                                  ]']
#
#  tf.math.multiply_170 (TFOpLamb  (None, 6, 196, 196)  0          ['tf.linalg.matmul_340[0][0]']
#  da)
#
#  stack_3_block_1_mhsa_pos_emb (  (None, 6, 196, 196)  4374       ['tf.math.multiply_170[0][0]']
#  MultiHeadRelativePositionalEmb
#  edding)
#
#  tf.reshape_812 (TFOpLambda)    (None, 196, 6, 32)   0           ['tf.split_170[0][2]']
#
#  stack_3_block_1_mhsa_attention  (None, 6, 196, 196)  0          ['stack_3_block_1_mhsa_pos_emb[0]
#  _scores (Softmax)                                               [0]']
#
#  tf.compat.v1.transpose_694 (TF  (None, 6, 196, 32)  0           ['tf.reshape_812[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_341 (TFOpLamb  (None, 6, 196, 32)  0           ['stack_3_block_1_mhsa_attention_
#  da)                                                             scores[0][0]',
#                                                                   'tf.compat.v1.transpose_694[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_695 (TF  (None, 196, 6, 32)  0           ['tf.linalg.matmul_341[0][0]']
#  OpLambda)
#
#  stack_3_block_1_shortcut_pool   (None, 14, 14, 192)  0          ['stack_2_block_3_output[0][0]']
#  (MaxPooling2D)
#
#  tf.reshape_813 (TFOpLambda)    (None, 14, 14, 192)  0           ['tf.compat.v1.transpose_695[0][0
#                                                                  ]']
#
#  stack_3_block_1_shortcut_conv   (None, 14, 14, 384)  73728      ['stack_3_block_1_shortcut_pool[0
#  (Conv2D)                                                        ][0]']
#
#  stack_3_block_1_mhsa_output (D  (None, 14, 14, 384)  73728      ['tf.reshape_813[0][0]']
#  ense)
#
#  stack_3_block_1_output (Add)   (None, 14, 14, 384)  0           ['stack_3_block_1_shortcut_conv[0
#                                                                  ][0]',
#                                                                   'stack_3_block_1_mhsa_output[0][
#                                                                  0]']
#
#  stack_3_block_1_ffn_preact_ln   (None, 14, 14, 384)  768        ['stack_3_block_1_output[0][0]']
#  (LayerNormalization)
#
#  stack_3_block_1_ffn_1_conv (Co  (None, 14, 14, 1536  589824     ['stack_3_block_1_ffn_preact_ln[0
#  nv2D)                          )                                ][0]']
#
#  stack_3_block_1_ffn_gelu (Acti  (None, 14, 14, 1536  0          ['stack_3_block_1_ffn_1_conv[0][0
#  vation)                        )                                ]']
#
#  stack_3_block_1_ffn_2_conv (Co  (None, 14, 14, 384)  589824     ['stack_3_block_1_ffn_gelu[0][0]'
#  nv2D)                                                           ]
#
#  stack_3_block_1_ffn_output (Ad  (None, 14, 14, 384)  0          ['stack_3_block_1_output[0][0]',
#  d)                                                               'stack_3_block_1_ffn_2_conv[0][0
#                                                                  ]']
#
#  stack_3_block_2_preact_ln (Lay  (None, 14, 14, 384)  768        ['stack_3_block_1_ffn_output[0][0
#  erNormalization)                                                ]']
#
#  stack_3_block_2_mhsa_qkv_conv   (None, 14, 14, 1152  442368     ['stack_3_block_2_preact_ln[0][0]
#  (Conv2D)                       )                                ']
#
#  tf.split_171 (TFOpLambda)      [(None, 14, 14, 384  0           ['stack_3_block_2_mhsa_qkv_conv[0
#                                 ),                               ][0]']
#                                  (None, 14, 14, 384
#                                 ),
#                                  (None, 14, 14, 384
#                                 )]
#
#  tf.reshape_814 (TFOpLambda)    (None, 196, 12, 32)  0           ['tf.split_171[0][0]']
#
#  tf.reshape_815 (TFOpLambda)    (None, 196, 12, 32)  0           ['tf.split_171[0][1]']
#
#  tf.compat.v1.transpose_696 (TF  (None, 12, 196, 32)  0          ['tf.reshape_814[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_697 (TF  (None, 12, 32, 196)  0          ['tf.reshape_815[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_342 (TFOpLamb  (None, 12, 196, 196  0          ['tf.compat.v1.transpose_696[0][0
#  da)                            )                                ]',
#                                                                   'tf.compat.v1.transpose_697[0][0
#                                                                  ]']
#
#  tf.math.multiply_171 (TFOpLamb  (None, 12, 196, 196  0          ['tf.linalg.matmul_342[0][0]']
#  da)                            )
#
#  stack_3_block_2_mhsa_pos_emb (  (None, 12, 196, 196  8748       ['tf.math.multiply_171[0][0]']
#  MultiHeadRelativePositionalEmb  )
#  edding)
#
#  tf.reshape_816 (TFOpLambda)    (None, 196, 12, 32)  0           ['tf.split_171[0][2]']
#
#  stack_3_block_2_mhsa_attention  (None, 12, 196, 196  0          ['stack_3_block_2_mhsa_pos_emb[0]
#  _scores (Softmax)              )                                [0]']
#
#  tf.compat.v1.transpose_698 (TF  (None, 12, 196, 32)  0          ['tf.reshape_816[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_343 (TFOpLamb  (None, 12, 196, 32)  0          ['stack_3_block_2_mhsa_attention_
#  da)                                                             scores[0][0]',
#                                                                   'tf.compat.v1.transpose_698[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_699 (TF  (None, 196, 12, 32)  0          ['tf.linalg.matmul_343[0][0]']
#  OpLambda)
#
#  tf.reshape_817 (TFOpLambda)    (None, 14, 14, 384)  0           ['tf.compat.v1.transpose_699[0][0
#                                                                  ]']
#
#  stack_3_block_2_mhsa_output (D  (None, 14, 14, 384)  147456     ['tf.reshape_817[0][0]']
#  ense)
#
#  stack_3_block_2_output (Add)   (None, 14, 14, 384)  0           ['stack_3_block_1_ffn_output[0][0
#                                                                  ]',
#                                                                   'stack_3_block_2_mhsa_output[0][
#                                                                  0]']
#
#  stack_3_block_2_ffn_preact_ln   (None, 14, 14, 384)  768        ['stack_3_block_2_output[0][0]']
#  (LayerNormalization)
#
#  stack_3_block_2_ffn_1_conv (Co  (None, 14, 14, 1536  589824     ['stack_3_block_2_ffn_preact_ln[0
#  nv2D)                          )                                ][0]']
#
#  stack_3_block_2_ffn_gelu (Acti  (None, 14, 14, 1536  0          ['stack_3_block_2_ffn_1_conv[0][0
#  vation)                        )                                ]']
#
#  stack_3_block_2_ffn_2_conv (Co  (None, 14, 14, 384)  589824     ['stack_3_block_2_ffn_gelu[0][0]'
#  nv2D)                                                           ]
#
#  stack_3_block_2_ffn_output (Ad  (None, 14, 14, 384)  0          ['stack_3_block_2_output[0][0]',
# ...
#  stack_4_block_1_mhsa_qkv_conv   (None, 7, 7, 1152)  442368      ['stack_4_block_1_pool[0][0]']
#  (Conv2D)
#
#  tf.split_175 (TFOpLambda)      [(None, 7, 7, 384),  0           ['stack_4_block_1_mhsa_qkv_conv[0
#                                  (None, 7, 7, 384),              ][0]']
#                                  (None, 7, 7, 384)]
#
#  tf.reshape_830 (TFOpLambda)    (None, 49, 12, 32)   0           ['tf.split_175[0][0]']
#
#  tf.reshape_831 (TFOpLambda)    (None, 49, 12, 32)   0           ['tf.split_175[0][1]']
#
#  tf.compat.v1.transpose_712 (TF  (None, 12, 49, 32)  0           ['tf.reshape_830[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_713 (TF  (None, 12, 32, 49)  0           ['tf.reshape_831[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_350 (TFOpLamb  (None, 12, 49, 49)  0           ['tf.compat.v1.transpose_712[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_713[0][0
#                                                                  ]']
#
#  tf.math.multiply_175 (TFOpLamb  (None, 12, 49, 49)  0           ['tf.linalg.matmul_350[0][0]']
#  da)
#
#  stack_4_block_1_mhsa_pos_emb (  (None, 12, 49, 49)  2028        ['tf.math.multiply_175[0][0]']
#  MultiHeadRelativePositionalEmb
#  edding)
#
#  tf.reshape_832 (TFOpLambda)    (None, 49, 12, 32)   0           ['tf.split_175[0][2]']
#
#  stack_4_block_1_mhsa_attention  (None, 12, 49, 49)  0           ['stack_4_block_1_mhsa_pos_emb[0]
#  _scores (Softmax)                                               [0]']
#
#  tf.compat.v1.transpose_714 (TF  (None, 12, 49, 32)  0           ['tf.reshape_832[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_351 (TFOpLamb  (None, 12, 49, 32)  0           ['stack_4_block_1_mhsa_attention_
#  da)                                                             scores[0][0]',
#                                                                   'tf.compat.v1.transpose_714[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_715 (TF  (None, 49, 12, 32)  0           ['tf.linalg.matmul_351[0][0]']
#  OpLambda)
#
#  stack_4_block_1_shortcut_pool   (None, 7, 7, 384)   0           ['stack_3_block_5_ffn_output[0][0
#  (MaxPooling2D)                                                  ]']
#
#  tf.reshape_833 (TFOpLambda)    (None, 7, 7, 384)    0           ['tf.compat.v1.transpose_715[0][0
#                                                                  ]']
#
#  stack_4_block_1_shortcut_conv   (None, 7, 7, 768)   294912      ['stack_4_block_1_shortcut_pool[0
#  (Conv2D)                                                        ][0]']
#
#  stack_4_block_1_mhsa_output (D  (None, 7, 7, 768)   294912      ['tf.reshape_833[0][0]']
#  ense)
#
#  stack_4_block_1_output (Add)   (None, 7, 7, 768)    0           ['stack_4_block_1_shortcut_conv[0
#                                                                  ][0]',
#                                                                   'stack_4_block_1_mhsa_output[0][
#                                                                  0]']
#
#  stack_4_block_1_ffn_preact_ln   (None, 7, 7, 768)   1536        ['stack_4_block_1_output[0][0]']
#  (LayerNormalization)
#
#  stack_4_block_1_ffn_1_conv (Co  (None, 7, 7, 3072)  2359296     ['stack_4_block_1_ffn_preact_ln[0
#  nv2D)                                                           ][0]']
#
#  stack_4_block_1_ffn_gelu (Acti  (None, 7, 7, 3072)  0           ['stack_4_block_1_ffn_1_conv[0][0
#  vation)                                                         ]']
#
#  stack_4_block_1_ffn_2_conv (Co  (None, 7, 7, 768)   2359296     ['stack_4_block_1_ffn_gelu[0][0]'
#  nv2D)                                                           ]
#
#  stack_4_block_1_ffn_output (Ad  (None, 7, 7, 768)   0           ['stack_4_block_1_output[0][0]',
#  d)                                                               'stack_4_block_1_ffn_2_conv[0][0
#                                                                  ]']
#
#  stack_4_block_2_preact_ln (Lay  (None, 7, 7, 768)   1536        ['stack_4_block_1_ffn_output[0][0
#  erNormalization)                                                ]']
#
#  stack_4_block_2_mhsa_qkv_conv   (None, 7, 7, 2304)  1769472     ['stack_4_block_2_preact_ln[0][0]
#  (Conv2D)                                                        ']
#
#  tf.split_176 (TFOpLambda)      [(None, 7, 7, 768),  0           ['stack_4_block_2_mhsa_qkv_conv[0
#                                  (None, 7, 7, 768),              ][0]']
#                                  (None, 7, 7, 768)]
#
#  tf.reshape_834 (TFOpLambda)    (None, 49, 24, 32)   0           ['tf.split_176[0][0]']
#
#  tf.reshape_835 (TFOpLambda)    (None, 49, 24, 32)   0           ['tf.split_176[0][1]']
#
#  tf.compat.v1.transpose_716 (TF  (None, 24, 49, 32)  0           ['tf.reshape_834[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_717 (TF  (None, 24, 32, 49)  0           ['tf.reshape_835[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_352 (TFOpLamb  (None, 24, 49, 49)  0           ['tf.compat.v1.transpose_716[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_717[0][0
#                                                                  ]']
#
#  tf.math.multiply_176 (TFOpLamb  (None, 24, 49, 49)  0           ['tf.linalg.matmul_352[0][0]']
#  da)
#
#  stack_4_block_2_mhsa_pos_emb (  (None, 24, 49, 49)  4056        ['tf.math.multiply_176[0][0]']
#  MultiHeadRelativePositionalEmb
#  edding)
#
#  tf.reshape_836 (TFOpLambda)    (None, 49, 24, 32)   0           ['tf.split_176[0][2]']
#
#  stack_4_block_2_mhsa_attention  (None, 24, 49, 49)  0           ['stack_4_block_2_mhsa_pos_emb[0]
#  _scores (Softmax)                                               [0]']
#
#  tf.compat.v1.transpose_718 (TF  (None, 24, 49, 32)  0           ['tf.reshape_836[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_353 (TFOpLamb  (None, 24, 49, 32)  0           ['stack_4_block_2_mhsa_attention_
#  da)                                                             scores[0][0]',
#                                                                   'tf.compat.v1.transpose_718[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_719 (TF  (None, 49, 24, 32)  0           ['tf.linalg.matmul_353[0][0]']
#  OpLambda)
#
#  tf.reshape_837 (TFOpLambda)    (None, 7, 7, 768)    0           ['tf.compat.v1.transpose_719[0][0
#                                                                  ]']
#
#  stack_4_block_2_mhsa_output (D  (None, 7, 7, 768)   589824      ['tf.reshape_837[0][0]']
#  ense)
#
#  stack_4_block_2_output (Add)   (None, 7, 7, 768)    0           ['stack_4_block_1_ffn_output[0][0
#                                                                  ]',
#                                                                   'stack_4_block_2_mhsa_output[0][
#                                                                  0]']
#
#  stack_4_block_2_ffn_preact_ln   (None, 7, 7, 768)   1536        ['stack_4_block_2_output[0][0]']
#  (LayerNormalization)
#
#  stack_4_block_2_ffn_1_conv (Co  (None, 7, 7, 3072)  2359296     ['stack_4_block_2_ffn_preact_ln[0
#  nv2D)                                                           ][0]']
#
#  stack_4_block_2_ffn_gelu (Acti  (None, 7, 7, 3072)  0           ['stack_4_block_2_ffn_1_conv[0][0
#  vation)                                                         ]']
#
#  stack_4_block_2_ffn_2_conv (Co  (None, 7, 7, 768)   2359296     ['stack_4_block_2_ffn_gelu[0][0]'
#  nv2D)                                                           ]
#
#  stack_4_block_2_ffn_output (Ad  (None, 7, 7, 768)   0           ['stack_4_block_2_output[0][0]',
#  d)                                                               'stack_4_block_2_ffn_2_conv[0][0
#                                                                  ]']
#
#  avg_pool (GlobalAveragePooling  (None, 768)         0           ['stack_4_block_2_ffn_output[0][0
#  2D)                                                             ]']
#
#  predictions (Dense)            (None, 23)           17687       ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22,539,905
# Trainable params: 22,528,257
# Non-trainable params: 11,648
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_4.fit(X_train, 
                  y_train, 
                  batch_size=32, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 168/168 [==============================] - 9s 41ms/step
#  - val_f1_macro: 0.3237135967428597 - val_f1_micro: 0.5860335195530726
#           - val_precision_macro: 0.44881713853744876 - val_precision_micro: 0.5860335195530726 - val_recall_macro: 0.3468296879878797 - val_recall_micro: 0.5860335195530726
#           - val_best_f1_score_macro: 0.3237135967428597 (epoch: 0) - val_best_f1_score_micro: 0.5860335195530726 (epoch: 0.5860335195530726)
# 168/168 [==============================] - 56s 256ms/step - loss: 1.9329 - accuracy: 0.5402 - top-5-accuracy: 0.8670 - val_loss: 0.9607 - val_accuracy: 0.6678 - val_top-5-accuracy: 0.9747
# Epoch 2/5
# 168/168 [==============================] - 7s 40ms/step
#  - val_f1_macro: 0.42400687490690386 - val_f1_micro: 0.7374301675977654
#           - val_precision_macro: 0.4690288522760323 - val_precision_micro: 0.7374301675977654 - val_recall_macro: 0.42102552214858097 - val_recall_micro: 0.7374301675977654
#           - val_best_f1_score_macro: 0.42400687490690386 (epoch: 1) - val_best_f1_score_micro: 0.7374301675977654 (epoch: 0.7374301675977654)
# 168/168 [==============================] - 38s 226ms/step - loss: 0.7309 - accuracy: 0.7371 - top-5-accuracy: 0.9762 - val_loss: 0.6883 - val_accuracy: 0.7685 - val_top-5-accuracy: 0.9788
# Epoch 3/5
# 168/168 [==============================] - 7s 41ms/step
#  - val_f1_macro: 0.4804561573275124 - val_f1_micro: 0.7675977653631285
#           - val_precision_macro: 0.5005484906550262 - val_precision_micro: 0.7675977653631285 - val_recall_macro: 0.49662549285352353 - val_recall_micro: 0.7675977653631285
#           - val_best_f1_score_macro: 0.4804561573275124 (epoch: 2) - val_best_f1_score_micro: 0.7675977653631285 (epoch: 0.7675977653631285)
# 168/168 [==============================] - 38s 226ms/step - loss: 0.6530 - accuracy: 0.7682 - top-5-accuracy: 0.9842 - val_loss: 0.6129 - val_accuracy: 0.8028 - val_top-5-accuracy: 0.9834
# Epoch 4/5
# 168/168 [==============================] - 7s 41ms/step
#  - val_f1_macro: 0.4356063648785733 - val_f1_micro: 0.7581005586592178
#           - val_precision_macro: 0.46420502079905684 - val_precision_micro: 0.7581005586592179 - val_recall_macro: 0.4517544940409495 - val_recall_micro: 0.7581005586592179
#           - val_best_f1_score_macro: 0.4804561573275124 (epoch: 2) - val_best_f1_score_micro: 0.7675977653631285 (epoch: 0.7675977653631285)
# 168/168 [==============================] - 38s 227ms/step - loss: 0.5123 - accuracy: 0.8209 - top-5-accuracy: 0.9892 - val_loss: 0.6823 - val_accuracy: 0.7890 - val_top-5-accuracy: 0.9806
# Epoch 5/5
# 168/168 [==============================] - 7s 40ms/step
#  - val_f1_macro: 0.3941789989952006 - val_f1_micro: 0.7262569832402235
#           - val_precision_macro: 0.46226611497460907 - val_precision_micro: 0.7262569832402235 - val_recall_macro: 0.4195313931392967 - val_recall_micro: 0.7262569832402235
#           - val_best_f1_score_macro: 0.4804561573275124 (epoch: 2) - val_best_f1_score_micro: 0.7675977653631285 (epoch: 0.7675977653631285)
# 168/168 [==============================] - 38s 226ms/step - loss: 0.5233 - accuracy: 0.8246 - top-5-accuracy: 0.9881 - val_loss: 0.8630 - val_accuracy: 0.7507 - val_top-5-accuracy: 0.9581

# %% [markdown]
# ## ConvNeXt

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_5.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_5.summary()
# Out:
# Model: "convnext_large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 56, 56, 192)  9408        ['input_17[0][0]']
#
#  stem_ln (LayerNormalization)   (None, 56, 56, 192)  384         ['stem_conv[0][0]']
#
#  stack1_block1_pad (ZeroPadding  (None, 62, 62, 192)  0          ['stem_ln[0][0]']
#  2D)
#
#  stack1_block1_dw_conv (Depthwi  (None, 56, 56, 192)  9600       ['stack1_block1_pad[0][0]']
#  seConv2D)
#
#  stack1_block1_ln (LayerNormali  (None, 56, 56, 192)  384        ['stack1_block1_dw_conv[0][0]']
#  zation)
#
#  stack1_block1_up_dense (Dense)  (None, 56, 56, 768)  148224     ['stack1_block1_ln[0][0]']
#
#  stack1_block1_gelu (Activation  (None, 56, 56, 768)  0          ['stack1_block1_up_dense[0][0]']
#  )
#
#  stack1_block1_down_dense (Dens  (None, 56, 56, 192)  147648     ['stack1_block1_gelu[0][0]']
#  e)
#
#  stack1_block1_gamma (ChannelAf  (None, 56, 56, 192)  192        ['stack1_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block1_output (Add)     (None, 56, 56, 192)  0           ['stem_ln[0][0]',
#                                                                   'stack1_block1_gamma[0][0]']
#
#  stack1_block2_pad (ZeroPadding  (None, 62, 62, 192)  0          ['stack1_block1_output[0][0]']
#  2D)
#
#  stack1_block2_dw_conv (Depthwi  (None, 56, 56, 192)  9600       ['stack1_block2_pad[0][0]']
#  seConv2D)
#
#  stack1_block2_ln (LayerNormali  (None, 56, 56, 192)  384        ['stack1_block2_dw_conv[0][0]']
#  zation)
#
#  stack1_block2_up_dense (Dense)  (None, 56, 56, 768)  148224     ['stack1_block2_ln[0][0]']
#
#  stack1_block2_gelu (Activation  (None, 56, 56, 768)  0          ['stack1_block2_up_dense[0][0]']
#  )
#
#  stack1_block2_down_dense (Dens  (None, 56, 56, 192)  147648     ['stack1_block2_gelu[0][0]']
#  e)
#
#  stack1_block2_gamma (ChannelAf  (None, 56, 56, 192)  192        ['stack1_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block2_drop (Dropout)   (None, 56, 56, 192)  0           ['stack1_block2_gamma[0][0]']
#
#  stack1_block2_output (Add)     (None, 56, 56, 192)  0           ['stack1_block1_output[0][0]',
#                                                                   'stack1_block2_drop[0][0]']
#
#  stack1_block3_pad (ZeroPadding  (None, 62, 62, 192)  0          ['stack1_block2_output[0][0]']
#  2D)
#
#  stack1_block3_dw_conv (Depthwi  (None, 56, 56, 192)  9600       ['stack1_block3_pad[0][0]']
#  seConv2D)
#
#  stack1_block3_ln (LayerNormali  (None, 56, 56, 192)  384        ['stack1_block3_dw_conv[0][0]']
#  zation)
#
#  stack1_block3_up_dense (Dense)  (None, 56, 56, 768)  148224     ['stack1_block3_ln[0][0]']
#
#  stack1_block3_gelu (Activation  (None, 56, 56, 768)  0          ['stack1_block3_up_dense[0][0]']
#  )
#
#  stack1_block3_down_dense (Dens  (None, 56, 56, 192)  147648     ['stack1_block3_gelu[0][0]']
#  e)
#
#  stack1_block3_gamma (ChannelAf  (None, 56, 56, 192)  192        ['stack1_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block3_drop (Dropout)   (None, 56, 56, 192)  0           ['stack1_block3_gamma[0][0]']
#
#  stack1_block3_output (Add)     (None, 56, 56, 192)  0           ['stack1_block2_output[0][0]',
#                                                                   'stack1_block3_drop[0][0]']
#
#  stack2_downsample_ln (LayerNor  (None, 56, 56, 192)  384        ['stack1_block3_output[0][0]']
#  malization)
#
#  stack2_downsample_conv (Conv2D  (None, 28, 28, 384)  295296     ['stack2_downsample_ln[0][0]']
#  )
#
#  stack2_block1_pad (ZeroPadding  (None, 34, 34, 384)  0          ['stack2_downsample_conv[0][0]']
#  2D)
#
#  stack2_block1_dw_conv (Depthwi  (None, 28, 28, 384)  19200      ['stack2_block1_pad[0][0]']
#  seConv2D)
#
#  stack2_block1_ln (LayerNormali  (None, 28, 28, 384)  768        ['stack2_block1_dw_conv[0][0]']
#  zation)
#
#  stack2_block1_up_dense (Dense)  (None, 28, 28, 1536  591360     ['stack2_block1_ln[0][0]']
#                                 )
#
#  stack2_block1_gelu (Activation  (None, 28, 28, 1536  0          ['stack2_block1_up_dense[0][0]']
#  )                              )
#
#  stack2_block1_down_dense (Dens  (None, 28, 28, 384)  590208     ['stack2_block1_gelu[0][0]']
#  e)
#
#  stack2_block1_gamma (ChannelAf  (None, 28, 28, 384)  384        ['stack2_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block1_drop (Dropout)   (None, 28, 28, 384)  0           ['stack2_block1_gamma[0][0]']
#
#  stack2_block1_output (Add)     (None, 28, 28, 384)  0           ['stack2_downsample_conv[0][0]',
#                                                                   'stack2_block1_drop[0][0]']
#
#  stack2_block2_pad (ZeroPadding  (None, 34, 34, 384)  0          ['stack2_block1_output[0][0]']
#  2D)
#
#  stack2_block2_dw_conv (Depthwi  (None, 28, 28, 384)  19200      ['stack2_block2_pad[0][0]']
#  seConv2D)
#
#  stack2_block2_ln (LayerNormali  (None, 28, 28, 384)  768        ['stack2_block2_dw_conv[0][0]']
#  zation)
#
#  stack2_block2_up_dense (Dense)  (None, 28, 28, 1536  591360     ['stack2_block2_ln[0][0]']
#                                 )
#
#  stack2_block2_gelu (Activation  (None, 28, 28, 1536  0          ['stack2_block2_up_dense[0][0]']
#  )                              )
#
#  stack2_block2_down_dense (Dens  (None, 28, 28, 384)  590208     ['stack2_block2_gelu[0][0]']
#  e)
#
#  stack2_block2_gamma (ChannelAf  (None, 28, 28, 384)  384        ['stack2_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block2_drop (Dropout)   (None, 28, 28, 384)  0           ['stack2_block2_gamma[0][0]']
#
#  stack2_block2_output (Add)     (None, 28, 28, 384)  0           ['stack2_block1_output[0][0]',
#                                                                   'stack2_block2_drop[0][0]']
#
#  stack2_block3_pad (ZeroPadding  (None, 34, 34, 384)  0          ['stack2_block2_output[0][0]']
#  2D)
#
#  stack2_block3_dw_conv (Depthwi  (None, 28, 28, 384)  19200      ['stack2_block3_pad[0][0]']
#  seConv2D)
#
#  stack2_block3_ln (LayerNormali  (None, 28, 28, 384)  768        ['stack2_block3_dw_conv[0][0]']
#  zation)
#
#  stack2_block3_up_dense (Dense)  (None, 28, 28, 1536  591360     ['stack2_block3_ln[0][0]']
#                                 )
#
#  stack2_block3_gelu (Activation  (None, 28, 28, 1536  0          ['stack2_block3_up_dense[0][0]']
#  )                              )
#
#  stack2_block3_down_dense (Dens  (None, 28, 28, 384)  590208     ['stack2_block3_gelu[0][0]']
#  e)
#
#  stack2_block3_gamma (ChannelAf  (None, 28, 28, 384)  384        ['stack2_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block3_drop (Dropout)   (None, 28, 28, 384)  0           ['stack2_block3_gamma[0][0]']
#
#  stack2_block3_output (Add)     (None, 28, 28, 384)  0           ['stack2_block2_output[0][0]',
#                                                                   'stack2_block3_drop[0][0]']
#
#  stack3_downsample_ln (LayerNor  (None, 28, 28, 384)  768        ['stack2_block3_output[0][0]']
#  malization)
#
#  stack3_downsample_conv (Conv2D  (None, 14, 14, 768)  1180416    ['stack3_downsample_ln[0][0]']
#  )
#
#  stack3_block1_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_downsample_conv[0][0]']
#  2D)
#
#  stack3_block1_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block1_pad[0][0]']
#  seConv2D)
#
#  stack3_block1_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block1_dw_conv[0][0]']
#  zation)
#
#  stack3_block1_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block1_ln[0][0]']
#                                 )
#
#  stack3_block1_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block1_up_dense[0][0]']
#  )                              )
#
#  stack3_block1_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block1_gelu[0][0]']
#  e)
#
#  stack3_block1_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block1_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block1_gamma[0][0]']
#
#  stack3_block1_output (Add)     (None, 14, 14, 768)  0           ['stack3_downsample_conv[0][0]',
#                                                                   'stack3_block1_drop[0][0]']
#
#  stack3_block2_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block1_output[0][0]']
#  2D)
#
#  stack3_block2_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block2_pad[0][0]']
#  seConv2D)
#
#  stack3_block2_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block2_dw_conv[0][0]']
#  zation)
#
#  stack3_block2_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block2_ln[0][0]']
#                                 )
#
#  stack3_block2_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block2_up_dense[0][0]']
#  )                              )
#
#  stack3_block2_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block2_gelu[0][0]']
#  e)
#
#  stack3_block2_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block2_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block2_gamma[0][0]']
#
#  stack3_block2_output (Add)     (None, 14, 14, 768)  0           ['stack3_block1_output[0][0]',
#                                                                   'stack3_block2_drop[0][0]']
#
#  stack3_block3_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block2_output[0][0]']
#  2D)
#
#  stack3_block3_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block3_pad[0][0]']
#  seConv2D)
#
#  stack3_block3_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block3_dw_conv[0][0]']
#  zation)
#
#  stack3_block3_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block3_ln[0][0]']
#                                 )
#
#  stack3_block3_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block3_up_dense[0][0]']
#  )                              )
#
#  stack3_block3_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block3_gelu[0][0]']
#  e)
#
#  stack3_block3_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block3_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block3_gamma[0][0]']
#
#  stack3_block3_output (Add)     (None, 14, 14, 768)  0           ['stack3_block2_output[0][0]',
#                                                                   'stack3_block3_drop[0][0]']
#
#  stack3_block4_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block3_output[0][0]']
#  2D)
#
#  stack3_block4_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block4_pad[0][0]']
#  seConv2D)
#
#  stack3_block4_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block4_dw_conv[0][0]']
#  zation)
#
#  stack3_block4_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block4_ln[0][0]']
#                                 )
#
#  stack3_block4_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block4_up_dense[0][0]']
#  )                              )
#
#  stack3_block4_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block4_gelu[0][0]']
#  e)
#
#  stack3_block4_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block4_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block4_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block4_gamma[0][0]']
#
#  stack3_block4_output (Add)     (None, 14, 14, 768)  0           ['stack3_block3_output[0][0]',
#                                                                   'stack3_block4_drop[0][0]']
#
#  stack3_block5_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block4_output[0][0]']
#  2D)
#
#  stack3_block5_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block5_pad[0][0]']
#  seConv2D)
#
#  stack3_block5_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block5_dw_conv[0][0]']
#  zation)
#
#  stack3_block5_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block5_ln[0][0]']
#                                 )
#
#  stack3_block5_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block5_up_dense[0][0]']
#  )                              )
#
#  stack3_block5_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block5_gelu[0][0]']
#  e)
#
#  stack3_block5_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block5_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block5_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block5_gamma[0][0]']
#
#  stack3_block5_output (Add)     (None, 14, 14, 768)  0           ['stack3_block4_output[0][0]',
#                                                                   'stack3_block5_drop[0][0]']
#
#  stack3_block6_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block5_output[0][0]']
#  2D)
#
#  stack3_block6_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block6_pad[0][0]']
#  seConv2D)
#
#  stack3_block6_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block6_dw_conv[0][0]']
#  zation)
#
#  stack3_block6_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block6_ln[0][0]']
#                                 )
#
#  stack3_block6_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block6_up_dense[0][0]']
#  )                              )
#
#  stack3_block6_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block6_gelu[0][0]']
#  e)
#
#  stack3_block6_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block6_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block6_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block6_gamma[0][0]']
#
#  stack3_block6_output (Add)     (None, 14, 14, 768)  0           ['stack3_block5_output[0][0]',
#                                                                   'stack3_block6_drop[0][0]']
#
#  stack3_block7_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block6_output[0][0]']
#  2D)
#
#  stack3_block7_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block7_pad[0][0]']
#  seConv2D)
#
#  stack3_block7_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block7_dw_conv[0][0]']
#  zation)
#
#  stack3_block7_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block7_ln[0][0]']
#                                 )
#
#  stack3_block7_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block7_up_dense[0][0]']
#  )                              )
#
#  stack3_block7_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block7_gelu[0][0]']
#  e)
#
#  stack3_block7_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block7_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block7_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block7_gamma[0][0]']
#
#  stack3_block7_output (Add)     (None, 14, 14, 768)  0           ['stack3_block6_output[0][0]',
#                                                                   'stack3_block7_drop[0][0]']
#
#  stack3_block8_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block7_output[0][0]']
#  2D)
#
#  stack3_block8_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block8_pad[0][0]']
#  seConv2D)
#
#  stack3_block8_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block8_dw_conv[0][0]']
#  zation)
#
#  stack3_block8_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block8_ln[0][0]']
#                                 )
#
#  stack3_block8_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block8_up_dense[0][0]']
#  )                              )
#
#  stack3_block8_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block8_gelu[0][0]']
#  e)
#
#  stack3_block8_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block8_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block8_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block8_gamma[0][0]']
#
#  stack3_block8_output (Add)     (None, 14, 14, 768)  0           ['stack3_block7_output[0][0]',
#                                                                   'stack3_block8_drop[0][0]']
#
#  stack3_block9_pad (ZeroPadding  (None, 20, 20, 768)  0          ['stack3_block8_output[0][0]']
#  2D)
#
#  stack3_block9_dw_conv (Depthwi  (None, 14, 14, 768)  38400      ['stack3_block9_pad[0][0]']
#  seConv2D)
#
#  stack3_block9_ln (LayerNormali  (None, 14, 14, 768)  1536       ['stack3_block9_dw_conv[0][0]']
#  zation)
#
#  stack3_block9_up_dense (Dense)  (None, 14, 14, 3072  2362368    ['stack3_block9_ln[0][0]']
#                                 )
#
#  stack3_block9_gelu (Activation  (None, 14, 14, 3072  0          ['stack3_block9_up_dense[0][0]']
#  )                              )
#
#  stack3_block9_down_dense (Dens  (None, 14, 14, 768)  2360064    ['stack3_block9_gelu[0][0]']
#  e)
#
#  stack3_block9_gamma (ChannelAf  (None, 14, 14, 768)  768        ['stack3_block9_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block9_drop (Dropout)   (None, 14, 14, 768)  0           ['stack3_block9_gamma[0][0]']
#
#  stack3_block9_output (Add)     (None, 14, 14, 768)  0           ['stack3_block8_output[0][0]',
#                                                                   'stack3_block9_drop[0][0]']
#
#  stack3_block10_pad (ZeroPaddin  (None, 20, 20, 768)  0          ['stack3_block9_output[0][0]']
#  g2D)
#
#  stack3_block10_dw_conv (Depthw  (None, 14, 14, 768)  38400      ['stack3_block10_pad[0][0]']
#  iseConv2D)
#
#  stack3_block10_ln (LayerNormal  (None, 14, 14, 768)  1536       ['stack3_block10_dw_conv[0][0]']
#  ization)
#
#  stack3_block10_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block10_ln[0][0]']
#  )                              )
#
#  stack3_block10_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block10_up_dense[0][0]']
#  n)                             )
#
#  stack3_block10_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block10_gelu[0][0]']
#  se)
#
#  stack3_block10_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block10_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block10_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block10_gamma[0][0]']
#
#  stack3_block10_output (Add)    (None, 14, 14, 768)  0           ['stack3_block9_output[0][0]',
#                                                                   'stack3_block10_drop[0][0]']
#
#  stack3_block11_pad (ZeroPaddin  (None, 20, 20, 768)  0          ['stack3_block10_output[0][0]']
#  g2D)
#
#  stack3_block11_dw_conv (Depthw  (None, 14, 14, 768)  38400      ['stack3_block11_pad[0][0]']
#  iseConv2D)
#
#  stack3_block11_ln (LayerNormal  (None, 14, 14, 768)  1536       ['stack3_block11_dw_conv[0][0]']
#  ization)
#
#  stack3_block11_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block11_ln[0][0]']
#  )                              )
#
#  stack3_block11_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block11_up_dense[0][0]']
#  n)                             )
#
#  stack3_block11_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block11_gelu[0][0]']
#  se)
#
#  stack3_block11_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block11_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block11_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block11_gamma[0][0]']
#
#  stack3_block11_output (Add)    (None, 14, 14, 768)  0           ['stack3_block10_output[0][0]',
#                                                                   'stack3_block11_drop[0][0]']
#
#  stack3_block12_pad (ZeroPaddin  (None, 20, 20, 768)  0          ['stack3_block11_output[0][0]']
#  g2D)
#
#  stack3_block12_dw_conv (Depthw  (None, 14, 14, 768)  38400      ['stack3_block12_pad[0][0]']
#  iseConv2D)
#
#  stack3_block12_ln (LayerNormal  (None, 14, 14, 768)  1536       ['stack3_block12_dw_conv[0][0]']
#  ization)
#
#  stack3_block12_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block12_ln[0][0]']
#  )                              )
#
#  stack3_block12_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block12_up_dense[0][0]']
#  n)                             )
#
#  stack3_block12_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block12_gelu[0][0]']
#  se)
#
#  stack3_block12_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block12_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block12_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block12_gamma[0][0]']
#
#  stack3_block12_output (Add)    (None, 14, 14, 768)  0           ['stack3_block11_output[0][0]',
#                                                                   'stack3_block12_drop[0][0]']
# ...
#
#  stack3_block25_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block25_ln[0][0]']
#  )                              )
#
#  stack3_block25_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block25_up_dense[0][0]']
#  n)                             )
#
#  stack3_block25_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block25_gelu[0][0]']
#  se)
#
#  stack3_block25_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block25_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block25_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block25_gamma[0][0]']
#
#  stack3_block25_output (Add)    (None, 14, 14, 768)  0           ['stack3_block24_output[0][0]',
#                                                                   'stack3_block25_drop[0][0]']
#
#  stack3_block26_pad (ZeroPaddin  (None, 20, 20, 768)  0          ['stack3_block25_output[0][0]']
#  g2D)
#
#  stack3_block26_dw_conv (Depthw  (None, 14, 14, 768)  38400      ['stack3_block26_pad[0][0]']
#  iseConv2D)
#
#  stack3_block26_ln (LayerNormal  (None, 14, 14, 768)  1536       ['stack3_block26_dw_conv[0][0]']
#  ization)
#
#  stack3_block26_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block26_ln[0][0]']
#  )                              )
#
#  stack3_block26_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block26_up_dense[0][0]']
#  n)                             )
#
#  stack3_block26_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block26_gelu[0][0]']
#  se)
#
#  stack3_block26_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block26_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block26_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block26_gamma[0][0]']
#
#  stack3_block26_output (Add)    (None, 14, 14, 768)  0           ['stack3_block25_output[0][0]',
#                                                                   'stack3_block26_drop[0][0]']
#
#  stack3_block27_pad (ZeroPaddin  (None, 20, 20, 768)  0          ['stack3_block26_output[0][0]']
#  g2D)
#
#  stack3_block27_dw_conv (Depthw  (None, 14, 14, 768)  38400      ['stack3_block27_pad[0][0]']
#  iseConv2D)
#
#  stack3_block27_ln (LayerNormal  (None, 14, 14, 768)  1536       ['stack3_block27_dw_conv[0][0]']
#  ization)
#
#  stack3_block27_up_dense (Dense  (None, 14, 14, 3072  2362368    ['stack3_block27_ln[0][0]']
#  )                              )
#
#  stack3_block27_gelu (Activatio  (None, 14, 14, 3072  0          ['stack3_block27_up_dense[0][0]']
#  n)                             )
#
#  stack3_block27_down_dense (Den  (None, 14, 14, 768)  2360064    ['stack3_block27_gelu[0][0]']
#  se)
#
#  stack3_block27_gamma (ChannelA  (None, 14, 14, 768)  768        ['stack3_block27_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block27_drop (Dropout)  (None, 14, 14, 768)  0           ['stack3_block27_gamma[0][0]']
#
#  stack3_block27_output (Add)    (None, 14, 14, 768)  0           ['stack3_block26_output[0][0]',
#                                                                   'stack3_block27_drop[0][0]']
#
#  stack4_downsample_ln (LayerNor  (None, 14, 14, 768)  1536       ['stack3_block27_output[0][0]']
#  malization)
#
#  stack4_downsample_conv (Conv2D  (None, 7, 7, 1536)  4720128     ['stack4_downsample_ln[0][0]']
#  )
#
#  stack4_block1_pad (ZeroPadding  (None, 13, 13, 1536  0          ['stack4_downsample_conv[0][0]']
#  2D)                            )
#
#  stack4_block1_dw_conv (Depthwi  (None, 7, 7, 1536)  76800       ['stack4_block1_pad[0][0]']
#  seConv2D)
#
#  stack4_block1_ln (LayerNormali  (None, 7, 7, 1536)  3072        ['stack4_block1_dw_conv[0][0]']
#  zation)
#
#  stack4_block1_up_dense (Dense)  (None, 7, 7, 6144)  9443328     ['stack4_block1_ln[0][0]']
#
#  stack4_block1_gelu (Activation  (None, 7, 7, 6144)  0           ['stack4_block1_up_dense[0][0]']
#  )
#
#  stack4_block1_down_dense (Dens  (None, 7, 7, 1536)  9438720     ['stack4_block1_gelu[0][0]']
#  e)
#
#  stack4_block1_gamma (ChannelAf  (None, 7, 7, 1536)  1536        ['stack4_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block1_drop (Dropout)   (None, 7, 7, 1536)   0           ['stack4_block1_gamma[0][0]']
#
#  stack4_block1_output (Add)     (None, 7, 7, 1536)   0           ['stack4_downsample_conv[0][0]',
#                                                                   'stack4_block1_drop[0][0]']
#
#  stack4_block2_pad (ZeroPadding  (None, 13, 13, 1536  0          ['stack4_block1_output[0][0]']
#  2D)                            )
#
#  stack4_block2_dw_conv (Depthwi  (None, 7, 7, 1536)  76800       ['stack4_block2_pad[0][0]']
#  seConv2D)
#
#  stack4_block2_ln (LayerNormali  (None, 7, 7, 1536)  3072        ['stack4_block2_dw_conv[0][0]']
#  zation)
#
#  stack4_block2_up_dense (Dense)  (None, 7, 7, 6144)  9443328     ['stack4_block2_ln[0][0]']
#
#  stack4_block2_gelu (Activation  (None, 7, 7, 6144)  0           ['stack4_block2_up_dense[0][0]']
#  )
#
#  stack4_block2_down_dense (Dens  (None, 7, 7, 1536)  9438720     ['stack4_block2_gelu[0][0]']
#  e)
#
#  stack4_block2_gamma (ChannelAf  (None, 7, 7, 1536)  1536        ['stack4_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block2_drop (Dropout)   (None, 7, 7, 1536)   0           ['stack4_block2_gamma[0][0]']
#
#  stack4_block2_output (Add)     (None, 7, 7, 1536)   0           ['stack4_block1_output[0][0]',
#                                                                   'stack4_block2_drop[0][0]']
#
#  stack4_block3_pad (ZeroPadding  (None, 13, 13, 1536  0          ['stack4_block2_output[0][0]']
#  2D)                            )
#
#  stack4_block3_dw_conv (Depthwi  (None, 7, 7, 1536)  76800       ['stack4_block3_pad[0][0]']
#  seConv2D)
#
#  stack4_block3_ln (LayerNormali  (None, 7, 7, 1536)  3072        ['stack4_block3_dw_conv[0][0]']
#  zation)
#
#  stack4_block3_up_dense (Dense)  (None, 7, 7, 6144)  9443328     ['stack4_block3_ln[0][0]']
#
#  stack4_block3_gelu (Activation  (None, 7, 7, 6144)  0           ['stack4_block3_up_dense[0][0]']
#  )
#
#  stack4_block3_down_dense (Dens  (None, 7, 7, 1536)  9438720     ['stack4_block3_gelu[0][0]']
#  e)
#
#  stack4_block3_gamma (ChannelAf  (None, 7, 7, 1536)  1536        ['stack4_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block3_drop (Dropout)   (None, 7, 7, 1536)   0           ['stack4_block3_gamma[0][0]']
#
#  stack4_block3_output (Add)     (None, 7, 7, 1536)   0           ['stack4_block2_output[0][0]',
#                                                                   'stack4_block3_drop[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['stack4_block3_output[0][0]']
#  2D)
#
#  head_ln (LayerNormalization)   (None, 1536)         3072        ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 23)           35351       ['head_ln[0][0]']
#
# ==================================================================================================
# Total params: 196,265,687
# Trainable params: 196,265,687
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_5.fit(X_train, 
                  y_train, 
                  batch_size=32, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 168/168 [==============================] - 29s 147ms/step
#  - val_f1_macro: 0.4441349339985783 - val_f1_micro: 0.7692737430167598
#           - val_precision_macro: 0.5218861584408652 - val_precision_micro: 0.7692737430167598 - val_recall_macro: 0.4776873070244286 - val_recall_micro: 0.7692737430167598
#           - val_best_f1_score_macro: 0.4441349339985783 (epoch: 0) - val_best_f1_score_micro: 0.7692737430167598 (epoch: 0.7692737430167598)
# 168/168 [==============================] - 148s 724ms/step - loss: 0.7717 - accuracy: 0.7436 - top-5-accuracy: 0.9650 - val_loss: 0.4913 - val_accuracy: 0.7864 - val_top-5-accuracy: 0.9907
# Epoch 2/5
# 168/168 [==============================] - 25s 147ms/step
#  - val_f1_macro: 0.46220845057676796 - val_f1_micro: 0.7724394785847298
#           - val_precision_macro: 0.5318792541818154 - val_precision_micro: 0.7724394785847299 - val_recall_macro: 0.4766277557249463 - val_recall_micro: 0.7724394785847299
#           - val_best_f1_score_macro: 0.46220845057676796 (epoch: 1) - val_best_f1_score_micro: 0.7724394785847298 (epoch: 0.7724394785847298)
# 168/168 [==============================] - 113s 675ms/step - loss: 0.4010 - accuracy: 0.8613 - top-5-accuracy: 0.9927 - val_loss: 0.4848 - val_accuracy: 0.8309 - val_top-5-accuracy: 0.9920
# Epoch 3/5
# 168/168 [==============================] - 25s 148ms/step
#  - val_f1_macro: 0.5267508784679086 - val_f1_micro: 0.8562383612662943
#           - val_precision_macro: 0.554417348827661 - val_precision_micro: 0.8562383612662943 - val_recall_macro: 0.5407263004404199 - val_recall_micro: 0.8562383612662943
#           - val_best_f1_score_macro: 0.5267508784679086 (epoch: 2) - val_best_f1_score_micro: 0.8562383612662943 (epoch: 0.8562383612662943)
# 168/168 [==============================] - 113s 675ms/step - loss: 0.3236 - accuracy: 0.8911 - top-5-accuracy: 0.9963 - val_loss: 0.3707 - val_accuracy: 0.8752 - val_top-5-accuracy: 0.9922
# Epoch 4/5
# 168/168 [==============================] - 25s 147ms/step
#  - val_f1_macro: 0.541938850790412 - val_f1_micro: 0.8595903165735568
#           - val_precision_macro: 0.570420941978196 - val_precision_micro: 0.8595903165735568 - val_recall_macro: 0.5453762947141015 - val_recall_micro: 0.8595903165735568
#           - val_best_f1_score_macro: 0.541938850790412 (epoch: 3) - val_best_f1_score_micro: 0.8595903165735568 (epoch: 0.8595903165735568)
# 168/168 [==============================] - 113s 673ms/step - loss: 0.2461 - accuracy: 0.9175 - top-5-accuracy: 0.9972 - val_loss: 0.4301 - val_accuracy: 0.8711 - val_top-5-accuracy: 0.9909
# Epoch 5/5
# 168/168 [==============================] - 25s 147ms/step
#  - val_f1_macro: 0.542683929228873 - val_f1_micro: 0.8283054003724395
#           - val_precision_macro: 0.5709837502569887 - val_precision_micro: 0.8283054003724395 - val_recall_macro: 0.5526492262576906 - val_recall_micro: 0.8283054003724395
#           - val_best_f1_score_macro: 0.542683929228873 (epoch: 4) - val_best_f1_score_micro: 0.8595903165735568 (epoch: 0.8595903165735568)
# 168/168 [==============================] - 113s 675ms/step - loss: 0.2079 - accuracy: 0.9304 - top-5-accuracy: 0.9985 - val_loss: 0.4470 - val_accuracy: 0.8449 - val_top-5-accuracy: 0.9898

# %% [markdown]
# ## DaViT

# %%
from tensorflow_addons.optimizers import AdamW

learning_rate = 0.001
weight_decay = 0.0001

optimizer = AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

model_6.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy")
        ],
    )

model_6.summary()
# Out:
# Model: "davit_b"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           ['input_18[0][0]']
#
#  stem_conv (Conv2D)             (None, 56, 56, 128)  18944       ['stem_pad[0][0]']
#
#  stem_ln (LayerNormalization)   (None, 56, 56, 128)  256         ['stem_conv[0][0]']
#
#  stack1_block1_pre_attn_cpe_pad  (None, 58, 58, 128)  0          ['stem_ln[0][0]']
#   (ZeroPadding2D)
#
#  stack1_block1_pre_attn_cpe_dw_  (None, 56, 56, 128)  1280       ['stack1_block1_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack1_block1_pre_attn_cpe_out  (None, 56, 56, 128)  0          ['stem_ln[0][0]',
#  put (Add)                                                        'stack1_block1_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack1_block1_attn_ln (LayerNo  (None, 56, 56, 128)  256        ['stack1_block1_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  tf.reshape_1158 (TFOpLambda)   (None, 7, 8, 896)    0           ['stack1_block1_attn_ln[0][0]']
#
#  tf.compat.v1.transpose_976 (TF  (None, 8, 7, 896)   0           ['tf.reshape_1158[0][0]']
#  OpLambda)
#
#  tf.reshape_1159 (TFOpLambda)   (None, 7, 7, 128)    0           ['tf.compat.v1.transpose_976[0][0
#                                                                  ]']
#
#  stack1_block1_attn_qkv (Dense)  (None, 7, 7, 384)   49536       ['tf.reshape_1159[0][0]']
#
#  tf.reshape_1160 (TFOpLambda)   (None, 49, 384)      0           ['stack1_block1_attn_qkv[0][0]']
#
#  tf.split_241 (TFOpLambda)      [(None, 49, 128),    0           ['tf.reshape_1160[0][0]']
#                                  (None, 49, 128),
#                                  (None, 49, 128)]
#
#  tf.reshape_1161 (TFOpLambda)   (None, 49, 4, 32)    0           ['tf.split_241[0][0]']
#
#  tf.reshape_1162 (TFOpLambda)   (None, 49, 4, 32)    0           ['tf.split_241[0][1]']
#
#  tf.compat.v1.transpose_977 (TF  (None, 4, 49, 32)   0           ['tf.reshape_1161[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_978 (TF  (None, 4, 32, 49)   0           ['tf.reshape_1162[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_482 (TFOpLamb  (None, 4, 49, 49)   0           ['tf.compat.v1.transpose_977[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_978[0][0
#                                                                  ]']
#
#  tf.math.multiply_241 (TFOpLamb  (None, 4, 49, 49)   0           ['tf.linalg.matmul_482[0][0]']
#  da)
#
#  tf.reshape_1163 (TFOpLambda)   (None, 49, 4, 32)    0           ['tf.split_241[0][2]']
#
#  stack1_block1_attn_attention_s  (None, 4, 49, 49)   0           ['tf.math.multiply_241[0][0]']
#  cores (Softmax)
#
#  tf.compat.v1.transpose_979 (TF  (None, 4, 49, 32)   0           ['tf.reshape_1163[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_483 (TFOpLamb  (None, 4, 49, 32)   0           ['stack1_block1_attn_attention_sc
#  da)                                                             ores[0][0]',
#                                                                   'tf.compat.v1.transpose_979[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_980 (TF  (None, 49, 4, 32)   0           ['tf.linalg.matmul_483[0][0]']
#  OpLambda)
#
#  tf.reshape_1164 (TFOpLambda)   (None, 7, 7, 128)    0           ['tf.compat.v1.transpose_980[0][0
#                                                                  ]']
#
#  stack1_block1_attn_output (Den  (None, 7, 7, 128)   16512       ['tf.reshape_1164[0][0]']
#  se)
#
#  tf.reshape_1165 (TFOpLambda)   (None, 8, 7, 896)    0           ['stack1_block1_attn_output[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_981 (TF  (None, 7, 8, 896)   0           ['tf.reshape_1165[0][0]']
#  OpLambda)
#
#  tf.reshape_1166 (TFOpLambda)   (None, 56, 56, 128)  0           ['tf.compat.v1.transpose_981[0][0
#                                                                  ]']
#
#  stack1_block1_1_output (Add)   (None, 56, 56, 128)  0           ['stack1_block1_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'tf.reshape_1166[0][0]']
#
#  stack1_block1_pre_ffn_cpe_pad   (None, 58, 58, 128)  0          ['stack1_block1_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack1_block1_pre_ffn_cpe_dw_c  (None, 56, 56, 128)  1280       ['stack1_block1_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack1_block1_pre_ffn_cpe_outp  (None, 56, 56, 128)  0          ['stack1_block1_1_output[0][0]',
#  ut (Add)                                                         'stack1_block1_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack1_block1_mlp_ln (LayerNor  (None, 56, 56, 128)  256        ['stack1_block1_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack1_block1_mlp_Dense_0 (Den  (None, 56, 56, 512)  66048      ['stack1_block1_mlp_ln[0][0]']
#  se)
#
#  stack1_block1_mlp_gelu (Activa  (None, 56, 56, 512)  0          ['stack1_block1_mlp_Dense_0[0][0]
#  tion)                                                           ']
#
#  stack1_block1_mlp_Dense_1 (Den  (None, 56, 56, 128)  65664      ['stack1_block1_mlp_gelu[0][0]']
#  se)
#
#  stack1_block1_2_output (Add)   (None, 56, 56, 128)  0           ['stack1_block1_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack1_block1_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack1_block2_pre_attn_cpe_pad  (None, 58, 58, 128)  0          ['stack1_block1_2_output[0][0]']
#   (ZeroPadding2D)
#
#  stack1_block2_pre_attn_cpe_dw_  (None, 56, 56, 128)  1280       ['stack1_block2_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack1_block2_pre_attn_cpe_out  (None, 56, 56, 128)  0          ['stack1_block1_2_output[0][0]',
#  put (Add)                                                        'stack1_block2_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack1_block2_attn_ln (LayerNo  (None, 56, 56, 128)  256        ['stack1_block2_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  stack1_block2_channel_attn_qkv  (None, 56, 56, 384)  49536      ['stack1_block2_attn_ln[0][0]']
#   (Dense)
#
#  tf.reshape_1167 (TFOpLambda)   (None, 3136, 384)    0           ['stack1_block2_channel_attn_qkv[
#                                                                  0][0]']
#
#  tf.split_242 (TFOpLambda)      [(None, 3136, 128),  0           ['tf.reshape_1167[0][0]']
#                                  (None, 3136, 128),
#                                  (None, 3136, 128)]
#
#  tf.reshape_1168 (TFOpLambda)   (None, 3136, 4, 32)  0           ['tf.split_242[0][1]']
#
#  tf.reshape_1169 (TFOpLambda)   (None, 3136, 4, 32)  0           ['tf.split_242[0][2]']
#
#  tf.compat.v1.transpose_982 (TF  (None, 4, 32, 3136)  0          ['tf.reshape_1168[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_983 (TF  (None, 4, 3136, 32)  0          ['tf.reshape_1169[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_484 (TFOpLamb  (None, 4, 32, 32)   0           ['tf.compat.v1.transpose_982[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_983[0][0
#                                                                  ]']
#
#  tf.math.multiply_242 (TFOpLamb  (None, 4, 32, 32)   0           ['tf.linalg.matmul_484[0][0]']
#  da)
#
#  tf.reshape_1170 (TFOpLambda)   (None, 3136, 4, 32)  0           ['tf.split_242[0][0]']
#
#  stack1_block2_channel_attn_att  (None, 4, 32, 32)   0           ['tf.math.multiply_242[0][0]']
#  ention_scores (Softmax)
#
#  tf.compat.v1.transpose_984 (TF  (None, 4, 32, 3136)  0          ['tf.reshape_1170[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_485 (TFOpLamb  (None, 4, 32, 3136)  0          ['stack1_block2_channel_attn_atte
#  da)                                                             ntion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_984[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_985 (TF  (None, 3136, 4, 32)  0          ['tf.linalg.matmul_485[0][0]']
#  OpLambda)
#
#  tf.reshape_1171 (TFOpLambda)   (None, 56, 56, 128)  0           ['tf.compat.v1.transpose_985[0][0
#                                                                  ]']
#
#  stack1_block2_channel_attn_out  (None, 56, 56, 128)  16512      ['tf.reshape_1171[0][0]']
#  put (Dense)
#
#  stack1_block2_1_output (Add)   (None, 56, 56, 128)  0           ['stack1_block2_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'stack1_block2_channel_attn_outp
#                                                                  ut[0][0]']
#
#  stack1_block2_pre_ffn_cpe_pad   (None, 58, 58, 128)  0          ['stack1_block2_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack1_block2_pre_ffn_cpe_dw_c  (None, 56, 56, 128)  1280       ['stack1_block2_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack1_block2_pre_ffn_cpe_outp  (None, 56, 56, 128)  0          ['stack1_block2_1_output[0][0]',
#  ut (Add)                                                         'stack1_block2_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack1_block2_mlp_ln (LayerNor  (None, 56, 56, 128)  256        ['stack1_block2_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack1_block2_mlp_Dense_0 (Den  (None, 56, 56, 512)  66048      ['stack1_block2_mlp_ln[0][0]']
#  se)
#
#  stack1_block2_mlp_gelu (Activa  (None, 56, 56, 512)  0          ['stack1_block2_mlp_Dense_0[0][0]
#  tion)                                                           ']
#
#  stack1_block2_mlp_Dense_1 (Den  (None, 56, 56, 128)  65664      ['stack1_block2_mlp_gelu[0][0]']
#  se)
#
#  stack1_block2_2_output (Add)   (None, 56, 56, 128)  0           ['stack1_block2_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack1_block2_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack2_downsample_ln (LayerNor  (None, 56, 56, 128)  256        ['stack1_block2_2_output[0][0]']
#  malization)
#
#  stack2_downsample_conv (Conv2D  (None, 28, 28, 256)  131328     ['stack2_downsample_ln[0][0]']
#  )
#
#  stack2_block1_pre_attn_cpe_pad  (None, 30, 30, 256)  0          ['stack2_downsample_conv[0][0]']
#   (ZeroPadding2D)
#
#  stack2_block1_pre_attn_cpe_dw_  (None, 28, 28, 256)  2560       ['stack2_block1_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack2_block1_pre_attn_cpe_out  (None, 28, 28, 256)  0          ['stack2_downsample_conv[0][0]',
#  put (Add)                                                        'stack2_block1_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack2_block1_attn_ln (LayerNo  (None, 28, 28, 256)  512        ['stack2_block1_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  tf.reshape_1172 (TFOpLambda)   (None, 7, 4, 1792)   0           ['stack2_block1_attn_ln[0][0]']
#
#  tf.compat.v1.transpose_986 (TF  (None, 4, 7, 1792)  0           ['tf.reshape_1172[0][0]']
#  OpLambda)
#
#  tf.reshape_1173 (TFOpLambda)   (None, 7, 7, 256)    0           ['tf.compat.v1.transpose_986[0][0
#                                                                  ]']
#
#  stack2_block1_attn_qkv (Dense)  (None, 7, 7, 768)   197376      ['tf.reshape_1173[0][0]']
#
#  tf.reshape_1174 (TFOpLambda)   (None, 49, 768)      0           ['stack2_block1_attn_qkv[0][0]']
#
#  tf.split_243 (TFOpLambda)      [(None, 49, 256),    0           ['tf.reshape_1174[0][0]']
#                                  (None, 49, 256),
#                                  (None, 49, 256)]
#
#  tf.reshape_1175 (TFOpLambda)   (None, 49, 8, 32)    0           ['tf.split_243[0][0]']
#
#  tf.reshape_1176 (TFOpLambda)   (None, 49, 8, 32)    0           ['tf.split_243[0][1]']
#
#  tf.compat.v1.transpose_987 (TF  (None, 8, 49, 32)   0           ['tf.reshape_1175[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_988 (TF  (None, 8, 32, 49)   0           ['tf.reshape_1176[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_486 (TFOpLamb  (None, 8, 49, 49)   0           ['tf.compat.v1.transpose_987[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_988[0][0
#                                                                  ]']
#
#  tf.math.multiply_243 (TFOpLamb  (None, 8, 49, 49)   0           ['tf.linalg.matmul_486[0][0]']
#  da)
#
#  tf.reshape_1177 (TFOpLambda)   (None, 49, 8, 32)    0           ['tf.split_243[0][2]']
#
#  stack2_block1_attn_attention_s  (None, 8, 49, 49)   0           ['tf.math.multiply_243[0][0]']
#  cores (Softmax)
#
#  tf.compat.v1.transpose_989 (TF  (None, 8, 49, 32)   0           ['tf.reshape_1177[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_487 (TFOpLamb  (None, 8, 49, 32)   0           ['stack2_block1_attn_attention_sc
#  da)                                                             ores[0][0]',
#                                                                   'tf.compat.v1.transpose_989[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_990 (TF  (None, 49, 8, 32)   0           ['tf.linalg.matmul_487[0][0]']
#  OpLambda)
#
#  tf.reshape_1178 (TFOpLambda)   (None, 7, 7, 256)    0           ['tf.compat.v1.transpose_990[0][0
#                                                                  ]']
#
#  stack2_block1_attn_output (Den  (None, 7, 7, 256)   65792       ['tf.reshape_1178[0][0]']
#  se)
#
#  tf.reshape_1179 (TFOpLambda)   (None, 4, 7, 1792)   0           ['stack2_block1_attn_output[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_991 (TF  (None, 7, 4, 1792)  0           ['tf.reshape_1179[0][0]']
#  OpLambda)
#
#  tf.reshape_1180 (TFOpLambda)   (None, 28, 28, 256)  0           ['tf.compat.v1.transpose_991[0][0
#                                                                  ]']
#
#  stack2_block1_1_output (Add)   (None, 28, 28, 256)  0           ['stack2_block1_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'tf.reshape_1180[0][0]']
#
#  stack2_block1_pre_ffn_cpe_pad   (None, 30, 30, 256)  0          ['stack2_block1_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack2_block1_pre_ffn_cpe_dw_c  (None, 28, 28, 256)  2560       ['stack2_block1_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack2_block1_pre_ffn_cpe_outp  (None, 28, 28, 256)  0          ['stack2_block1_1_output[0][0]',
#  ut (Add)                                                         'stack2_block1_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack2_block1_mlp_ln (LayerNor  (None, 28, 28, 256)  512        ['stack2_block1_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack2_block1_mlp_Dense_0 (Den  (None, 28, 28, 1024  263168     ['stack2_block1_mlp_ln[0][0]']
#  se)                            )
#
#  stack2_block1_mlp_gelu (Activa  (None, 28, 28, 1024  0          ['stack2_block1_mlp_Dense_0[0][0]
#  tion)                          )                                ']
#
#  stack2_block1_mlp_Dense_1 (Den  (None, 28, 28, 256)  262400     ['stack2_block1_mlp_gelu[0][0]']
#  se)
#
#  stack2_block1_2_output (Add)   (None, 28, 28, 256)  0           ['stack2_block1_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack2_block1_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack2_block2_pre_attn_cpe_pad  (None, 30, 30, 256)  0          ['stack2_block1_2_output[0][0]']
#   (ZeroPadding2D)
#
#  stack2_block2_pre_attn_cpe_dw_  (None, 28, 28, 256)  2560       ['stack2_block2_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack2_block2_pre_attn_cpe_out  (None, 28, 28, 256)  0          ['stack2_block1_2_output[0][0]',
#  put (Add)                                                        'stack2_block2_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack2_block2_attn_ln (LayerNo  (None, 28, 28, 256)  512        ['stack2_block2_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  stack2_block2_channel_attn_qkv  (None, 28, 28, 768)  197376     ['stack2_block2_attn_ln[0][0]']
#   (Dense)
#
#  tf.reshape_1181 (TFOpLambda)   (None, 784, 768)     0           ['stack2_block2_channel_attn_qkv[
#                                                                  0][0]']
#
#  tf.split_244 (TFOpLambda)      [(None, 784, 256),   0           ['tf.reshape_1181[0][0]']
#                                  (None, 784, 256),
#                                  (None, 784, 256)]
#
#  tf.reshape_1182 (TFOpLambda)   (None, 784, 8, 32)   0           ['tf.split_244[0][1]']
#
#  tf.reshape_1183 (TFOpLambda)   (None, 784, 8, 32)   0           ['tf.split_244[0][2]']
#
#  tf.compat.v1.transpose_992 (TF  (None, 8, 32, 784)  0           ['tf.reshape_1182[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_993 (TF  (None, 8, 784, 32)  0           ['tf.reshape_1183[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_488 (TFOpLamb  (None, 8, 32, 32)   0           ['tf.compat.v1.transpose_992[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_993[0][0
#                                                                  ]']
#
#  tf.math.multiply_244 (TFOpLamb  (None, 8, 32, 32)   0           ['tf.linalg.matmul_488[0][0]']
#  da)
#
#  tf.reshape_1184 (TFOpLambda)   (None, 784, 8, 32)   0           ['tf.split_244[0][0]']
#
#  stack2_block2_channel_attn_att  (None, 8, 32, 32)   0           ['tf.math.multiply_244[0][0]']
#  ention_scores (Softmax)
#
#  tf.compat.v1.transpose_994 (TF  (None, 8, 32, 784)  0           ['tf.reshape_1184[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_489 (TFOpLamb  (None, 8, 32, 784)  0           ['stack2_block2_channel_attn_atte
#  da)                                                             ntion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_994[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_995 (TF  (None, 784, 8, 32)  0           ['tf.linalg.matmul_489[0][0]']
#  OpLambda)
#
#  tf.reshape_1185 (TFOpLambda)   (None, 28, 28, 256)  0           ['tf.compat.v1.transpose_995[0][0
#                                                                  ]']
#
#  stack2_block2_channel_attn_out  (None, 28, 28, 256)  65792      ['tf.reshape_1185[0][0]']
#  put (Dense)
#
#  stack2_block2_1_output (Add)   (None, 28, 28, 256)  0           ['stack2_block2_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'stack2_block2_channel_attn_outp
#                                                                  ut[0][0]']
#
#  stack2_block2_pre_ffn_cpe_pad   (None, 30, 30, 256)  0          ['stack2_block2_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack2_block2_pre_ffn_cpe_dw_c  (None, 28, 28, 256)  2560       ['stack2_block2_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack2_block2_pre_ffn_cpe_outp  (None, 28, 28, 256)  0          ['stack2_block2_1_output[0][0]',
#  ut (Add)                                                         'stack2_block2_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack2_block2_mlp_ln (LayerNor  (None, 28, 28, 256)  512        ['stack2_block2_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack2_block2_mlp_Dense_0 (Den  (None, 28, 28, 1024  263168     ['stack2_block2_mlp_ln[0][0]']
#  se)                            )
#
#  stack2_block2_mlp_gelu (Activa  (None, 28, 28, 1024  0          ['stack2_block2_mlp_Dense_0[0][0]
#  tion)                          )                                ']
#
#  stack2_block2_mlp_Dense_1 (Den  (None, 28, 28, 256)  262400     ['stack2_block2_mlp_gelu[0][0]']
#  se)
#
#  stack2_block2_2_output (Add)   (None, 28, 28, 256)  0           ['stack2_block2_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack2_block2_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack3_downsample_ln (LayerNor  (None, 28, 28, 256)  512        ['stack2_block2_2_output[0][0]']
#  malization)
#
#  stack3_downsample_conv (Conv2D  (None, 14, 14, 512)  524800     ['stack3_downsample_ln[0][0]']
#  )
#
#  stack3_block1_pre_attn_cpe_pad  (None, 16, 16, 512)  0          ['stack3_downsample_conv[0][0]']
#   (ZeroPadding2D)
#
#  stack3_block1_pre_attn_cpe_dw_  (None, 14, 14, 512)  5120       ['stack3_block1_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack3_block1_pre_attn_cpe_out  (None, 14, 14, 512)  0          ['stack3_downsample_conv[0][0]',
#  put (Add)                                                        'stack3_block1_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack3_block1_attn_ln (LayerNo  (None, 14, 14, 512)  1024       ['stack3_block1_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  tf.reshape_1186 (TFOpLambda)   (None, 7, 2, 3584)   0           ['stack3_block1_attn_ln[0][0]']
#
#  tf.compat.v1.transpose_996 (TF  (None, 2, 7, 3584)  0           ['tf.reshape_1186[0][0]']
#  OpLambda)
#
#  tf.reshape_1187 (TFOpLambda)   (None, 7, 7, 512)    0           ['tf.compat.v1.transpose_996[0][0
#                                                                  ]']
#
#  stack3_block1_attn_qkv (Dense)  (None, 7, 7, 1536)  787968      ['tf.reshape_1187[0][0]']
#
#  tf.reshape_1188 (TFOpLambda)   (None, 49, 1536)     0           ['stack3_block1_attn_qkv[0][0]']
#
#  tf.split_245 (TFOpLambda)      [(None, 49, 512),    0           ['tf.reshape_1188[0][0]']
#                                  (None, 49, 512),
#                                  (None, 49, 512)]
#
#  tf.reshape_1189 (TFOpLambda)   (None, 49, 16, 32)   0           ['tf.split_245[0][0]']
#
#  tf.reshape_1190 (TFOpLambda)   (None, 49, 16, 32)   0           ['tf.split_245[0][1]']
#
#  tf.compat.v1.transpose_997 (TF  (None, 16, 49, 32)  0           ['tf.reshape_1189[0][0]']
#  OpLambda)
#
#  tf.compat.v1.transpose_998 (TF  (None, 16, 32, 49)  0           ['tf.reshape_1190[0][0]']
#  OpLambda)
#
#  tf.linalg.matmul_490 (TFOpLamb  (None, 16, 49, 49)  0           ['tf.compat.v1.transpose_997[0][0
#  da)                                                             ]',
#                                                                   'tf.compat.v1.transpose_998[0][0
#                                                                  ]']
#
#  tf.math.multiply_245 (TFOpLamb  (None, 16, 49, 49)  0           ['tf.linalg.matmul_490[0][0]']
#  da)
#
#  tf.reshape_1191 (TFOpLambda)   (None, 49, 16, 32)   0           ['tf.split_245[0][2]']
#
#  stack3_block1_attn_attention_s  (None, 16, 49, 49)  0           ['tf.math.multiply_245[0][0]']
#  cores (Softmax)
#
# ...
#
#  tf.linalg.matmul_527 (TFOpLamb  (None, 32, 49, 32)  0           ['stack4_block1_attn_attention_sc
#  da)                                                             ores[0][0]',
#                                                                   'tf.compat.v1.transpose_1089[0][
#                                                                  0]']
#
#  tf.compat.v1.transpose_1090 (T  (None, 49, 32, 32)  0           ['tf.linalg.matmul_527[0][0]']
#  FOpLambda)
#
#  tf.reshape_1318 (TFOpLambda)   (None, 7, 7, 1024)   0           ['tf.compat.v1.transpose_1090[0][
#                                                                  0]']
#
#  stack4_block1_attn_output (Den  (None, 7, 7, 1024)  1049600     ['tf.reshape_1318[0][0]']
#  se)
#
#  tf.reshape_1319 (TFOpLambda)   (None, 1, 7, 7168)   0           ['stack4_block1_attn_output[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_1091 (T  (None, 7, 1, 7168)  0           ['tf.reshape_1319[0][0]']
#  FOpLambda)
#
#  tf.reshape_1320 (TFOpLambda)   (None, 7, 7, 1024)   0           ['tf.compat.v1.transpose_1091[0][
#                                                                  0]']
#
#  stack4_block1_1_output (Add)   (None, 7, 7, 1024)   0           ['stack4_block1_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'tf.reshape_1320[0][0]']
#
#  stack4_block1_pre_ffn_cpe_pad   (None, 9, 9, 1024)  0           ['stack4_block1_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack4_block1_pre_ffn_cpe_dw_c  (None, 7, 7, 1024)  10240       ['stack4_block1_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack4_block1_pre_ffn_cpe_outp  (None, 7, 7, 1024)  0           ['stack4_block1_1_output[0][0]',
#  ut (Add)                                                         'stack4_block1_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack4_block1_mlp_ln (LayerNor  (None, 7, 7, 1024)  2048        ['stack4_block1_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack4_block1_mlp_Dense_0 (Den  (None, 7, 7, 4096)  4198400     ['stack4_block1_mlp_ln[0][0]']
#  se)
#
#  stack4_block1_mlp_gelu (Activa  (None, 7, 7, 4096)  0           ['stack4_block1_mlp_Dense_0[0][0]
#  tion)                                                           ']
#
#  stack4_block1_mlp_Dense_1 (Den  (None, 7, 7, 1024)  4195328     ['stack4_block1_mlp_gelu[0][0]']
#  se)
#
#  stack4_block1_2_output (Add)   (None, 7, 7, 1024)   0           ['stack4_block1_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack4_block1_mlp_Dense_1[0][0]
#                                                                  ']
#
#  stack4_block2_pre_attn_cpe_pad  (None, 9, 9, 1024)  0           ['stack4_block1_2_output[0][0]']
#   (ZeroPadding2D)
#
#  stack4_block2_pre_attn_cpe_dw_  (None, 7, 7, 1024)  10240       ['stack4_block2_pre_attn_cpe_pad[
#  conv (DepthwiseConv2D)                                          0][0]']
#
#  stack4_block2_pre_attn_cpe_out  (None, 7, 7, 1024)  0           ['stack4_block1_2_output[0][0]',
#  put (Add)                                                        'stack4_block2_pre_attn_cpe_dw_c
#                                                                  onv[0][0]']
#
#  stack4_block2_attn_ln (LayerNo  (None, 7, 7, 1024)  2048        ['stack4_block2_pre_attn_cpe_outp
#  rmalization)                                                    ut[0][0]']
#
#  stack4_block2_channel_attn_qkv  (None, 7, 7, 3072)  3148800     ['stack4_block2_attn_ln[0][0]']
#   (Dense)
#
#  tf.reshape_1321 (TFOpLambda)   (None, 49, 3072)     0           ['stack4_block2_channel_attn_qkv[
#                                                                  0][0]']
#
#  tf.split_264 (TFOpLambda)      [(None, 49, 1024),   0           ['tf.reshape_1321[0][0]']
#                                  (None, 49, 1024),
#                                  (None, 49, 1024)]
#
#  tf.reshape_1322 (TFOpLambda)   (None, 49, 32, 32)   0           ['tf.split_264[0][1]']
#
#  tf.reshape_1323 (TFOpLambda)   (None, 49, 32, 32)   0           ['tf.split_264[0][2]']
#
#  tf.compat.v1.transpose_1092 (T  (None, 32, 32, 49)  0           ['tf.reshape_1322[0][0]']
#  FOpLambda)
#
#  tf.compat.v1.transpose_1093 (T  (None, 32, 49, 32)  0           ['tf.reshape_1323[0][0]']
#  FOpLambda)
#
#  tf.linalg.matmul_528 (TFOpLamb  (None, 32, 32, 32)  0           ['tf.compat.v1.transpose_1092[0][
#  da)                                                             0]',
#                                                                   'tf.compat.v1.transpose_1093[0][
#                                                                  0]']
#
#  tf.math.multiply_264 (TFOpLamb  (None, 32, 32, 32)  0           ['tf.linalg.matmul_528[0][0]']
#  da)
#
#  tf.reshape_1324 (TFOpLambda)   (None, 49, 32, 32)   0           ['tf.split_264[0][0]']
#
#  stack4_block2_channel_attn_att  (None, 32, 32, 32)  0           ['tf.math.multiply_264[0][0]']
#  ention_scores (Softmax)
#
#  tf.compat.v1.transpose_1094 (T  (None, 32, 32, 49)  0           ['tf.reshape_1324[0][0]']
#  FOpLambda)
#
#  tf.linalg.matmul_529 (TFOpLamb  (None, 32, 32, 49)  0           ['stack4_block2_channel_attn_atte
#  da)                                                             ntion_scores[0][0]',
#                                                                   'tf.compat.v1.transpose_1094[0][
#                                                                  0]']
#
#  tf.compat.v1.transpose_1095 (T  (None, 49, 32, 32)  0           ['tf.linalg.matmul_529[0][0]']
#  FOpLambda)
#
#  tf.reshape_1325 (TFOpLambda)   (None, 7, 7, 1024)   0           ['tf.compat.v1.transpose_1095[0][
#                                                                  0]']
#
#  stack4_block2_channel_attn_out  (None, 7, 7, 1024)  1049600     ['tf.reshape_1325[0][0]']
#  put (Dense)
#
#  stack4_block2_1_output (Add)   (None, 7, 7, 1024)   0           ['stack4_block2_pre_attn_cpe_outp
#                                                                  ut[0][0]',
#                                                                   'stack4_block2_channel_attn_outp
#                                                                  ut[0][0]']
#
#  stack4_block2_pre_ffn_cpe_pad   (None, 9, 9, 1024)  0           ['stack4_block2_1_output[0][0]']
#  (ZeroPadding2D)
#
#  stack4_block2_pre_ffn_cpe_dw_c  (None, 7, 7, 1024)  10240       ['stack4_block2_pre_ffn_cpe_pad[0
#  onv (DepthwiseConv2D)                                           ][0]']
#
#  stack4_block2_pre_ffn_cpe_outp  (None, 7, 7, 1024)  0           ['stack4_block2_1_output[0][0]',
#  ut (Add)                                                         'stack4_block2_pre_ffn_cpe_dw_co
#                                                                  nv[0][0]']
#
#  stack4_block2_mlp_ln (LayerNor  (None, 7, 7, 1024)  2048        ['stack4_block2_pre_ffn_cpe_outpu
#  malization)                                                     t[0][0]']
#
#  stack4_block2_mlp_Dense_0 (Den  (None, 7, 7, 4096)  4198400     ['stack4_block2_mlp_ln[0][0]']
#  se)
#
#  stack4_block2_mlp_gelu (Activa  (None, 7, 7, 4096)  0           ['stack4_block2_mlp_Dense_0[0][0]
#  tion)                                                           ']
#
#  stack4_block2_mlp_Dense_1 (Den  (None, 7, 7, 1024)  4195328     ['stack4_block2_mlp_gelu[0][0]']
#  se)
#
#  stack4_block2_2_output (Add)   (None, 7, 7, 1024)   0           ['stack4_block2_pre_ffn_cpe_outpu
#                                                                  t[0][0]',
#                                                                   'stack4_block2_mlp_Dense_1[0][0]
#                                                                  ']
#
#  pre_output_ln (LayerNormalizat  (None, 7, 7, 1024)  2048        ['stack4_block2_2_output[0][0]']
#  ion)
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['pre_output_ln[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 23)           23575       ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 86,952,983
# Trainable params: 86,952,983
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
metrics = MetricsCallback()

model_6.fit(X_train, 
                  y_train, 
                  batch_size=32, 
                  epochs=5, 
                  validation_data=(X_test, y_test), 
                  callbacks=[metrics])
# Out:
# Epoch 1/5
# 168/168 [==============================] - 25s 115ms/step
#  - val_f1_macro: 0.4072599189113387 - val_f1_micro: 0.7216014897579144
#           - val_precision_macro: 0.4280395437889379 - val_precision_micro: 0.7216014897579144 - val_recall_macro: 0.4206629592178578 - val_recall_micro: 0.7216014897579144
#           - val_best_f1_score_macro: 0.4072599189113387 (epoch: 0) - val_best_f1_score_micro: 0.7216014897579144 (epoch: 0.7216014897579144)
# 168/168 [==============================] - 101s 602ms/step - loss: 0.9341 - accuracy: 0.6877 - top-5-accuracy: 0.9466 - val_loss: 0.6108 - val_accuracy: 0.7890 - val_top-5-accuracy: 0.9873
# Epoch 2/5
# 168/168 [==============================] - 19s 115ms/step
#  - val_f1_macro: 0.43343410504149305 - val_f1_micro: 0.7597765363128491
#           - val_precision_macro: 0.49291358121830386 - val_precision_micro: 0.7597765363128491 - val_recall_macro: 0.4543915843357619 - val_recall_micro: 0.7597765363128491
#           - val_best_f1_score_macro: 0.43343410504149305 (epoch: 1) - val_best_f1_score_micro: 0.7597765363128491 (epoch: 0.7597765363128491)
# 168/168 [==============================] - 90s 534ms/step - loss: 0.4842 - accuracy: 0.8339 - top-5-accuracy: 0.9899 - val_loss: 0.5557 - val_accuracy: 0.7931 - val_top-5-accuracy: 0.9929
# Epoch 3/5
# 168/168 [==============================] - 19s 115ms/step
#  - val_f1_macro: 0.4742485077856029 - val_f1_micro: 0.8167597765363128
#           - val_precision_macro: 0.548517069701323 - val_precision_micro: 0.8167597765363128 - val_recall_macro: 0.4936084927544544 - val_recall_micro: 0.8167597765363128
#           - val_best_f1_score_macro: 0.4742485077856029 (epoch: 2) - val_best_f1_score_micro: 0.8167597765363128 (epoch: 0.8167597765363128)
# 168/168 [==============================] - 89s 534ms/step - loss: 0.4209 - accuracy: 0.8590 - top-5-accuracy: 0.9922 - val_loss: 0.4905 - val_accuracy: 0.8456 - val_top-5-accuracy: 0.9912
# Epoch 4/5
# 168/168 [==============================] - 19s 115ms/step
#  - val_f1_macro: 0.5092047017126545 - val_f1_micro: 0.8245810055865922
#           - val_precision_macro: 0.5790891675843021 - val_precision_micro: 0.8245810055865922 - val_recall_macro: 0.5175349107014207 - val_recall_micro: 0.8245810055865922
#           - val_best_f1_score_macro: 0.5092047017126545 (epoch: 3) - val_best_f1_score_micro: 0.8245810055865922 (epoch: 0.8245810055865922)
# 168/168 [==============================] - 90s 534ms/step - loss: 0.3544 - accuracy: 0.8806 - top-5-accuracy: 0.9955 - val_loss: 0.4755 - val_accuracy: 0.8495 - val_top-5-accuracy: 0.9879
# Epoch 5/5
# 168/168 [==============================] - 19s 115ms/step
#  - val_f1_macro: 0.5062944275752578 - val_f1_micro: 0.8364990689013035
#           - val_precision_macro: 0.5645761000654141 - val_precision_micro: 0.8364990689013035 - val_recall_macro: 0.5039627108926183 - val_recall_micro: 0.8364990689013035
#           - val_best_f1_score_macro: 0.5092047017126545 (epoch: 3) - val_best_f1_score_micro: 0.8364990689013035 (epoch: 0.8364990689013035)
# 168/168 [==============================] - 89s 534ms/step - loss: 0.3293 - accuracy: 0.8831 - top-5-accuracy: 0.9946 - val_loss: 0.4409 - val_accuracy: 0.8533 - val_top-5-accuracy: 0.9933
